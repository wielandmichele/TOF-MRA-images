# %%
# !pip install statsmodels

# %%
from numba import cuda
device = cuda.get_current_device()
device.reset()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b0eb58af4839> in <module>
# ----> 1 from numba import cuda
#       2 device = cuda.get_current_device()
#       3 device.reset()
#
# ModuleNotFoundError: No module named 'numba'

# %%
import os
import pandas as pd
import zipfile
import numpy as np
import tensorflow as tf
import h5py
import random
from scipy import ndimage
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import sklearn
import tempfile
import datetime
from statsmodels.stats.proportion import proportion_confint
from functions.auc_delong_xu import auc_ci_Delong

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import to_categorical
from keras.layers.merge import concatenate
from tensorflow.keras import regularizers

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session
import gc

from keras import backend as K

# %%
tf.__version__
# Out:
# '2.4.0'

# %% [markdown]
# ### Import data from HD5File

# %% [markdown]
# Checking the data

# %%
PATH_3D_H5 = 'Images/preprocessed_data_64_56_20.hdf5'
with h5py.File(PATH_3D_H5, 'r') as h5:
    print('H5-file: ', list(h5.keys()))

     # Training data
    X_train = h5["X_train"][:]
    Y_train = h5["Y_train"][:]
    pat_train = h5["pat_train"][:]

    # Test
    X_test = h5["X_test"][:]
    Y_test = h5["Y_test"][:]
    pat_test = h5["pat_test"][:]

print(X_train.shape, X_train.min(), X_train.max(), X_train.mean(), X_train.std(), Y_train.shape)
print(X_test.shape, X_test.min(), X_test.max(), X_test.mean(), X_test.std(), Y_test.shape)
# Out:
# H5-file:  ['X_test', 'X_train', 'Y_test', 'Y_train', 'pat_test', 'pat_train']
# (407, 64, 56, 20, 1) -1.6816219000176573 19.021640746993885 -2.6654705119115727e-18 1.0000000000000009 (407, 2)
# (101, 64, 56, 20, 1) -1.6874111699704113 16.380229156865855 1.871832878858821e-17 0.9999999999999997 (101, 2)

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# Zoom images

# %%
# zoom
def random_zoom3d(X_im, min_zoom, max_zoom):
    z = np.random.sample() *(max_zoom-min_zoom) + min_zoom
    zoom_matrix = np.array([[z, 0, 0, 0],
                            [0, z, 0, 0],
                            [0, 0, z, 0],
                            [0, 0, 0, 1]])
    return ndimage.affine_transform(X_im, zoom_matrix, mode = "nearest", order = 1)

# %%
x = X_train[0]
X_aug = random_zoom3d(x, 0.8,1.00)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Rotate images

# %%
# rotate
def random_rotate3d(X_im, min_angle_xy, max_angle_xy, min_angle_xz, max_angle_xz, min_angle_yz, max_angle_yz):
    angle_xy = np.random.uniform(min_angle_xy, max_angle_xy)
    angle_xz = np.random.uniform(min_angle_xz, max_angle_xz)
    angle_yz = np.random.uniform(min_angle_yz, max_angle_yz)
    rotation_axis = np.random.choice([0,1,2])
    if(rotation_axis == 0):
        X_im = ndimage.rotate(X_im, angle = angle_xy, axes = (0,1), mode = "nearest", reshape = False, order = 3)
    if(rotation_axis == 1):
        X_im = ndimage.rotate(X_im, angle = angle_xz, axes = (0,2), mode = "nearest", reshape = False, order = 3)
    if(rotation_axis == 2):
        X_im = ndimage.rotate(X_im, angle = angle_yz, axes = (1,2), mode = "nearest", reshape = False, order = 3)
    return X_im

# %%
x = X_train[0]
X_aug = random_rotate3d(x, -20, 20, -10, 10, -5, 5)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Shifting images

# %%
# shifting
def random_shift3d(X_im, min_shift_x, max_shift_x, min_shift_y, max_shift_y, min_shift_z, max_shift_z):
    x_shift = np.random.uniform(min_shift_x, max_shift_x)
    y_shift = np.random.uniform(min_shift_y, max_shift_y)
    z_shift = np.random.uniform(min_shift_z, max_shift_z)
    return ndimage.shift(X_im, [x_shift, y_shift, z_shift, 0], mode = "nearest", order = 0)

# %%
x = X_train[0]
X_aug = random_shift3d(x, -10, 10, -10, 10, 0, 0)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Flipping images

# %%
def random_flip3d(X_im):
    axis = np.random.choice([0,1])
    if(axis == 0): # vertical flip
        X_im = X_im[:,::-1,:,:]
        # X_im = X_im[::-1,:,:,:] #horizontal
        # X_im = np.asarray(X_im).swapaxes(0, 1)#left, right flip
    return X_im

# %%
x = X_train[0]
X_aug = random_flip3d(x)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Gauss filter

# %%
# Gauss filter (Glättung, Mittelwertberechnung per Pixel basierend auf umgebenden Pixeln ausgewählt mit Gaussfkt.)
def random_gaussianfilter3d(X_im, sigma_max):
    sigma = np.random.uniform(0, sigma_max)
    return ndimage.gaussian_filter(X_im, sigma, mode = "nearest")

# %%
x = X_train[0]
X_aug = random_gaussianfilter3d(x, 0.2)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %%
@tf.function
def augment_3d_many(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        if IMAGE_DIMENSION == (128, 112, 64):
            volume = random_zoom3d(volume, 0.8, 1.3)
            volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            volume = random_shift3d(volume, -20, 20, -20, 20, 0, 0) #do not shift in z direction
            #volume = random_flip3d(volume)
            #volume = random_gaussianfilter3d(volume, 0.2)
            
        if IMAGE_DIMENSION == (96,84,30):
            volume = random_zoom3d(volume, 0.90,1.1)
            volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0)
            volume = random_flip3d(volume)
            volume = random_gaussianfilter3d(volume, 0.2)
            
        if IMAGE_DIMENSION == (64,56,20):
            volume = random_zoom3d(volume, 0.95,1.05) 
            volume = random_rotate3d(volume, -10, 10, -5, 5, -5, 5)
            volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
            #volume = random_flip3d(volume)
            volume = random_gaussianfilter3d(volume, 0.2)
            
        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
@tf.function
def augment_3d_one(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        rand = np.random.randint(0,6)
        
        if IMAGE_DIMENSION == (128, 112, 40):
            if rand == 0:
                volume = random_zoom3d(volume, 0.8, 1.3)
            if rand == 1:
                volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            if rand == 2:
                volume = random_shift3d(volume, -20, 20, -20, 20, 0, 0) #do not shift in z direction
            if rand == 3:
                volume = random_flip3d(volume)
            if rand == 4:
                volume = random_gaussianfilter3d(volume, 0.2)
            if rand == 5:
                volume = volume
            
        if IMAGE_DIMENSION == (64,56,20):
            if rand == 0:
                volume = random_zoom3d(volume, 0.8,1.1) 
            if rand == 1:
                volume = random_rotate3d(volume, -20, 20, -10, 10, 0, 0)
            if rand == 2:
                #volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
                volume = random_shift3d(volume, -10, 10, -10, 10, 0, 0) #do not shift in z direction
            if rand == 3:
                volume = random_flip3d(volume)
            if rand == 4:
                volume = random_gaussianfilter3d(volume, 0.2)
            if rand == 5:
                volume = volume

        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
@tf.function
def augment_3d_two(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        rand = np.random.randint(0,6, size = 2)
            
        if IMAGE_DIMENSION == (64,56,20):
            if 0 in rand:
                volume = volume
                rand = np.array([0,0])
            if 1 in rand:
                volume = random_rotate3d(volume, -20, 20, -10, 10, 0, 0)
            if 2 in rand:
                #volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
                volume = random_shift3d(volume, -10, 10, -10, 10, 0, 0) #do not shift in z direction
            if 3 in rand:
                volume = random_flip3d(volume)
            if 4 in rand:
                volume = random_gaussianfilter3d(volume, 0.2)
            if 5 in rand:
                volume = random_zoom3d(volume, 0.8,1.00) 

        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
def train_preprocessing(volume, label):
    volume = augment_3d_two(volume)
    return volume, label

# %% [markdown]
# Balanced dataset with tf.data

# %%
bool_train_labels = Y_train[:,1] != 0
pos_features = X_train[bool_train_labels]
neg_features = X_train[~bool_train_labels]
pos_labels = Y_train[bool_train_labels]
neg_labels = Y_train[~bool_train_labels]

# %%
def make_ds(features, labels):
  ds = tf.data.Dataset.from_tensor_slices((features, labels))#.cache()
  ds = ds.shuffle(len(pos_features)*2).repeat()
  return ds

pos_ds = make_ds(pos_features, pos_labels)
neg_ds = make_ds(neg_features, neg_labels)

# %%
resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5])
validation_loader = tf.data.Dataset.from_tensor_slices((X_test, Y_test))

batch_size = 4
# Augment the on the fly during training.
resampled_data = (
    
    resampled_ds.shuffle(buffer_size = (len(pos_features)*2), reshuffle_each_iteration=True)
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(X_test))
    .batch(batch_size)
    .prefetch(2)
)

# %%
pos = len(pos_features)
neg = len(neg_features)
total = pos + neg
resampled_steps_per_epoch = np.ceil(2.0*pos/batch_size)
resampled_steps_per_epoch
# Out:
# 141.0

# %%
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.62
# Weight for class 1: 0.72

# %% [markdown]
# ### Train CNN

# %%
IMAGE_DIMENSION = (64,56,20)
w = IMAGE_DIMENSION[0]
h = IMAGE_DIMENSION[1]
d = IMAGE_DIMENSION[2]

# %%
def get_model(width=w, height=h, depth=d):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=16, kernel_size=3, activation="relu", padding = 'same')(inputs)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2, padding = 'same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Flatten()(x)
    
    x = layers.Dense(units=64, activation="relu", kernel_regularizer=regularizers.l2(0.001))(x)
    #x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)

    outputs = layers.Dense(units=2, activation="softmax")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")

    return model

# %%
# Build model softmax
model = get_model(width=w, height=h, depth=d)
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 56, 20, 1)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 64, 56, 20, 16)    448
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 32, 28, 10, 16)    0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 28, 10, 16)    64
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 32, 28, 10, 32)    13856
# _________________________________________________________________
# average_pooling3d_1 (Average (None, 16, 14, 5, 32)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 14, 5, 32)     128
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 16, 14, 5, 32)     27680
# _________________________________________________________________
# average_pooling3d_2 (Average (None, 8, 7, 2, 32)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 7, 2, 32)       128
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 7, 2, 64)       55360
# _________________________________________________________________
# average_pooling3d_3 (Average (None, 4, 3, 1, 64)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 3, 1, 64)       256
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 3, 1, 64)       110656
# _________________________________________________________________
# average_pooling3d_4 (Average (None, 2, 2, 1, 64)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 2, 1, 64)       256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 225,410
# Trainable params: 224,994
# Non-trainable params: 416
# _________________________________________________________________

# %%
### define metrics
metrics = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc')]

### prepare files for logging
if os.path.exists('results.csv'):
    os.remove('results.csv')
    
shutil.rmtree('History')
os.makedirs('History')
    
filepath = 'History/model.epoch{epoch:02d}.hdf5'
    
### define callback_list
callback_list = [
    keras.callbacks.ModelCheckpoint(filepath=filepath, save_freq='epoch', verbose=1), 
    keras.callbacks.CSVLogger('results.csv')]
    
model.compile(loss = "categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate =  0.00001),
              #optimizer = keras.optimizers.RMSprop(learning_rate = 0.00001),
              metrics = metrics)

# %%
 def reset_keras():
        """
        Resets the Tensorflow graph and clears the session. Should be executed after eevery traning session with a model.

        :return:
        """
        sess = tf.compat.v1.keras.backend.get_session()
        tf.keras.backend.clear_session()
        sess.close()
        sess = tf.compat.v1.keras.backend.get_session()

        try:
            del model # this is from global space - change this as you need
        except:
            pass

        print(gc.collect()) # if it's done something you should see a number being outputted

        # use the same config as you used to create the session
        config = ConfigProto()
        config.gpu_options.per_process_gpu_memory_fraction = 1
        config.gpu_options.visible_device_list = "0"
        tf.compat.v1.keras.backend.set_session(Session(config=config))

# %%
reset_keras()
# Out:
# 114

# %% [markdown]
# ### Balanced model

# %%
epochs = 300
hist = model.fit(
    resampled_data,
    validation_data=validation_dataset,
    epochs=epochs,
    verbose=1, callbacks=callback_list, 
    steps_per_epoch = resampled_steps_per_epoch,
    class_weight = class_weight)
# Out:
# Epoch 1/300
# 141/141 [==============================] - 30s 193ms/step - loss: 1.0366 - accuracy: 0.5037 - auc: 0.5141 - val_loss: 0.9677 - val_accuracy: 0.3069 - val_auc: 0.3218
#
# Epoch 00001: saving model to History/model.epoch01.hdf5
# Epoch 2/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.9418 - accuracy: 0.4852 - auc: 0.4984 - val_loss: 0.9494 - val_accuracy: 0.3069 - val_auc: 0.3409
#
# Epoch 00002: saving model to History/model.epoch02.hdf5
# Epoch 3/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.9424 - accuracy: 0.4761 - auc: 0.4828 - val_loss: 1.0606 - val_accuracy: 0.3267 - val_auc: 0.3121
#
# Epoch 00003: saving model to History/model.epoch03.hdf5
# Epoch 4/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.8755 - accuracy: 0.5290 - auc: 0.5276 - val_loss: 1.0194 - val_accuracy: 0.3465 - val_auc: 0.3102
#
# Epoch 00004: saving model to History/model.epoch04.hdf5
# Epoch 5/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8852 - accuracy: 0.5282 - auc: 0.5401 - val_loss: 0.9889 - val_accuracy: 0.3663 - val_auc: 0.3325
#
# Epoch 00005: saving model to History/model.epoch05.hdf5
# Epoch 6/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.8557 - accuracy: 0.4965 - auc: 0.5247 - val_loss: 1.0227 - val_accuracy: 0.3564 - val_auc: 0.3125
#
# Epoch 00006: saving model to History/model.epoch06.hdf5
# Epoch 7/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.8455 - accuracy: 0.5287 - auc: 0.5444 - val_loss: 1.1001 - val_accuracy: 0.3069 - val_auc: 0.2937
#
# Epoch 00007: saving model to History/model.epoch07.hdf5
# Epoch 8/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.8237 - accuracy: 0.5104 - auc: 0.5320 - val_loss: 1.1153 - val_accuracy: 0.2970 - val_auc: 0.2765
#
# Epoch 00008: saving model to History/model.epoch08.hdf5
# Epoch 9/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.8541 - accuracy: 0.5366 - auc: 0.5489 - val_loss: 1.1150 - val_accuracy: 0.3069 - val_auc: 0.2902
#
# Epoch 00009: saving model to History/model.epoch09.hdf5
# Epoch 10/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8137 - accuracy: 0.5677 - auc: 0.5868 - val_loss: 1.1560 - val_accuracy: 0.2772 - val_auc: 0.2594
#
# Epoch 00010: saving model to History/model.epoch10.hdf5
# Epoch 11/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8223 - accuracy: 0.5262 - auc: 0.5669 - val_loss: 0.9942 - val_accuracy: 0.3960 - val_auc: 0.3327
#
# Epoch 00011: saving model to History/model.epoch11.hdf5
# Epoch 12/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7969 - accuracy: 0.5498 - auc: 0.5853 - val_loss: 1.1005 - val_accuracy: 0.3168 - val_auc: 0.2859
#
# Epoch 00012: saving model to History/model.epoch12.hdf5
# Epoch 13/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8015 - accuracy: 0.5220 - auc: 0.5766 - val_loss: 1.1293 - val_accuracy: 0.3168 - val_auc: 0.2914
#
# Epoch 00013: saving model to History/model.epoch13.hdf5
# Epoch 14/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.8214 - accuracy: 0.5301 - auc: 0.5532 - val_loss: 1.0768 - val_accuracy: 0.3168 - val_auc: 0.3002
#
# Epoch 00014: saving model to History/model.epoch14.hdf5
# Epoch 15/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.8223 - accuracy: 0.5250 - auc: 0.5494 - val_loss: 1.0952 - val_accuracy: 0.3168 - val_auc: 0.2800
#
# Epoch 00015: saving model to History/model.epoch15.hdf5
# Epoch 16/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7905 - accuracy: 0.5342 - auc: 0.5882 - val_loss: 1.0561 - val_accuracy: 0.3564 - val_auc: 0.2980
#
# Epoch 00016: saving model to History/model.epoch16.hdf5
# Epoch 17/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.7806 - accuracy: 0.5334 - auc: 0.6015 - val_loss: 1.0392 - val_accuracy: 0.3861 - val_auc: 0.3332
#
# Epoch 00017: saving model to History/model.epoch17.hdf5
# Epoch 18/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8113 - accuracy: 0.5590 - auc: 0.5732 - val_loss: 0.9475 - val_accuracy: 0.3762 - val_auc: 0.3488
#
# Epoch 00018: saving model to History/model.epoch18.hdf5
# Epoch 19/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.7747 - accuracy: 0.5305 - auc: 0.5844 - val_loss: 0.9985 - val_accuracy: 0.3564 - val_auc: 0.3287
#
# Epoch 00019: saving model to History/model.epoch19.hdf5
# Epoch 20/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.7647 - accuracy: 0.5701 - auc: 0.6294 - val_loss: 0.9769 - val_accuracy: 0.3762 - val_auc: 0.3350
#
# Epoch 00020: saving model to History/model.epoch20.hdf5
# Epoch 21/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7485 - accuracy: 0.5743 - auc: 0.6376 - val_loss: 1.0489 - val_accuracy: 0.3267 - val_auc: 0.3055
#
# Epoch 00021: saving model to History/model.epoch21.hdf5
# Epoch 22/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7764 - accuracy: 0.5634 - auc: 0.6101 - val_loss: 1.0544 - val_accuracy: 0.3366 - val_auc: 0.3011
#
# Epoch 00022: saving model to History/model.epoch22.hdf5
# Epoch 23/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7730 - accuracy: 0.5582 - auc: 0.6124 - val_loss: 1.0518 - val_accuracy: 0.3267 - val_auc: 0.2998
#
# Epoch 00023: saving model to History/model.epoch23.hdf5
# Epoch 24/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.8099 - accuracy: 0.5652 - auc: 0.5937 - val_loss: 1.0574 - val_accuracy: 0.3267 - val_auc: 0.2809
#
# Epoch 00024: saving model to History/model.epoch24.hdf5
# Epoch 25/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7733 - accuracy: 0.5888 - auc: 0.6164 - val_loss: 0.9785 - val_accuracy: 0.3168 - val_auc: 0.3102
#
# Epoch 00025: saving model to History/model.epoch25.hdf5
# Epoch 26/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7876 - accuracy: 0.5778 - auc: 0.6121 - val_loss: 1.0634 - val_accuracy: 0.3168 - val_auc: 0.2851
#
# Epoch 00026: saving model to History/model.epoch26.hdf5
# Epoch 27/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7622 - accuracy: 0.5639 - auc: 0.6176 - val_loss: 1.1076 - val_accuracy: 0.3168 - val_auc: 0.2990
#
# Epoch 00027: saving model to History/model.epoch27.hdf5
# Epoch 28/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.7274 - accuracy: 0.6024 - auc: 0.6715 - val_loss: 1.1465 - val_accuracy: 0.3168 - val_auc: 0.2907
#
# Epoch 00028: saving model to History/model.epoch28.hdf5
# Epoch 29/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.7596 - accuracy: 0.6113 - auc: 0.6566 - val_loss: 1.1902 - val_accuracy: 0.2970 - val_auc: 0.2815
#
# Epoch 00029: saving model to History/model.epoch29.hdf5
# Epoch 30/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7406 - accuracy: 0.5886 - auc: 0.6805 - val_loss: 1.2448 - val_accuracy: 0.3069 - val_auc: 0.2876
#
# Epoch 00030: saving model to History/model.epoch30.hdf5
# Epoch 31/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7287 - accuracy: 0.6080 - auc: 0.6825 - val_loss: 1.1419 - val_accuracy: 0.3168 - val_auc: 0.2855
#
# Epoch 00031: saving model to History/model.epoch31.hdf5
# Epoch 32/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7964 - accuracy: 0.5414 - auc: 0.5880 - val_loss: 1.0141 - val_accuracy: 0.3960 - val_auc: 0.3434
#
# Epoch 00032: saving model to History/model.epoch32.hdf5
# Epoch 33/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7627 - accuracy: 0.6015 - auc: 0.6442 - val_loss: 1.0040 - val_accuracy: 0.3564 - val_auc: 0.3255
#
# Epoch 00033: saving model to History/model.epoch33.hdf5
# Epoch 34/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.7396 - accuracy: 0.5868 - auc: 0.6528 - val_loss: 1.0278 - val_accuracy: 0.3366 - val_auc: 0.3053
#
# Epoch 00034: saving model to History/model.epoch34.hdf5
# Epoch 35/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.7413 - accuracy: 0.5830 - auc: 0.6520 - val_loss: 0.9190 - val_accuracy: 0.4257 - val_auc: 0.3978
#
# Epoch 00035: saving model to History/model.epoch35.hdf5
# Epoch 36/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7550 - accuracy: 0.5862 - auc: 0.6318 - val_loss: 1.0415 - val_accuracy: 0.3762 - val_auc: 0.3144
#
# Epoch 00036: saving model to History/model.epoch36.hdf5
# Epoch 37/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7146 - accuracy: 0.6248 - auc: 0.6897 - val_loss: 0.9620 - val_accuracy: 0.4257 - val_auc: 0.3801
#
# Epoch 00037: saving model to History/model.epoch37.hdf5
# Epoch 38/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7033 - accuracy: 0.6446 - auc: 0.7086 - val_loss: 1.0878 - val_accuracy: 0.3267 - val_auc: 0.2944
#
# Epoch 00038: saving model to History/model.epoch38.hdf5
# Epoch 39/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.7287 - accuracy: 0.6381 - auc: 0.6822 - val_loss: 0.9674 - val_accuracy: 0.3762 - val_auc: 0.3469
#
# Epoch 00039: saving model to History/model.epoch39.hdf5
# Epoch 40/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.7204 - accuracy: 0.6317 - auc: 0.6789 - val_loss: 0.8976 - val_accuracy: 0.4653 - val_auc: 0.4126
#
# Epoch 00040: saving model to History/model.epoch40.hdf5
# Epoch 41/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7308 - accuracy: 0.6497 - auc: 0.6851 - val_loss: 0.9493 - val_accuracy: 0.3564 - val_auc: 0.3631
#
# Epoch 00041: saving model to History/model.epoch41.hdf5
# Epoch 42/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6833 - accuracy: 0.6436 - auc: 0.7188 - val_loss: 0.9429 - val_accuracy: 0.4158 - val_auc: 0.3975
#
# Epoch 00042: saving model to History/model.epoch42.hdf5
# Epoch 43/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7198 - accuracy: 0.6230 - auc: 0.6936 - val_loss: 0.9976 - val_accuracy: 0.3762 - val_auc: 0.3416
#
# Epoch 00043: saving model to History/model.epoch43.hdf5
# Epoch 44/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7152 - accuracy: 0.6575 - auc: 0.6898 - val_loss: 0.9143 - val_accuracy: 0.4356 - val_auc: 0.4343
#
# Epoch 00044: saving model to History/model.epoch44.hdf5
# Epoch 45/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6986 - accuracy: 0.6502 - auc: 0.7067 - val_loss: 0.8837 - val_accuracy: 0.5149 - val_auc: 0.5039
#
# Epoch 00045: saving model to History/model.epoch45.hdf5
# Epoch 46/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.6930 - accuracy: 0.6787 - auc: 0.7269 - val_loss: 0.9377 - val_accuracy: 0.4653 - val_auc: 0.4370
#
# Epoch 00046: saving model to History/model.epoch46.hdf5
# Epoch 47/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.7041 - accuracy: 0.6053 - auc: 0.6897 - val_loss: 1.0482 - val_accuracy: 0.3465 - val_auc: 0.3547
#
# Epoch 00047: saving model to History/model.epoch47.hdf5
# Epoch 48/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6630 - accuracy: 0.6648 - auc: 0.7471 - val_loss: 1.1317 - val_accuracy: 0.3366 - val_auc: 0.3515
#
# Epoch 00048: saving model to History/model.epoch48.hdf5
# Epoch 49/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6785 - accuracy: 0.6293 - auc: 0.7155 - val_loss: 0.8791 - val_accuracy: 0.5743 - val_auc: 0.5371
#
# Epoch 00049: saving model to History/model.epoch49.hdf5
# Epoch 50/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6837 - accuracy: 0.6756 - auc: 0.7327 - val_loss: 0.9480 - val_accuracy: 0.4950 - val_auc: 0.4401
#
# Epoch 00050: saving model to History/model.epoch50.hdf5
# Epoch 51/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.6344 - accuracy: 0.6965 - auc: 0.7665 - val_loss: 0.9352 - val_accuracy: 0.4950 - val_auc: 0.4380
#
# Epoch 00051: saving model to History/model.epoch51.hdf5
# Epoch 52/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.6870 - accuracy: 0.6525 - auc: 0.7211 - val_loss: 0.9036 - val_accuracy: 0.4950 - val_auc: 0.4662
#
# Epoch 00052: saving model to History/model.epoch52.hdf5
# Epoch 53/300
# 141/141 [==============================] - 26s 186ms/step - loss: 0.6652 - accuracy: 0.7057 - auc: 0.7639 - val_loss: 0.9810 - val_accuracy: 0.4653 - val_auc: 0.4368
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6424 - accuracy: 0.7228 - auc: 0.7828 - val_loss: 0.9271 - val_accuracy: 0.4257 - val_auc: 0.4317
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.6435 - accuracy: 0.7071 - auc: 0.7729 - val_loss: 0.8051 - val_accuracy: 0.5743 - val_auc: 0.6000
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6512 - accuracy: 0.7049 - auc: 0.7835 - val_loss: 0.9376 - val_accuracy: 0.5050 - val_auc: 0.4656
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6044 - accuracy: 0.7354 - auc: 0.8106 - val_loss: 0.9122 - val_accuracy: 0.4455 - val_auc: 0.4656
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6838 - accuracy: 0.6385 - auc: 0.7275 - val_loss: 0.9328 - val_accuracy: 0.4950 - val_auc: 0.4551
#
# Epoch 00058: saving model to History/model.epoch58.hdf5
# Epoch 59/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6705 - accuracy: 0.7015 - auc: 0.7396 - val_loss: 0.9118 - val_accuracy: 0.4851 - val_auc: 0.4748
#
# Epoch 00059: saving model to History/model.epoch59.hdf5
# Epoch 60/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.6515 - accuracy: 0.7048 - auc: 0.7655 - val_loss: 0.8519 - val_accuracy: 0.5149 - val_auc: 0.5715
#
# Epoch 00060: saving model to History/model.epoch60.hdf5
# Epoch 61/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6661 - accuracy: 0.6700 - auc: 0.7454 - val_loss: 0.9481 - val_accuracy: 0.4752 - val_auc: 0.4753
#
# Epoch 00061: saving model to History/model.epoch61.hdf5
# Epoch 62/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6346 - accuracy: 0.7284 - auc: 0.7776 - val_loss: 0.8869 - val_accuracy: 0.4950 - val_auc: 0.5014
#
# Epoch 00062: saving model to History/model.epoch62.hdf5
# Epoch 63/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6523 - accuracy: 0.6764 - auc: 0.7430 - val_loss: 0.8242 - val_accuracy: 0.5941 - val_auc: 0.6237
#
# Epoch 00063: saving model to History/model.epoch63.hdf5
# Epoch 64/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5991 - accuracy: 0.7300 - auc: 0.8175 - val_loss: 0.8481 - val_accuracy: 0.5842 - val_auc: 0.5815
#
# Epoch 00064: saving model to History/model.epoch64.hdf5
# Epoch 65/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.6414 - accuracy: 0.7355 - auc: 0.7841 - val_loss: 0.8140 - val_accuracy: 0.5842 - val_auc: 0.6395
#
# Epoch 00065: saving model to History/model.epoch65.hdf5
# Epoch 66/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.6098 - accuracy: 0.7425 - auc: 0.8162 - val_loss: 0.9263 - val_accuracy: 0.5446 - val_auc: 0.5365
#
# Epoch 00066: saving model to History/model.epoch66.hdf5
# Epoch 67/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.6768 - accuracy: 0.6910 - auc: 0.7500 - val_loss: 0.8126 - val_accuracy: 0.6238 - val_auc: 0.6643
#
# Epoch 00067: saving model to History/model.epoch67.hdf5
# Epoch 68/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.6305 - accuracy: 0.6998 - auc: 0.7955 - val_loss: 0.9109 - val_accuracy: 0.5248 - val_auc: 0.5290
#
# Epoch 00068: saving model to History/model.epoch68.hdf5
# Epoch 69/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6201 - accuracy: 0.7283 - auc: 0.7887 - val_loss: 0.8261 - val_accuracy: 0.5545 - val_auc: 0.5843
#
# Epoch 00069: saving model to History/model.epoch69.hdf5
# Epoch 70/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.6208 - accuracy: 0.7082 - auc: 0.8085 - val_loss: 0.8439 - val_accuracy: 0.5644 - val_auc: 0.6014
#
# Epoch 00070: saving model to History/model.epoch70.hdf5
# Epoch 71/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.5963 - accuracy: 0.7488 - auc: 0.8273 - val_loss: 0.9129 - val_accuracy: 0.4455 - val_auc: 0.4997
#
# Epoch 00071: saving model to History/model.epoch71.hdf5
# Epoch 72/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5974 - accuracy: 0.7517 - auc: 0.8194 - val_loss: 0.9271 - val_accuracy: 0.4950 - val_auc: 0.5037
#
# Epoch 00072: saving model to History/model.epoch72.hdf5
# Epoch 73/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.6108 - accuracy: 0.7034 - auc: 0.7872 - val_loss: 0.8678 - val_accuracy: 0.5644 - val_auc: 0.5567
#
# Epoch 00073: saving model to History/model.epoch73.hdf5
# Epoch 74/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6073 - accuracy: 0.7646 - auc: 0.8228 - val_loss: 0.8881 - val_accuracy: 0.5149 - val_auc: 0.5236
#
# Epoch 00074: saving model to History/model.epoch74.hdf5
# Epoch 75/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6255 - accuracy: 0.7247 - auc: 0.8031 - val_loss: 0.8680 - val_accuracy: 0.5446 - val_auc: 0.5695
#
# Epoch 00075: saving model to History/model.epoch75.hdf5
# Epoch 76/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5969 - accuracy: 0.7183 - auc: 0.8092 - val_loss: 0.9374 - val_accuracy: 0.5545 - val_auc: 0.5416
#
# Epoch 00076: saving model to History/model.epoch76.hdf5
# Epoch 77/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.6148 - accuracy: 0.7042 - auc: 0.7857 - val_loss: 1.0008 - val_accuracy: 0.4950 - val_auc: 0.4899
#
# Epoch 00077: saving model to History/model.epoch77.hdf5
# Epoch 78/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5674 - accuracy: 0.7707 - auc: 0.8476 - val_loss: 0.8005 - val_accuracy: 0.6238 - val_auc: 0.6446
#
# Epoch 00078: saving model to History/model.epoch78.hdf5
# Epoch 79/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.6179 - accuracy: 0.7309 - auc: 0.8083 - val_loss: 0.8518 - val_accuracy: 0.5545 - val_auc: 0.5975
#
# Epoch 00079: saving model to History/model.epoch79.hdf5
# Epoch 80/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5718 - accuracy: 0.7412 - auc: 0.8418 - val_loss: 0.9067 - val_accuracy: 0.4752 - val_auc: 0.5323
#
# Epoch 00080: saving model to History/model.epoch80.hdf5
# Epoch 81/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5571 - accuracy: 0.7656 - auc: 0.8474 - val_loss: 0.8782 - val_accuracy: 0.5248 - val_auc: 0.5694
#
# Epoch 00081: saving model to History/model.epoch81.hdf5
# Epoch 82/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5422 - accuracy: 0.7596 - auc: 0.8475 - val_loss: 0.8518 - val_accuracy: 0.5545 - val_auc: 0.6052
#
# Epoch 00082: saving model to History/model.epoch82.hdf5
# Epoch 83/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5485 - accuracy: 0.7643 - auc: 0.8467 - val_loss: 0.9483 - val_accuracy: 0.5149 - val_auc: 0.5191
#
# Epoch 00083: saving model to History/model.epoch83.hdf5
# Epoch 84/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5066 - accuracy: 0.8192 - auc: 0.8790 - val_loss: 0.8806 - val_accuracy: 0.5941 - val_auc: 0.5855
#
# Epoch 00084: saving model to History/model.epoch84.hdf5
# Epoch 85/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5223 - accuracy: 0.7932 - auc: 0.8745 - val_loss: 0.8177 - val_accuracy: 0.6436 - val_auc: 0.6762
#
# Epoch 00085: saving model to History/model.epoch85.hdf5
# Epoch 86/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5733 - accuracy: 0.7657 - auc: 0.8467 - val_loss: 0.8814 - val_accuracy: 0.5446 - val_auc: 0.5769
#
# Epoch 00086: saving model to History/model.epoch86.hdf5
# Epoch 87/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.5779 - accuracy: 0.7547 - auc: 0.8292 - val_loss: 0.8629 - val_accuracy: 0.5347 - val_auc: 0.5962
#
# Epoch 00087: saving model to History/model.epoch87.hdf5
# Epoch 88/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5881 - accuracy: 0.7396 - auc: 0.8057 - val_loss: 0.9968 - val_accuracy: 0.4554 - val_auc: 0.4937
#
# Epoch 00088: saving model to History/model.epoch88.hdf5
# Epoch 89/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5642 - accuracy: 0.7687 - auc: 0.8402 - val_loss: 1.0005 - val_accuracy: 0.4851 - val_auc: 0.4964
#
# Epoch 00089: saving model to History/model.epoch89.hdf5
# Epoch 90/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5424 - accuracy: 0.7716 - auc: 0.8484 - val_loss: 0.9180 - val_accuracy: 0.5545 - val_auc: 0.5833
#
# Epoch 00090: saving model to History/model.epoch90.hdf5
# Epoch 91/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5016 - accuracy: 0.8063 - auc: 0.8902 - val_loss: 0.9069 - val_accuracy: 0.5644 - val_auc: 0.5778
#
# Epoch 00091: saving model to History/model.epoch91.hdf5
# Epoch 92/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5453 - accuracy: 0.7726 - auc: 0.8502 - val_loss: 0.8980 - val_accuracy: 0.5941 - val_auc: 0.6165
#
# Epoch 00092: saving model to History/model.epoch92.hdf5
# Epoch 93/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5156 - accuracy: 0.8036 - auc: 0.8723 - val_loss: 0.9031 - val_accuracy: 0.5842 - val_auc: 0.5988
#
# Epoch 00093: saving model to History/model.epoch93.hdf5
# Epoch 94/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4956 - accuracy: 0.7907 - auc: 0.8851 - val_loss: 0.8606 - val_accuracy: 0.6040 - val_auc: 0.6516
#
# Epoch 00094: saving model to History/model.epoch94.hdf5
# Epoch 95/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.4929 - accuracy: 0.8136 - auc: 0.8902 - val_loss: 0.8610 - val_accuracy: 0.6139 - val_auc: 0.6459
#
# Epoch 00095: saving model to History/model.epoch95.hdf5
# Epoch 96/300
# 141/141 [==============================] - 28s 196ms/step - loss: 0.5389 - accuracy: 0.7965 - auc: 0.8544 - val_loss: 0.9671 - val_accuracy: 0.5743 - val_auc: 0.5517
#
# Epoch 00096: saving model to History/model.epoch96.hdf5
# Epoch 97/300
# 141/141 [==============================] - 29s 205ms/step - loss: 0.4766 - accuracy: 0.8224 - auc: 0.9026 - val_loss: 0.9154 - val_accuracy: 0.5842 - val_auc: 0.5864
#
# Epoch 00097: saving model to History/model.epoch97.hdf5
# Epoch 98/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.4822 - accuracy: 0.8059 - auc: 0.8886 - val_loss: 0.9051 - val_accuracy: 0.5743 - val_auc: 0.6133
#
# Epoch 00098: saving model to History/model.epoch98.hdf5
# Epoch 99/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.4974 - accuracy: 0.8173 - auc: 0.8937 - val_loss: 0.9563 - val_accuracy: 0.5248 - val_auc: 0.5500
#
# Epoch 00099: saving model to History/model.epoch99.hdf5
# Epoch 100/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4899 - accuracy: 0.7867 - auc: 0.8873 - val_loss: 0.8319 - val_accuracy: 0.5644 - val_auc: 0.6410
#
# Epoch 00100: saving model to History/model.epoch100.hdf5
# Epoch 101/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5443 - accuracy: 0.7869 - auc: 0.8570 - val_loss: 0.8951 - val_accuracy: 0.5545 - val_auc: 0.5821
#
# Epoch 00101: saving model to History/model.epoch101.hdf5
# Epoch 102/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.5181 - accuracy: 0.8020 - auc: 0.8757 - val_loss: 0.8626 - val_accuracy: 0.5743 - val_auc: 0.6360
#
# Epoch 00102: saving model to History/model.epoch102.hdf5
# Epoch 103/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5076 - accuracy: 0.7854 - auc: 0.8848 - val_loss: 0.8874 - val_accuracy: 0.5446 - val_auc: 0.5933
#
# Epoch 00103: saving model to History/model.epoch103.hdf5
# Epoch 104/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4984 - accuracy: 0.7973 - auc: 0.8814 - val_loss: 0.9396 - val_accuracy: 0.5743 - val_auc: 0.5645
#
# Epoch 00104: saving model to History/model.epoch104.hdf5
# Epoch 105/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5208 - accuracy: 0.7932 - auc: 0.8733 - val_loss: 0.8565 - val_accuracy: 0.6634 - val_auc: 0.6627
#
# Epoch 00105: saving model to History/model.epoch105.hdf5
# Epoch 106/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5185 - accuracy: 0.7943 - auc: 0.8770 - val_loss: 0.8387 - val_accuracy: 0.6436 - val_auc: 0.6690
#
# Epoch 00106: saving model to History/model.epoch106.hdf5
# Epoch 107/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4831 - accuracy: 0.8089 - auc: 0.8943 - val_loss: 0.8863 - val_accuracy: 0.6238 - val_auc: 0.6241
#
# Epoch 00107: saving model to History/model.epoch107.hdf5
# Epoch 108/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4490 - accuracy: 0.8166 - auc: 0.9152 - val_loss: 0.8646 - val_accuracy: 0.5941 - val_auc: 0.6363
#
# Epoch 00108: saving model to History/model.epoch108.hdf5
# Epoch 109/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.5120 - accuracy: 0.7921 - auc: 0.8798 - val_loss: 0.8162 - val_accuracy: 0.6535 - val_auc: 0.6872
#
# Epoch 00109: saving model to History/model.epoch109.hdf5
# Epoch 110/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4343 - accuracy: 0.8427 - auc: 0.9239 - val_loss: 0.8881 - val_accuracy: 0.5842 - val_auc: 0.6044
#
# Epoch 00110: saving model to History/model.epoch110.hdf5
# Epoch 111/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4578 - accuracy: 0.8366 - auc: 0.9052 - val_loss: 0.8562 - val_accuracy: 0.6139 - val_auc: 0.6428
#
# Epoch 00111: saving model to History/model.epoch111.hdf5
# Epoch 112/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.5129 - accuracy: 0.8278 - auc: 0.8800 - val_loss: 0.8266 - val_accuracy: 0.6337 - val_auc: 0.6761
#
# Epoch 00112: saving model to History/model.epoch112.hdf5
# Epoch 113/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4635 - accuracy: 0.8217 - auc: 0.9061 - val_loss: 0.9192 - val_accuracy: 0.5842 - val_auc: 0.5910
#
# Epoch 00113: saving model to History/model.epoch113.hdf5
# Epoch 114/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4570 - accuracy: 0.8315 - auc: 0.9125 - val_loss: 0.8444 - val_accuracy: 0.6238 - val_auc: 0.6732
#
# Epoch 00114: saving model to History/model.epoch114.hdf5
# Epoch 115/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.5451 - accuracy: 0.7861 - auc: 0.8661 - val_loss: 0.8608 - val_accuracy: 0.6238 - val_auc: 0.6370
#
# Epoch 00115: saving model to History/model.epoch115.hdf5
# Epoch 116/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4901 - accuracy: 0.7981 - auc: 0.8830 - val_loss: 0.9281 - val_accuracy: 0.5149 - val_auc: 0.5556
#
# Epoch 00116: saving model to History/model.epoch116.hdf5
# Epoch 117/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4638 - accuracy: 0.8270 - auc: 0.9045 - val_loss: 0.9057 - val_accuracy: 0.5743 - val_auc: 0.6170
#
# Epoch 00117: saving model to History/model.epoch117.hdf5
# Epoch 118/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4956 - accuracy: 0.7930 - auc: 0.8671 - val_loss: 0.9462 - val_accuracy: 0.5545 - val_auc: 0.5859
#
# Epoch 00118: saving model to History/model.epoch118.hdf5
# Epoch 119/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.4224 - accuracy: 0.8570 - auc: 0.9260 - val_loss: 0.9964 - val_accuracy: 0.5050 - val_auc: 0.5358
#
# Epoch 00119: saving model to History/model.epoch119.hdf5
# Epoch 120/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4170 - accuracy: 0.8343 - auc: 0.9260 - val_loss: 0.9069 - val_accuracy: 0.5941 - val_auc: 0.6221
#
# Epoch 00120: saving model to History/model.epoch120.hdf5
# Epoch 121/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4548 - accuracy: 0.8318 - auc: 0.9083 - val_loss: 0.8709 - val_accuracy: 0.6337 - val_auc: 0.6776
#
# Epoch 00121: saving model to History/model.epoch121.hdf5
# Epoch 122/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.4504 - accuracy: 0.8406 - auc: 0.9186 - val_loss: 0.9146 - val_accuracy: 0.5446 - val_auc: 0.6184
#
# Epoch 00122: saving model to History/model.epoch122.hdf5
# Epoch 123/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4730 - accuracy: 0.8213 - auc: 0.9003 - val_loss: 0.9086 - val_accuracy: 0.5446 - val_auc: 0.5961
#
# Epoch 00123: saving model to History/model.epoch123.hdf5
# Epoch 124/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4469 - accuracy: 0.8490 - auc: 0.9203 - val_loss: 1.0336 - val_accuracy: 0.4851 - val_auc: 0.5249
#
# Epoch 00124: saving model to History/model.epoch124.hdf5
# Epoch 125/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4214 - accuracy: 0.8389 - auc: 0.9200 - val_loss: 0.9033 - val_accuracy: 0.6733 - val_auc: 0.6859
#
# Epoch 00125: saving model to History/model.epoch125.hdf5
# Epoch 126/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4845 - accuracy: 0.8222 - auc: 0.9091 - val_loss: 0.9439 - val_accuracy: 0.5842 - val_auc: 0.6277
#
# Epoch 00126: saving model to History/model.epoch126.hdf5
# Epoch 127/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.3763 - accuracy: 0.8887 - auc: 0.9444 - val_loss: 0.9814 - val_accuracy: 0.6634 - val_auc: 0.6951
#
# Epoch 00127: saving model to History/model.epoch127.hdf5
# Epoch 128/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4425 - accuracy: 0.8582 - auc: 0.9225 - val_loss: 1.0120 - val_accuracy: 0.5347 - val_auc: 0.5785
#
# Epoch 00128: saving model to History/model.epoch128.hdf5
# Epoch 129/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4652 - accuracy: 0.8250 - auc: 0.9036 - val_loss: 0.9540 - val_accuracy: 0.5248 - val_auc: 0.5907
#
# Epoch 00129: saving model to History/model.epoch129.hdf5
# Epoch 130/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4219 - accuracy: 0.8151 - auc: 0.9255 - val_loss: 0.9350 - val_accuracy: 0.7030 - val_auc: 0.6936
#
# Epoch 00130: saving model to History/model.epoch130.hdf5
# Epoch 131/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.4366 - accuracy: 0.8424 - auc: 0.9231 - val_loss: 0.9452 - val_accuracy: 0.6238 - val_auc: 0.6542
#
# Epoch 00131: saving model to History/model.epoch131.hdf5
# Epoch 132/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4122 - accuracy: 0.8788 - auc: 0.9349 - val_loss: 0.9358 - val_accuracy: 0.6337 - val_auc: 0.6745
#
# Epoch 00132: saving model to History/model.epoch132.hdf5
# Epoch 133/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4103 - accuracy: 0.8875 - auc: 0.9359 - val_loss: 0.9971 - val_accuracy: 0.5545 - val_auc: 0.5929
#
# Epoch 00133: saving model to History/model.epoch133.hdf5
# Epoch 134/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4201 - accuracy: 0.8284 - auc: 0.9235 - val_loss: 1.0180 - val_accuracy: 0.5842 - val_auc: 0.5914
#
# Epoch 00134: saving model to History/model.epoch134.hdf5
# Epoch 135/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4191 - accuracy: 0.8777 - auc: 0.9299 - val_loss: 0.9464 - val_accuracy: 0.5644 - val_auc: 0.6202
#
# Epoch 00135: saving model to History/model.epoch135.hdf5
# Epoch 136/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4221 - accuracy: 0.8496 - auc: 0.9292 - val_loss: 1.2107 - val_accuracy: 0.4653 - val_auc: 0.5044
#
# Epoch 00136: saving model to History/model.epoch136.hdf5
# Epoch 137/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.4133 - accuracy: 0.8548 - auc: 0.9260 - val_loss: 0.9635 - val_accuracy: 0.6238 - val_auc: 0.6584
#
# Epoch 00137: saving model to History/model.epoch137.hdf5
# Epoch 138/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4358 - accuracy: 0.8505 - auc: 0.9207 - val_loss: 1.0079 - val_accuracy: 0.5743 - val_auc: 0.5930
#
# Epoch 00138: saving model to History/model.epoch138.hdf5
# Epoch 139/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4131 - accuracy: 0.8549 - auc: 0.9357 - val_loss: 0.9576 - val_accuracy: 0.6436 - val_auc: 0.6612
#
# Epoch 00139: saving model to History/model.epoch139.hdf5
# Epoch 140/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4339 - accuracy: 0.8597 - auc: 0.9295 - val_loss: 1.0487 - val_accuracy: 0.5050 - val_auc: 0.5350
#
# Epoch 00140: saving model to History/model.epoch140.hdf5
# Epoch 141/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.4228 - accuracy: 0.8342 - auc: 0.9176 - val_loss: 1.2005 - val_accuracy: 0.4554 - val_auc: 0.4757
#
# Epoch 00141: saving model to History/model.epoch141.hdf5
# Epoch 142/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4740 - accuracy: 0.7986 - auc: 0.8933 - val_loss: 1.0294 - val_accuracy: 0.5743 - val_auc: 0.6036
#
# Epoch 00142: saving model to History/model.epoch142.hdf5
# Epoch 143/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4257 - accuracy: 0.8417 - auc: 0.9233 - val_loss: 0.9842 - val_accuracy: 0.6238 - val_auc: 0.6484
#
# Epoch 00143: saving model to History/model.epoch143.hdf5
# Epoch 144/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3769 - accuracy: 0.8729 - auc: 0.9491 - val_loss: 1.0570 - val_accuracy: 0.5644 - val_auc: 0.5866
#
# Epoch 00144: saving model to History/model.epoch144.hdf5
# Epoch 145/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3658 - accuracy: 0.8891 - auc: 0.9466 - val_loss: 1.0816 - val_accuracy: 0.5446 - val_auc: 0.5770
#
# Epoch 00145: saving model to History/model.epoch145.hdf5
# Epoch 146/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4129 - accuracy: 0.8413 - auc: 0.9272 - val_loss: 1.0416 - val_accuracy: 0.6832 - val_auc: 0.7027
#
# Epoch 00146: saving model to History/model.epoch146.hdf5
# Epoch 147/300
# 141/141 [==============================] - 26s 186ms/step - loss: 0.4138 - accuracy: 0.8763 - auc: 0.9375 - val_loss: 1.0848 - val_accuracy: 0.5050 - val_auc: 0.5541
#
# Epoch 00147: saving model to History/model.epoch147.hdf5
# Epoch 148/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3708 - accuracy: 0.8771 - auc: 0.9489 - val_loss: 1.0038 - val_accuracy: 0.6535 - val_auc: 0.6909
#
# Epoch 00148: saving model to History/model.epoch148.hdf5
# Epoch 149/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3840 - accuracy: 0.8744 - auc: 0.9522 - val_loss: 1.0074 - val_accuracy: 0.5644 - val_auc: 0.6156
#
# Epoch 00149: saving model to History/model.epoch149.hdf5
# Epoch 150/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4084 - accuracy: 0.8689 - auc: 0.9369 - val_loss: 1.0429 - val_accuracy: 0.5545 - val_auc: 0.5906
#
# Epoch 00150: saving model to History/model.epoch150.hdf5
# Epoch 151/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3941 - accuracy: 0.8576 - auc: 0.9328 - val_loss: 1.0136 - val_accuracy: 0.5743 - val_auc: 0.5998
#
# Epoch 00151: saving model to History/model.epoch151.hdf5
# Epoch 152/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4006 - accuracy: 0.8721 - auc: 0.9274 - val_loss: 1.0737 - val_accuracy: 0.5743 - val_auc: 0.5801
#
# Epoch 00152: saving model to History/model.epoch152.hdf5
# Epoch 153/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3810 - accuracy: 0.8602 - auc: 0.9421 - val_loss: 1.0034 - val_accuracy: 0.6436 - val_auc: 0.6890
#
# Epoch 00153: saving model to History/model.epoch153.hdf5
# Epoch 154/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3815 - accuracy: 0.8659 - auc: 0.9460 - val_loss: 1.0150 - val_accuracy: 0.6634 - val_auc: 0.6747
#
# Epoch 00154: saving model to History/model.epoch154.hdf5
# Epoch 155/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3447 - accuracy: 0.9008 - auc: 0.9616 - val_loss: 1.0580 - val_accuracy: 0.6040 - val_auc: 0.6355
#
# Epoch 00155: saving model to History/model.epoch155.hdf5
# Epoch 156/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.3617 - accuracy: 0.8755 - auc: 0.9486 - val_loss: 1.0675 - val_accuracy: 0.5644 - val_auc: 0.5949
#
# Epoch 00156: saving model to History/model.epoch156.hdf5
# Epoch 157/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.4189 - accuracy: 0.8318 - auc: 0.9246 - val_loss: 1.0388 - val_accuracy: 0.6337 - val_auc: 0.6550
#
# Epoch 00157: saving model to History/model.epoch157.hdf5
# Epoch 158/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3764 - accuracy: 0.8830 - auc: 0.9456 - val_loss: 1.1113 - val_accuracy: 0.4950 - val_auc: 0.5541
#
# Epoch 00158: saving model to History/model.epoch158.hdf5
# Epoch 159/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3418 - accuracy: 0.8832 - auc: 0.9639 - val_loss: 1.1892 - val_accuracy: 0.5149 - val_auc: 0.5306
#
# Epoch 00159: saving model to History/model.epoch159.hdf5
# Epoch 160/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.4051 - accuracy: 0.8412 - auc: 0.9288 - val_loss: 1.0821 - val_accuracy: 0.6832 - val_auc: 0.6820
#
# Epoch 00160: saving model to History/model.epoch160.hdf5
# Epoch 161/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3494 - accuracy: 0.9002 - auc: 0.9627 - val_loss: 1.0606 - val_accuracy: 0.5545 - val_auc: 0.6070
#
# Epoch 00161: saving model to History/model.epoch161.hdf5
# Epoch 162/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3475 - accuracy: 0.8973 - auc: 0.9576 - val_loss: 1.0437 - val_accuracy: 0.6931 - val_auc: 0.6762
#
# Epoch 00162: saving model to History/model.epoch162.hdf5
# Epoch 163/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3625 - accuracy: 0.8939 - auc: 0.9524 - val_loss: 1.0480 - val_accuracy: 0.6436 - val_auc: 0.6676
#
# Epoch 00163: saving model to History/model.epoch163.hdf5
# Epoch 164/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.4191 - accuracy: 0.8595 - auc: 0.9413 - val_loss: 1.1927 - val_accuracy: 0.4851 - val_auc: 0.5157
#
# Epoch 00164: saving model to History/model.epoch164.hdf5
# Epoch 165/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3728 - accuracy: 0.8730 - auc: 0.9443 - val_loss: 1.0952 - val_accuracy: 0.5644 - val_auc: 0.6071
#
# Epoch 00165: saving model to History/model.epoch165.hdf5
# Epoch 166/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3693 - accuracy: 0.8731 - auc: 0.9520 - val_loss: 1.0170 - val_accuracy: 0.6634 - val_auc: 0.6693
#
# Epoch 00166: saving model to History/model.epoch166.hdf5
# Epoch 167/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3594 - accuracy: 0.9126 - auc: 0.9555 - val_loss: 1.0384 - val_accuracy: 0.5644 - val_auc: 0.6080
#
# Epoch 00167: saving model to History/model.epoch167.hdf5
# Epoch 168/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3739 - accuracy: 0.8731 - auc: 0.9442 - val_loss: 1.0543 - val_accuracy: 0.5545 - val_auc: 0.6298
#
# Epoch 00168: saving model to History/model.epoch168.hdf5
# Epoch 169/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3200 - accuracy: 0.9179 - auc: 0.9689 - val_loss: 1.0586 - val_accuracy: 0.6535 - val_auc: 0.6701
#
# Epoch 00169: saving model to History/model.epoch169.hdf5
# Epoch 170/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3522 - accuracy: 0.8799 - auc: 0.9549 - val_loss: 1.0636 - val_accuracy: 0.6634 - val_auc: 0.6767
#
# Epoch 00170: saving model to History/model.epoch170.hdf5
# Epoch 171/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3441 - accuracy: 0.8895 - auc: 0.9604 - val_loss: 1.0813 - val_accuracy: 0.6535 - val_auc: 0.6725
#
# Epoch 00171: saving model to History/model.epoch171.hdf5
# Epoch 172/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3779 - accuracy: 0.8798 - auc: 0.9487 - val_loss: 1.1036 - val_accuracy: 0.5644 - val_auc: 0.5977
#
# Epoch 00172: saving model to History/model.epoch172.hdf5
# Epoch 173/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3555 - accuracy: 0.8674 - auc: 0.9550 - val_loss: 1.0422 - val_accuracy: 0.5446 - val_auc: 0.6065
#
# Epoch 00173: saving model to History/model.epoch173.hdf5
# Epoch 174/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.3359 - accuracy: 0.8860 - auc: 0.9571 - val_loss: 1.0321 - val_accuracy: 0.6337 - val_auc: 0.6665
#
# Epoch 00174: saving model to History/model.epoch174.hdf5
# Epoch 175/300
# 141/141 [==============================] - 27s 194ms/step - loss: 0.3008 - accuracy: 0.9308 - auc: 0.9800 - val_loss: 1.0777 - val_accuracy: 0.5545 - val_auc: 0.6284
#
# Epoch 00175: saving model to History/model.epoch175.hdf5
# Epoch 176/300
# 141/141 [==============================] - 28s 200ms/step - loss: 0.3570 - accuracy: 0.8779 - auc: 0.9477 - val_loss: 1.0550 - val_accuracy: 0.6238 - val_auc: 0.6671
#
# Epoch 00176: saving model to History/model.epoch176.hdf5
# Epoch 177/300
# 141/141 [==============================] - 27s 194ms/step - loss: 0.3016 - accuracy: 0.9017 - auc: 0.9691 - val_loss: 1.0778 - val_accuracy: 0.6634 - val_auc: 0.6895
#
# Epoch 00177: saving model to History/model.epoch177.hdf5
# Epoch 178/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3478 - accuracy: 0.8971 - auc: 0.9581 - val_loss: 1.0846 - val_accuracy: 0.6238 - val_auc: 0.6471
#
# Epoch 00178: saving model to History/model.epoch178.hdf5
# Epoch 179/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3566 - accuracy: 0.8719 - auc: 0.9477 - val_loss: 1.1095 - val_accuracy: 0.6535 - val_auc: 0.6657
#
# Epoch 00179: saving model to History/model.epoch179.hdf5
# Epoch 180/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3053 - accuracy: 0.9049 - auc: 0.9708 - val_loss: 1.0630 - val_accuracy: 0.6040 - val_auc: 0.6523
#
# Epoch 00180: saving model to History/model.epoch180.hdf5
# Epoch 181/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3154 - accuracy: 0.8945 - auc: 0.9649 - val_loss: 1.1753 - val_accuracy: 0.6733 - val_auc: 0.6867
#
# Epoch 00181: saving model to History/model.epoch181.hdf5
# Epoch 182/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3443 - accuracy: 0.8916 - auc: 0.9601 - val_loss: 1.1285 - val_accuracy: 0.6337 - val_auc: 0.6596
#
# Epoch 00182: saving model to History/model.epoch182.hdf5
# Epoch 183/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3216 - accuracy: 0.8972 - auc: 0.9659 - val_loss: 1.0819 - val_accuracy: 0.6238 - val_auc: 0.6678
#
# Epoch 00183: saving model to History/model.epoch183.hdf5
# Epoch 184/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.3144 - accuracy: 0.9120 - auc: 0.9642 - val_loss: 1.1495 - val_accuracy: 0.6238 - val_auc: 0.6702
#
# Epoch 00184: saving model to History/model.epoch184.hdf5
# Epoch 185/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.3212 - accuracy: 0.9072 - auc: 0.9674 - val_loss: 1.1675 - val_accuracy: 0.6634 - val_auc: 0.6806
#
# Epoch 00185: saving model to History/model.epoch185.hdf5
# Epoch 186/300
# 141/141 [==============================] - 35s 245ms/step - loss: 0.2786 - accuracy: 0.9256 - auc: 0.9794 - val_loss: 1.1011 - val_accuracy: 0.6337 - val_auc: 0.6538
#
# Epoch 00186: saving model to History/model.epoch186.hdf5
# Epoch 187/300
# 141/141 [==============================] - 36s 254ms/step - loss: 0.3527 - accuracy: 0.8876 - auc: 0.9539 - val_loss: 1.0969 - val_accuracy: 0.6040 - val_auc: 0.6270
#
# Epoch 00187: saving model to History/model.epoch187.hdf5
# Epoch 188/300
# 141/141 [==============================] - 37s 265ms/step - loss: 0.3023 - accuracy: 0.9140 - auc: 0.9746 - val_loss: 1.1177 - val_accuracy: 0.6139 - val_auc: 0.6342
#
# Epoch 00188: saving model to History/model.epoch188.hdf5
# Epoch 189/300
# 141/141 [==============================] - 38s 271ms/step - loss: 0.3237 - accuracy: 0.8915 - auc: 0.9675 - val_loss: 1.1812 - val_accuracy: 0.6139 - val_auc: 0.6432
#
# Epoch 00189: saving model to History/model.epoch189.hdf5
# Epoch 190/300
# 141/141 [==============================] - 35s 251ms/step - loss: 0.3038 - accuracy: 0.9152 - auc: 0.9724 - val_loss: 1.2051 - val_accuracy: 0.5446 - val_auc: 0.6052
#
# Epoch 00190: saving model to History/model.epoch190.hdf5
# Epoch 191/300
# 141/141 [==============================] - 38s 271ms/step - loss: 0.3175 - accuracy: 0.8930 - auc: 0.9615 - val_loss: 1.1322 - val_accuracy: 0.6634 - val_auc: 0.6667
#
# Epoch 00191: saving model to History/model.epoch191.hdf5
# Epoch 192/300
# 141/141 [==============================] - 37s 263ms/step - loss: 0.2715 - accuracy: 0.9189 - auc: 0.9787 - val_loss: 1.1069 - val_accuracy: 0.6040 - val_auc: 0.6453
#
# Epoch 00192: saving model to History/model.epoch192.hdf5
# Epoch 193/300
# 141/141 [==============================] - 34s 239ms/step - loss: 0.2894 - accuracy: 0.9149 - auc: 0.9727 - val_loss: 1.1372 - val_accuracy: 0.5941 - val_auc: 0.6547
#
# Epoch 00193: saving model to History/model.epoch193.hdf5
# Epoch 194/300
# 141/141 [==============================] - 30s 214ms/step - loss: 0.2832 - accuracy: 0.9188 - auc: 0.9772 - val_loss: 1.1205 - val_accuracy: 0.6733 - val_auc: 0.6823
#
# Epoch 00194: saving model to History/model.epoch194.hdf5
# Epoch 195/300
# 141/141 [==============================] - 29s 207ms/step - loss: 0.2962 - accuracy: 0.9063 - auc: 0.9750 - val_loss: 1.1501 - val_accuracy: 0.6337 - val_auc: 0.6599
#
# Epoch 00195: saving model to History/model.epoch195.hdf5
# Epoch 196/300
# 141/141 [==============================] - 29s 209ms/step - loss: 0.3331 - accuracy: 0.9010 - auc: 0.9598 - val_loss: 1.1105 - val_accuracy: 0.6436 - val_auc: 0.6756
#
# Epoch 00196: saving model to History/model.epoch196.hdf5
# Epoch 197/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3010 - accuracy: 0.9155 - auc: 0.9726 - val_loss: 1.1154 - val_accuracy: 0.6733 - val_auc: 0.6905
#
# Epoch 00197: saving model to History/model.epoch197.hdf5
# Epoch 198/300
# 141/141 [==============================] - 28s 198ms/step - loss: 0.2620 - accuracy: 0.9266 - auc: 0.9842 - val_loss: 1.1817 - val_accuracy: 0.5545 - val_auc: 0.6098
#
# Epoch 00198: saving model to History/model.epoch198.hdf5
# Epoch 199/300
# 141/141 [==============================] - 31s 218ms/step - loss: 0.3030 - accuracy: 0.9166 - auc: 0.9650 - val_loss: 1.1772 - val_accuracy: 0.6238 - val_auc: 0.6605
#
# Epoch 00199: saving model to History/model.epoch199.hdf5
# Epoch 200/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2717 - accuracy: 0.9128 - auc: 0.9769 - val_loss: 1.1925 - val_accuracy: 0.5743 - val_auc: 0.6359
#
# Epoch 00200: saving model to History/model.epoch200.hdf5
# Epoch 201/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.2689 - accuracy: 0.9222 - auc: 0.9758 - val_loss: 1.1738 - val_accuracy: 0.5941 - val_auc: 0.6250
#
# Epoch 00201: saving model to History/model.epoch201.hdf5
# Epoch 202/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.2682 - accuracy: 0.9352 - auc: 0.9819 - val_loss: 1.1489 - val_accuracy: 0.5743 - val_auc: 0.6294
#
# Epoch 00202: saving model to History/model.epoch202.hdf5
# Epoch 203/300
# ...
# Epoch 234/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2542 - accuracy: 0.9297 - auc: 0.9838 - val_loss: 1.2403 - val_accuracy: 0.6238 - val_auc: 0.6788
#
# Epoch 00234: saving model to History/model.epoch234.hdf5
# Epoch 235/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.2550 - accuracy: 0.9446 - auc: 0.9826 - val_loss: 1.2143 - val_accuracy: 0.5842 - val_auc: 0.6291
#
# Epoch 00235: saving model to History/model.epoch235.hdf5
# Epoch 236/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2486 - accuracy: 0.9341 - auc: 0.9849 - val_loss: 1.2179 - val_accuracy: 0.6535 - val_auc: 0.6927
#
# Epoch 00236: saving model to History/model.epoch236.hdf5
# Epoch 237/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2599 - accuracy: 0.9355 - auc: 0.9815 - val_loss: 1.1606 - val_accuracy: 0.6535 - val_auc: 0.7096
#
# Epoch 00237: saving model to History/model.epoch237.hdf5
# Epoch 238/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2719 - accuracy: 0.9155 - auc: 0.9797 - val_loss: 1.1511 - val_accuracy: 0.6436 - val_auc: 0.6946
#
# Epoch 00238: saving model to History/model.epoch238.hdf5
# Epoch 239/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2408 - accuracy: 0.9351 - auc: 0.9864 - val_loss: 1.2143 - val_accuracy: 0.6040 - val_auc: 0.6683
#
# Epoch 00239: saving model to History/model.epoch239.hdf5
# Epoch 240/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.3096 - accuracy: 0.8961 - auc: 0.9655 - val_loss: 1.1950 - val_accuracy: 0.6337 - val_auc: 0.6826
#
# Epoch 00240: saving model to History/model.epoch240.hdf5
# Epoch 241/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.2399 - accuracy: 0.9357 - auc: 0.9853 - val_loss: 1.3141 - val_accuracy: 0.6139 - val_auc: 0.6628
#
# Epoch 00241: saving model to History/model.epoch241.hdf5
# Epoch 242/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2315 - accuracy: 0.9509 - auc: 0.9874 - val_loss: 1.2281 - val_accuracy: 0.5842 - val_auc: 0.6410
#
# Epoch 00242: saving model to History/model.epoch242.hdf5
# Epoch 243/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.2582 - accuracy: 0.9352 - auc: 0.9837 - val_loss: 1.1966 - val_accuracy: 0.5842 - val_auc: 0.6455
#
# Epoch 00243: saving model to History/model.epoch243.hdf5
# Epoch 244/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2354 - accuracy: 0.9420 - auc: 0.9872 - val_loss: 1.2529 - val_accuracy: 0.6634 - val_auc: 0.6816
#
# Epoch 00244: saving model to History/model.epoch244.hdf5
# Epoch 245/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2205 - accuracy: 0.9472 - auc: 0.9879 - val_loss: 1.2519 - val_accuracy: 0.6238 - val_auc: 0.6851
#
# Epoch 00245: saving model to History/model.epoch245.hdf5
# Epoch 246/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.3061 - accuracy: 0.9041 - auc: 0.9641 - val_loss: 1.3047 - val_accuracy: 0.6634 - val_auc: 0.7049
#
# Epoch 00246: saving model to History/model.epoch246.hdf5
# Epoch 247/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2380 - accuracy: 0.9437 - auc: 0.9856 - val_loss: 1.2126 - val_accuracy: 0.6733 - val_auc: 0.6981
#
# Epoch 00247: saving model to History/model.epoch247.hdf5
# Epoch 248/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2388 - accuracy: 0.9451 - auc: 0.9864 - val_loss: 1.2699 - val_accuracy: 0.6238 - val_auc: 0.6798
#
# Epoch 00248: saving model to History/model.epoch248.hdf5
# Epoch 249/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2378 - accuracy: 0.9593 - auc: 0.9840 - val_loss: 1.2521 - val_accuracy: 0.6040 - val_auc: 0.6522
#
# Epoch 00249: saving model to History/model.epoch249.hdf5
# Epoch 250/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2629 - accuracy: 0.9488 - auc: 0.9812 - val_loss: 1.2717 - val_accuracy: 0.6337 - val_auc: 0.6859
#
# Epoch 00250: saving model to History/model.epoch250.hdf5
# Epoch 251/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.2440 - accuracy: 0.9417 - auc: 0.9861 - val_loss: 1.2324 - val_accuracy: 0.6436 - val_auc: 0.6921
#
# Epoch 00251: saving model to History/model.epoch251.hdf5
# Epoch 252/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.2470 - accuracy: 0.9423 - auc: 0.9826 - val_loss: 1.3096 - val_accuracy: 0.6139 - val_auc: 0.6776
#
# Epoch 00252: saving model to History/model.epoch252.hdf5
# Epoch 253/300
# 141/141 [==============================] - 27s 193ms/step - loss: 0.2064 - accuracy: 0.9641 - auc: 0.9908 - val_loss: 1.2963 - val_accuracy: 0.6238 - val_auc: 0.6829
#
# Epoch 00253: saving model to History/model.epoch253.hdf5
# Epoch 254/300
# 141/141 [==============================] - 31s 220ms/step - loss: 0.2428 - accuracy: 0.9139 - auc: 0.9839 - val_loss: 1.2594 - val_accuracy: 0.6139 - val_auc: 0.6769
#
# Epoch 00254: saving model to History/model.epoch254.hdf5
# Epoch 255/300
# 141/141 [==============================] - 34s 243ms/step - loss: 0.2239 - accuracy: 0.9450 - auc: 0.9892 - val_loss: 1.3752 - val_accuracy: 0.6733 - val_auc: 0.7032
#
# Epoch 00255: saving model to History/model.epoch255.hdf5
# Epoch 256/300
# 141/141 [==============================] - 28s 196ms/step - loss: 0.2435 - accuracy: 0.9402 - auc: 0.9879 - val_loss: 1.2960 - val_accuracy: 0.6139 - val_auc: 0.6682
#
# Epoch 00256: saving model to History/model.epoch256.hdf5
# Epoch 257/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2402 - accuracy: 0.9527 - auc: 0.9818 - val_loss: 1.4368 - val_accuracy: 0.6931 - val_auc: 0.6939
#
# Epoch 00257: saving model to History/model.epoch257.hdf5
# Epoch 258/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2420 - accuracy: 0.9329 - auc: 0.9878 - val_loss: 1.4835 - val_accuracy: 0.6832 - val_auc: 0.7065
#
# Epoch 00258: saving model to History/model.epoch258.hdf5
# Epoch 259/300
# 141/141 [==============================] - 33s 237ms/step - loss: 0.2120 - accuracy: 0.9543 - auc: 0.9911 - val_loss: 1.3218 - val_accuracy: 0.6436 - val_auc: 0.6640
#
# Epoch 00259: saving model to History/model.epoch259.hdf5
# Epoch 260/300
# 141/141 [==============================] - 39s 280ms/step - loss: 0.2500 - accuracy: 0.9418 - auc: 0.9765 - val_loss: 1.3328 - val_accuracy: 0.5941 - val_auc: 0.6601
#
# Epoch 00260: saving model to History/model.epoch260.hdf5
# Epoch 261/300
# 141/141 [==============================] - 38s 267ms/step - loss: 0.2170 - accuracy: 0.9553 - auc: 0.9907 - val_loss: 1.3594 - val_accuracy: 0.6634 - val_auc: 0.6980
#
# Epoch 00261: saving model to History/model.epoch261.hdf5
# Epoch 262/300
# 141/141 [==============================] - 38s 270ms/step - loss: 0.2224 - accuracy: 0.9559 - auc: 0.9881 - val_loss: 1.2974 - val_accuracy: 0.6238 - val_auc: 0.6802
#
# Epoch 00262: saving model to History/model.epoch262.hdf5
# Epoch 263/300
# 141/141 [==============================] - 38s 266ms/step - loss: 0.2139 - accuracy: 0.9475 - auc: 0.9915 - val_loss: 1.3701 - val_accuracy: 0.5446 - val_auc: 0.6120
#
# Epoch 00263: saving model to History/model.epoch263.hdf5
# Epoch 264/300
# 141/141 [==============================] - 38s 270ms/step - loss: 0.2394 - accuracy: 0.9380 - auc: 0.9836 - val_loss: 1.3503 - val_accuracy: 0.6040 - val_auc: 0.6604
#
# Epoch 00264: saving model to History/model.epoch264.hdf5
# Epoch 265/300
# 141/141 [==============================] - 38s 271ms/step - loss: 0.2073 - accuracy: 0.9579 - auc: 0.9907 - val_loss: 1.3125 - val_accuracy: 0.6535 - val_auc: 0.6957
#
# Epoch 00265: saving model to History/model.epoch265.hdf5
# Epoch 266/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2430 - accuracy: 0.9320 - auc: 0.9848 - val_loss: 1.3517 - val_accuracy: 0.6238 - val_auc: 0.6721
#
# Epoch 00266: saving model to History/model.epoch266.hdf5
# Epoch 267/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2549 - accuracy: 0.9336 - auc: 0.9810 - val_loss: 1.4256 - val_accuracy: 0.6436 - val_auc: 0.6911
#
# Epoch 00267: saving model to History/model.epoch267.hdf5
# Epoch 268/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.2231 - accuracy: 0.9425 - auc: 0.9898 - val_loss: 1.5638 - val_accuracy: 0.6832 - val_auc: 0.6966
#
# Epoch 00268: saving model to History/model.epoch268.hdf5
# Epoch 269/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.2119 - accuracy: 0.9504 - auc: 0.9896 - val_loss: 1.4275 - val_accuracy: 0.6436 - val_auc: 0.6969
#
# Epoch 00269: saving model to History/model.epoch269.hdf5
# Epoch 270/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2472 - accuracy: 0.9282 - auc: 0.9816 - val_loss: 1.3398 - val_accuracy: 0.5743 - val_auc: 0.6569
#
# Epoch 00270: saving model to History/model.epoch270.hdf5
# Epoch 271/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2246 - accuracy: 0.9296 - auc: 0.9819 - val_loss: 1.4604 - val_accuracy: 0.6634 - val_auc: 0.7103
#
# Epoch 00271: saving model to History/model.epoch271.hdf5
# Epoch 272/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2141 - accuracy: 0.9515 - auc: 0.9923 - val_loss: 1.4473 - val_accuracy: 0.6337 - val_auc: 0.7109
#
# Epoch 00272: saving model to History/model.epoch272.hdf5
# Epoch 273/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.2278 - accuracy: 0.9477 - auc: 0.9874 - val_loss: 1.4880 - val_accuracy: 0.6139 - val_auc: 0.6397
#
# Epoch 00273: saving model to History/model.epoch273.hdf5
# Epoch 274/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2241 - accuracy: 0.9497 - auc: 0.9874 - val_loss: 1.3137 - val_accuracy: 0.6238 - val_auc: 0.6839
#
# Epoch 00274: saving model to History/model.epoch274.hdf5
# Epoch 275/300
# 141/141 [==============================] - 26s 186ms/step - loss: 0.2466 - accuracy: 0.9480 - auc: 0.9824 - val_loss: 1.3647 - val_accuracy: 0.6040 - val_auc: 0.6381
#
# Epoch 00275: saving model to History/model.epoch275.hdf5
# Epoch 276/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2404 - accuracy: 0.9390 - auc: 0.9830 - val_loss: 1.4623 - val_accuracy: 0.6139 - val_auc: 0.6710
#
# Epoch 00276: saving model to History/model.epoch276.hdf5
# Epoch 277/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.1980 - accuracy: 0.9656 - auc: 0.9948 - val_loss: 1.4558 - val_accuracy: 0.6337 - val_auc: 0.6747
#
# Epoch 00277: saving model to History/model.epoch277.hdf5
# Epoch 278/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2076 - accuracy: 0.9354 - auc: 0.9893 - val_loss: 1.5467 - val_accuracy: 0.6436 - val_auc: 0.6799
#
# Epoch 00278: saving model to History/model.epoch278.hdf5
# Epoch 279/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2082 - accuracy: 0.9553 - auc: 0.9897 - val_loss: 1.4557 - val_accuracy: 0.6139 - val_auc: 0.6503
#
# Epoch 00279: saving model to History/model.epoch279.hdf5
# Epoch 280/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.1810 - accuracy: 0.9658 - auc: 0.9956 - val_loss: 1.4554 - val_accuracy: 0.5644 - val_auc: 0.6244
#
# Epoch 00280: saving model to History/model.epoch280.hdf5
# Epoch 281/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.2193 - accuracy: 0.9425 - auc: 0.9887 - val_loss: 1.5150 - val_accuracy: 0.5743 - val_auc: 0.6291
#
# Epoch 00281: saving model to History/model.epoch281.hdf5
# Epoch 282/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.2097 - accuracy: 0.9586 - auc: 0.9915 - val_loss: 1.4442 - val_accuracy: 0.5941 - val_auc: 0.6605
#
# Epoch 00282: saving model to History/model.epoch282.hdf5
# Epoch 283/300
# 141/141 [==============================] - 27s 190ms/step - loss: 0.1894 - accuracy: 0.9621 - auc: 0.9945 - val_loss: 1.4681 - val_accuracy: 0.6040 - val_auc: 0.6503
#
# Epoch 00283: saving model to History/model.epoch283.hdf5
# Epoch 284/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.1698 - accuracy: 0.9765 - auc: 0.9955 - val_loss: 1.4573 - val_accuracy: 0.5545 - val_auc: 0.6269
#
# Epoch 00284: saving model to History/model.epoch284.hdf5
# Epoch 285/300
# 141/141 [==============================] - 27s 191ms/step - loss: 0.1808 - accuracy: 0.9719 - auc: 0.9946 - val_loss: 1.4908 - val_accuracy: 0.6139 - val_auc: 0.6701
#
# Epoch 00285: saving model to History/model.epoch285.hdf5
# Epoch 286/300
# 141/141 [==============================] - 26s 188ms/step - loss: 0.2326 - accuracy: 0.9443 - auc: 0.9873 - val_loss: 1.4576 - val_accuracy: 0.5347 - val_auc: 0.6086
#
# Epoch 00286: saving model to History/model.epoch286.hdf5
# Epoch 287/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.1969 - accuracy: 0.9570 - auc: 0.9909 - val_loss: 1.4823 - val_accuracy: 0.6040 - val_auc: 0.6432
#
# Epoch 00287: saving model to History/model.epoch287.hdf5
# Epoch 288/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.2057 - accuracy: 0.9584 - auc: 0.9898 - val_loss: 1.5261 - val_accuracy: 0.6535 - val_auc: 0.6900
#
# Epoch 00288: saving model to History/model.epoch288.hdf5
# Epoch 289/300
# 141/141 [==============================] - 28s 198ms/step - loss: 0.1835 - accuracy: 0.9747 - auc: 0.9942 - val_loss: 1.4686 - val_accuracy: 0.6337 - val_auc: 0.6786
#
# Epoch 00289: saving model to History/model.epoch289.hdf5
# Epoch 290/300
# 141/141 [==============================] - 28s 197ms/step - loss: 0.1794 - accuracy: 0.9718 - auc: 0.9950 - val_loss: 1.4745 - val_accuracy: 0.6139 - val_auc: 0.6600
#
# Epoch 00290: saving model to History/model.epoch290.hdf5
# Epoch 291/300
# 141/141 [==============================] - 30s 214ms/step - loss: 0.2203 - accuracy: 0.9458 - auc: 0.9863 - val_loss: 1.5012 - val_accuracy: 0.6238 - val_auc: 0.6768
#
# Epoch 00291: saving model to History/model.epoch291.hdf5
# Epoch 292/300
# 141/141 [==============================] - 28s 198ms/step - loss: 0.2149 - accuracy: 0.9459 - auc: 0.9901 - val_loss: 1.5123 - val_accuracy: 0.5842 - val_auc: 0.6443
#
# Epoch 00292: saving model to History/model.epoch292.hdf5
# Epoch 293/300
# 141/141 [==============================] - 29s 209ms/step - loss: 0.2053 - accuracy: 0.9619 - auc: 0.9897 - val_loss: 1.5498 - val_accuracy: 0.6535 - val_auc: 0.6793
#
# Epoch 00293: saving model to History/model.epoch293.hdf5
# Epoch 294/300
# 141/141 [==============================] - 30s 211ms/step - loss: 0.2078 - accuracy: 0.9496 - auc: 0.9912 - val_loss: 1.5019 - val_accuracy: 0.6634 - val_auc: 0.6757
#
# Epoch 00294: saving model to History/model.epoch294.hdf5
# Epoch 295/300
# 141/141 [==============================] - 27s 189ms/step - loss: 0.1779 - accuracy: 0.9670 - auc: 0.9959 - val_loss: 1.7210 - val_accuracy: 0.7129 - val_auc: 0.7107
#
# Epoch 00295: saving model to History/model.epoch295.hdf5
# Epoch 296/300
# 141/141 [==============================] - 29s 208ms/step - loss: 0.1792 - accuracy: 0.9702 - auc: 0.9945 - val_loss: 1.4461 - val_accuracy: 0.5842 - val_auc: 0.6579
#
# Epoch 00296: saving model to History/model.epoch296.hdf5
# Epoch 297/300
# 141/141 [==============================] - 32s 224ms/step - loss: 0.1755 - accuracy: 0.9719 - auc: 0.9960 - val_loss: 1.5379 - val_accuracy: 0.6040 - val_auc: 0.6570
#
# Epoch 00297: saving model to History/model.epoch297.hdf5
# Epoch 298/300
# 141/141 [==============================] - 27s 192ms/step - loss: 0.2018 - accuracy: 0.9479 - auc: 0.9916 - val_loss: 1.4613 - val_accuracy: 0.5941 - val_auc: 0.6585
#
# Epoch 00298: saving model to History/model.epoch298.hdf5
# Epoch 299/300
# 141/141 [==============================] - 26s 187ms/step - loss: 0.2014 - accuracy: 0.9458 - auc: 0.9937 - val_loss: 1.4379 - val_accuracy: 0.6040 - val_auc: 0.6697
#
# Epoch 00299: saving model to History/model.epoch299.hdf5
# Epoch 300/300
# 141/141 [==============================] - 27s 188ms/step - loss: 0.2078 - accuracy: 0.9479 - auc: 0.9881 - val_loss: 1.5027 - val_accuracy: 0.6733 - val_auc: 0.7002
#
# Epoch 00300: saving model to History/model.epoch300.hdf5

# %%
dat = pd.read_csv('results.csv', index_col='epoch')

fig, ax = plt.subplots(3, 1, figsize=(7,14))
metrics = ['accuracy', 'loss', 'auc']

for i, metric in enumerate(metrics):
    ax[i].plot(dat[metric])
    ax[i].plot(dat['val_'+metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])
    
    if metric == 'accuracy' or metric == 'auc':
        ax[i].set_ylim(0,1)
        
    else:
        ax[i].set_ylim(0)
    
fig.tight_layout()
plt.show()

p = 'softmax'+str(IMAGE_DIMENSION)
fig.savefig(p)

# %% [markdown]
# #### Prediction on test data

# %%
best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
print(best_model)
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
model.load_weights('History/model.epoch200.hdf5')

y_prob = model.predict(X_test, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_test = Y_test.argmax(axis = 1)
# Out:
# 77

# %%
auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_test,
    y_scores=y_prob[:,1])

cm = confusion_matrix(y_test, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

print("Accuracy: ", round((np.mean(y_pred == y_test)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_test, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_test, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  57.43  CI: [0.477 0.666]
# AUC:  0.557 CI: [0.433 0.682]
# Confusion matrix:
#  [[12 19]
#  [24 46]]
# Normalized Confusion matrix:
#  [[0.387 0.613]
#  [0.343 0.657]]

# %% [markdown]
# #### Prediction on training data

# %%
best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
print(best_model)
#best_model = np.where(dat.val_auc == np.max(dat.val_auc))[0][0]
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
#model.load_weights('History/model.epoch' + str(best_model) + '.hdf5')

y_prob = model.predict(X_train, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_train = Y_train.argmax(axis = 1)
# Out:
# 1

# %%
cm = confusion_matrix(y_train, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_train,
    y_scores=y_prob[:,1])

print("Accuracy: ", round((np.mean(y_pred == y_train)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_train, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_train, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  78.62  CI: [0.744 0.823]
# AUC:  0.957 CI: [0.94  0.975]
# Confusion matrix:
#  [[123   3]
#  [ 84 197]]
# Normalized Confusion matrix:
#  [[0.976 0.024]
#  [0.299 0.701]]

# %% [markdown]
# #### Prediction on balanced test data

# %%
bool_test_labels = Y_test[:,1] != 0
pos_features_test = X_test[bool_test_labels]
neg_features_test = X_test[~bool_test_labels]
pos_labels_test = Y_test[bool_test_labels]
neg_labels_test = Y_test[~bool_test_labels]

ids = np.arange(len(neg_features_test))
choices = np.random.choice(ids, len(pos_features_test))
res_neg_features = neg_features_test[choices]
res_neg_labels = neg_labels_test[choices]

resampled_features = np.concatenate([res_neg_features, pos_features_test], axis=0)
resampled_labels = np.concatenate([res_neg_labels, pos_labels_test], axis=0)

order = np.arange(len(resampled_labels))
np.random.shuffle(order)
X_test_balanced = resampled_features[order]
Y_test_balanced  = resampled_labels[order]

# %%
best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
print(best_model)
#best_model = np.where(dat.val_auc == np.max(dat.val_auc))[0][0]
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
#model.load_weights('History/model.epoch' + str(best_model) + '.hdf5')

y_prob = model.predict(X_test_balanced, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_test_balanced = Y_test_balanced.argmax(axis = 1)
# Out:
# 1

# %%
cm = confusion_matrix(y_test_balanced, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_test_balanced,
    y_scores=y_prob[:,1])

print("Accuracy: ", round((np.mean(y_pred == y_test_balanced)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_test_balanced, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_test_balanced, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  55.0  CI: [0.467 0.63 ]
# AUC:  0.637 CI: [0.544 0.73 ]
# Confusion matrix:
#  [[39 31]
#  [32 38]]
# Normalized Confusion matrix:
#  [[0.557 0.443]
#  [0.457 0.543]]

# %% [markdown]
# ### Deep Ensemble

# %%
def ensemble(width, height, depth, batch_size, count, X_test, Y_test, pat_test):
    
    model = get_model(width=w, height=h, depth=d)
    
    print(model.summary())
    
    metrics = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc')]
    
    model.compile(loss = "categorical_crossentropy",
              optimizer = keras.optimizers.Adam(learning_rate =  0.00001),
              metrics = metrics)
    
    epochs = 200
    hist = model.fit(
    resampled_data,
    validation_data=validation_dataset,
    epochs=epochs,
    verbose=1, callbacks=callback_list, 
    steps_per_epoch = resampled_steps_per_epoch,
    class_weight = class_weight)
    
    y_prob = model.predict(X_test, batch_size=batch_size)
    y_pred = (y_prob[:,1] > 0.5).astype(np.int)
    y_test = Y_test.argmax(axis = 1) 
    
    model.save('model'+str(count)+'.h5')
    
    df = pd.DataFrame()
    df.loc[:,'y_test'] = y_test
    df.loc[:,'y_pred'] = y_pred
    df.loc[:,'y_prob'] = list(y_prob[:,1])
    df.loc[:,'pat'] = pat_test
    
    return df

# %%
for index in range(4,5):
    reset_keras()
    
    df = ensemble(width=w, height=h, depth=d, count = index, batch_size = 4, X_test = X_test, Y_test = Y_test, pat_test = pat_test)
    
    df.to_csv('predictions'+str(index)+'.csv', index=False)
# Out:
# 100
# Model: "3dcnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 56, 20, 1)]   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 64, 56, 20, 16)    448
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 32, 28, 10, 16)    0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 28, 10, 16)    64
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 32, 28, 10, 32)    13856
# _________________________________________________________________
# average_pooling3d_1 (Average (None, 16, 14, 5, 32)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 14, 5, 32)     128
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 16, 14, 5, 32)     27680
# _________________________________________________________________
# average_pooling3d_2 (Average (None, 8, 7, 2, 32)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 7, 2, 32)       128
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 7, 2, 64)       55360
# _________________________________________________________________
# average_pooling3d_3 (Average (None, 4, 3, 1, 64)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 3, 1, 64)       256
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 3, 1, 64)       110656
# _________________________________________________________________
# average_pooling3d_4 (Average (None, 2, 2, 1, 64)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 2, 1, 64)       256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 225,410
# Trainable params: 224,994
# Non-trainable params: 416
# _________________________________________________________________
# None
# Epoch 1/200
# 141/141 [==============================] - 18s 92ms/step - loss: 1.0313 - accuracy: 0.5635 - auc: 0.5627 - val_loss: 0.8753 - val_accuracy: 0.3069 - val_auc: 0.3257
#
# Epoch 00001: saving model to History/model.epoch01.hdf5
# Epoch 2/200
# 141/141 [==============================] - 12s 84ms/step - loss: 0.9967 - accuracy: 0.5138 - auc: 0.5024 - val_loss: 1.0860 - val_accuracy: 0.3069 - val_auc: 0.3482
#
# Epoch 00002: saving model to History/model.epoch02.hdf5
# Epoch 3/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.9275 - accuracy: 0.5029 - auc: 0.5271 - val_loss: 1.1359 - val_accuracy: 0.3069 - val_auc: 0.3230
#
# Epoch 00003: saving model to History/model.epoch03.hdf5
# Epoch 4/200
# 141/141 [==============================] - 14s 96ms/step - loss: 0.8924 - accuracy: 0.5375 - auc: 0.5603 - val_loss: 0.9544 - val_accuracy: 0.3366 - val_auc: 0.3382
#
# Epoch 00004: saving model to History/model.epoch04.hdf5
# Epoch 5/200
# 141/141 [==============================] - 14s 98ms/step - loss: 0.8603 - accuracy: 0.5276 - auc: 0.5531 - val_loss: 1.0145 - val_accuracy: 0.3267 - val_auc: 0.3380
#
# Epoch 00005: saving model to History/model.epoch05.hdf5
# Epoch 6/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.8154 - accuracy: 0.5516 - auc: 0.5857 - val_loss: 0.9357 - val_accuracy: 0.4356 - val_auc: 0.4181
#
# Epoch 00006: saving model to History/model.epoch06.hdf5
# Epoch 7/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.8453 - accuracy: 0.5659 - auc: 0.5745 - val_loss: 1.1007 - val_accuracy: 0.3564 - val_auc: 0.3474
#
# Epoch 00007: saving model to History/model.epoch07.hdf5
# Epoch 8/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.8607 - accuracy: 0.5402 - auc: 0.5369 - val_loss: 1.1271 - val_accuracy: 0.3663 - val_auc: 0.3373
#
# Epoch 00008: saving model to History/model.epoch08.hdf5
# Epoch 9/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.8644 - accuracy: 0.4969 - auc: 0.5382 - val_loss: 1.1043 - val_accuracy: 0.3168 - val_auc: 0.3405
#
# Epoch 00009: saving model to History/model.epoch09.hdf5
# Epoch 10/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.8187 - accuracy: 0.5708 - auc: 0.6005 - val_loss: 1.1210 - val_accuracy: 0.3366 - val_auc: 0.3398
#
# Epoch 00010: saving model to History/model.epoch10.hdf5
# Epoch 11/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.8121 - accuracy: 0.5400 - auc: 0.5567 - val_loss: 0.9979 - val_accuracy: 0.3663 - val_auc: 0.3612
#
# Epoch 00011: saving model to History/model.epoch11.hdf5
# Epoch 12/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.8212 - accuracy: 0.5633 - auc: 0.5720 - val_loss: 1.0197 - val_accuracy: 0.3069 - val_auc: 0.3524
#
# Epoch 00012: saving model to History/model.epoch12.hdf5
# Epoch 13/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.8067 - accuracy: 0.5807 - auc: 0.6093 - val_loss: 0.9816 - val_accuracy: 0.3762 - val_auc: 0.3708
#
# Epoch 00013: saving model to History/model.epoch13.hdf5
# Epoch 14/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.8489 - accuracy: 0.5334 - auc: 0.5420 - val_loss: 0.9598 - val_accuracy: 0.3762 - val_auc: 0.3637
#
# Epoch 00014: saving model to History/model.epoch14.hdf5
# Epoch 15/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.8115 - accuracy: 0.5582 - auc: 0.5913 - val_loss: 1.0351 - val_accuracy: 0.3564 - val_auc: 0.3434
#
# Epoch 00015: saving model to History/model.epoch15.hdf5
# Epoch 16/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.7659 - accuracy: 0.5526 - auc: 0.6177 - val_loss: 1.1449 - val_accuracy: 0.3267 - val_auc: 0.3315
#
# Epoch 00016: saving model to History/model.epoch16.hdf5
# Epoch 17/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.7704 - accuracy: 0.5596 - auc: 0.6205 - val_loss: 1.0819 - val_accuracy: 0.3465 - val_auc: 0.3339
#
# Epoch 00017: saving model to History/model.epoch17.hdf5
# Epoch 18/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.7499 - accuracy: 0.6002 - auc: 0.6509 - val_loss: 0.9127 - val_accuracy: 0.4158 - val_auc: 0.3938
#
# Epoch 00018: saving model to History/model.epoch18.hdf5
# Epoch 19/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.7861 - accuracy: 0.6079 - auc: 0.6514 - val_loss: 0.9806 - val_accuracy: 0.3663 - val_auc: 0.3622
#
# Epoch 00019: saving model to History/model.epoch19.hdf5
# Epoch 20/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.7394 - accuracy: 0.6240 - auc: 0.6635 - val_loss: 1.1381 - val_accuracy: 0.3366 - val_auc: 0.3338
#
# Epoch 00020: saving model to History/model.epoch20.hdf5
# Epoch 21/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.7607 - accuracy: 0.6248 - auc: 0.6542 - val_loss: 0.9537 - val_accuracy: 0.4059 - val_auc: 0.3784
#
# Epoch 00021: saving model to History/model.epoch21.hdf5
# Epoch 22/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.7358 - accuracy: 0.6313 - auc: 0.6815 - val_loss: 0.9702 - val_accuracy: 0.3762 - val_auc: 0.3517
#
# Epoch 00022: saving model to History/model.epoch22.hdf5
# Epoch 23/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.7330 - accuracy: 0.6321 - auc: 0.6790 - val_loss: 1.0035 - val_accuracy: 0.3465 - val_auc: 0.3632
#
# Epoch 00023: saving model to History/model.epoch23.hdf5
# Epoch 24/200
# 141/141 [==============================] - 13s 94ms/step - loss: 0.7226 - accuracy: 0.6172 - auc: 0.6874 - val_loss: 0.9626 - val_accuracy: 0.3663 - val_auc: 0.3577
#
# Epoch 00024: saving model to History/model.epoch24.hdf5
# Epoch 25/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.7532 - accuracy: 0.6317 - auc: 0.6846 - val_loss: 0.9649 - val_accuracy: 0.3366 - val_auc: 0.3510
#
# Epoch 00025: saving model to History/model.epoch25.hdf5
# Epoch 26/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.7103 - accuracy: 0.6311 - auc: 0.6954 - val_loss: 0.8162 - val_accuracy: 0.5644 - val_auc: 0.5508
#
# Epoch 00026: saving model to History/model.epoch26.hdf5
# Epoch 27/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.7380 - accuracy: 0.6197 - auc: 0.6928 - val_loss: 0.9676 - val_accuracy: 0.3762 - val_auc: 0.3813
#
# Epoch 00027: saving model to History/model.epoch27.hdf5
# Epoch 28/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.7319 - accuracy: 0.6284 - auc: 0.6855 - val_loss: 0.9195 - val_accuracy: 0.4059 - val_auc: 0.4164
#
# Epoch 00028: saving model to History/model.epoch28.hdf5
# Epoch 29/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.7040 - accuracy: 0.6670 - auc: 0.7320 - val_loss: 0.9893 - val_accuracy: 0.3564 - val_auc: 0.3711
#
# Epoch 00029: saving model to History/model.epoch29.hdf5
# Epoch 30/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.7111 - accuracy: 0.5922 - auc: 0.6782 - val_loss: 0.9629 - val_accuracy: 0.3960 - val_auc: 0.3947
#
# Epoch 00030: saving model to History/model.epoch30.hdf5
# Epoch 31/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.6800 - accuracy: 0.6827 - auc: 0.7533 - val_loss: 1.0672 - val_accuracy: 0.3564 - val_auc: 0.3438
#
# Epoch 00031: saving model to History/model.epoch31.hdf5
# Epoch 32/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.6985 - accuracy: 0.6240 - auc: 0.6928 - val_loss: 0.9651 - val_accuracy: 0.3762 - val_auc: 0.3715
#
# Epoch 00032: saving model to History/model.epoch32.hdf5
# Epoch 33/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.7178 - accuracy: 0.6117 - auc: 0.6632 - val_loss: 0.9272 - val_accuracy: 0.4554 - val_auc: 0.4373
#
# Epoch 00033: saving model to History/model.epoch33.hdf5
# Epoch 34/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.7225 - accuracy: 0.6233 - auc: 0.6865 - val_loss: 0.9397 - val_accuracy: 0.4356 - val_auc: 0.4164
#
# Epoch 00034: saving model to History/model.epoch34.hdf5
# Epoch 35/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.6749 - accuracy: 0.7191 - auc: 0.7619 - val_loss: 0.9836 - val_accuracy: 0.3564 - val_auc: 0.3905
#
# Epoch 00035: saving model to History/model.epoch35.hdf5
# Epoch 36/200
# 141/141 [==============================] - 12s 84ms/step - loss: 0.6310 - accuracy: 0.6968 - auc: 0.7743 - val_loss: 0.9796 - val_accuracy: 0.4257 - val_auc: 0.4159
#
# Epoch 00036: saving model to History/model.epoch36.hdf5
# Epoch 37/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.6806 - accuracy: 0.6573 - auc: 0.7357 - val_loss: 1.0837 - val_accuracy: 0.3960 - val_auc: 0.3651
#
# Epoch 00037: saving model to History/model.epoch37.hdf5
# Epoch 38/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6555 - accuracy: 0.7006 - auc: 0.7633 - val_loss: 0.9663 - val_accuracy: 0.4059 - val_auc: 0.4037
#
# Epoch 00038: saving model to History/model.epoch38.hdf5
# Epoch 39/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.6440 - accuracy: 0.6686 - auc: 0.7709 - val_loss: 0.9910 - val_accuracy: 0.4455 - val_auc: 0.4132
#
# Epoch 00039: saving model to History/model.epoch39.hdf5
# Epoch 40/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6439 - accuracy: 0.6842 - auc: 0.7633 - val_loss: 1.0373 - val_accuracy: 0.3861 - val_auc: 0.3762
#
# Epoch 00040: saving model to History/model.epoch40.hdf5
# Epoch 41/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6558 - accuracy: 0.6814 - auc: 0.7538 - val_loss: 0.9127 - val_accuracy: 0.5149 - val_auc: 0.4949
#
# Epoch 00041: saving model to History/model.epoch41.hdf5
# Epoch 42/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.6375 - accuracy: 0.6919 - auc: 0.7766 - val_loss: 0.9528 - val_accuracy: 0.4653 - val_auc: 0.4492
#
# Epoch 00042: saving model to History/model.epoch42.hdf5
# Epoch 43/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.6761 - accuracy: 0.6391 - auc: 0.7386 - val_loss: 0.9835 - val_accuracy: 0.4257 - val_auc: 0.4367
#
# Epoch 00043: saving model to History/model.epoch43.hdf5
# Epoch 44/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6403 - accuracy: 0.6928 - auc: 0.7685 - val_loss: 1.2335 - val_accuracy: 0.3465 - val_auc: 0.3295
#
# Epoch 00044: saving model to History/model.epoch44.hdf5
# Epoch 45/200
# 141/141 [==============================] - 15s 106ms/step - loss: 0.6516 - accuracy: 0.6551 - auc: 0.7639 - val_loss: 1.0018 - val_accuracy: 0.4653 - val_auc: 0.4317
#
# Epoch 00045: saving model to History/model.epoch45.hdf5
# Epoch 46/200
# 141/141 [==============================] - 17s 117ms/step - loss: 0.6750 - accuracy: 0.6920 - auc: 0.7630 - val_loss: 0.9317 - val_accuracy: 0.4455 - val_auc: 0.4646
#
# Epoch 00046: saving model to History/model.epoch46.hdf5
# Epoch 47/200
# 141/141 [==============================] - 16s 113ms/step - loss: 0.6281 - accuracy: 0.6800 - auc: 0.7656 - val_loss: 1.0290 - val_accuracy: 0.4059 - val_auc: 0.4223
#
# Epoch 00047: saving model to History/model.epoch47.hdf5
# Epoch 48/200
# 141/141 [==============================] - 17s 118ms/step - loss: 0.6339 - accuracy: 0.6892 - auc: 0.7961 - val_loss: 0.9262 - val_accuracy: 0.4554 - val_auc: 0.4835
#
# Epoch 00048: saving model to History/model.epoch48.hdf5
# Epoch 49/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.6171 - accuracy: 0.7414 - auc: 0.8048 - val_loss: 0.9286 - val_accuracy: 0.5446 - val_auc: 0.5279
#
# Epoch 00049: saving model to History/model.epoch49.hdf5
# Epoch 50/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.6314 - accuracy: 0.6879 - auc: 0.7874 - val_loss: 1.0735 - val_accuracy: 0.4059 - val_auc: 0.4129
#
# Epoch 00050: saving model to History/model.epoch50.hdf5
# Epoch 51/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.5813 - accuracy: 0.7358 - auc: 0.8256 - val_loss: 0.8391 - val_accuracy: 0.5842 - val_auc: 0.5956
#
# Epoch 00051: saving model to History/model.epoch51.hdf5
# Epoch 52/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.6250 - accuracy: 0.7178 - auc: 0.7988 - val_loss: 0.8677 - val_accuracy: 0.5644 - val_auc: 0.5756
#
# Epoch 00052: saving model to History/model.epoch52.hdf5
# Epoch 53/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6117 - accuracy: 0.7582 - auc: 0.8195 - val_loss: 0.8070 - val_accuracy: 0.6040 - val_auc: 0.6484
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.6363 - accuracy: 0.7092 - auc: 0.8017 - val_loss: 0.8375 - val_accuracy: 0.5644 - val_auc: 0.5924
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.5872 - accuracy: 0.7421 - auc: 0.8355 - val_loss: 0.9535 - val_accuracy: 0.4950 - val_auc: 0.4790
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.6204 - accuracy: 0.7131 - auc: 0.7911 - val_loss: 1.0543 - val_accuracy: 0.4158 - val_auc: 0.4442
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/200
# 141/141 [==============================] - 12s 83ms/step - loss: 0.5574 - accuracy: 0.7542 - auc: 0.8462 - val_loss: 0.9161 - val_accuracy: 0.5347 - val_auc: 0.5321
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.6082 - accuracy: 0.7448 - auc: 0.8106 - val_loss: 1.0869 - val_accuracy: 0.4059 - val_auc: 0.4281
#
# Epoch 00058: saving model to History/model.epoch58.hdf5
# Epoch 59/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.5958 - accuracy: 0.7350 - auc: 0.8101 - val_loss: 0.9423 - val_accuracy: 0.5050 - val_auc: 0.5119
#
# Epoch 00059: saving model to History/model.epoch59.hdf5
# Epoch 60/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.5733 - accuracy: 0.7643 - auc: 0.8452 - val_loss: 1.0019 - val_accuracy: 0.4554 - val_auc: 0.4872
#
# Epoch 00060: saving model to History/model.epoch60.hdf5
# Epoch 61/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.6044 - accuracy: 0.7175 - auc: 0.8059 - val_loss: 0.8821 - val_accuracy: 0.5347 - val_auc: 0.5548
#
# Epoch 00061: saving model to History/model.epoch61.hdf5
# Epoch 62/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.5601 - accuracy: 0.7500 - auc: 0.8465 - val_loss: 0.8054 - val_accuracy: 0.6139 - val_auc: 0.6537
#
# Epoch 00062: saving model to History/model.epoch62.hdf5
# Epoch 63/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.5825 - accuracy: 0.7549 - auc: 0.8151 - val_loss: 0.9184 - val_accuracy: 0.5149 - val_auc: 0.5244
#
# Epoch 00063: saving model to History/model.epoch63.hdf5
# Epoch 64/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.6010 - accuracy: 0.7108 - auc: 0.8180 - val_loss: 0.9419 - val_accuracy: 0.4950 - val_auc: 0.5133
#
# Epoch 00064: saving model to History/model.epoch64.hdf5
# Epoch 65/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.5602 - accuracy: 0.7828 - auc: 0.8508 - val_loss: 1.1413 - val_accuracy: 0.3960 - val_auc: 0.4385
#
# Epoch 00065: saving model to History/model.epoch65.hdf5
# Epoch 66/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.5906 - accuracy: 0.7256 - auc: 0.8212 - val_loss: 0.8904 - val_accuracy: 0.5743 - val_auc: 0.5739
#
# Epoch 00066: saving model to History/model.epoch66.hdf5
# Epoch 67/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.5432 - accuracy: 0.7693 - auc: 0.8447 - val_loss: 0.8025 - val_accuracy: 0.6634 - val_auc: 0.6636
#
# Epoch 00067: saving model to History/model.epoch67.hdf5
# Epoch 68/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.5307 - accuracy: 0.7928 - auc: 0.8758 - val_loss: 0.8684 - val_accuracy: 0.6040 - val_auc: 0.6003
#
# Epoch 00068: saving model to History/model.epoch68.hdf5
# Epoch 69/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.5813 - accuracy: 0.7294 - auc: 0.8213 - val_loss: 0.8856 - val_accuracy: 0.5743 - val_auc: 0.5933
#
# Epoch 00069: saving model to History/model.epoch69.hdf5
# Epoch 70/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.5543 - accuracy: 0.7815 - auc: 0.8479 - val_loss: 0.8637 - val_accuracy: 0.5941 - val_auc: 0.6188
#
# Epoch 00070: saving model to History/model.epoch70.hdf5
# Epoch 71/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.5385 - accuracy: 0.7682 - auc: 0.8660 - val_loss: 1.0454 - val_accuracy: 0.4554 - val_auc: 0.4781
#
# Epoch 00071: saving model to History/model.epoch71.hdf5
# Epoch 72/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.5419 - accuracy: 0.7808 - auc: 0.8541 - val_loss: 0.8669 - val_accuracy: 0.6238 - val_auc: 0.6045
#
# Epoch 00072: saving model to History/model.epoch72.hdf5
# Epoch 73/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.5183 - accuracy: 0.7957 - auc: 0.8775 - val_loss: 0.8216 - val_accuracy: 0.6436 - val_auc: 0.6511
#
# Epoch 00073: saving model to History/model.epoch73.hdf5
# Epoch 74/200
# 141/141 [==============================] - 14s 102ms/step - loss: 0.5393 - accuracy: 0.7813 - auc: 0.8661 - val_loss: 0.8459 - val_accuracy: 0.5644 - val_auc: 0.6070
#
# Epoch 00074: saving model to History/model.epoch74.hdf5
# Epoch 75/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.5637 - accuracy: 0.7462 - auc: 0.8367 - val_loss: 1.0111 - val_accuracy: 0.4752 - val_auc: 0.4909
#
# Epoch 00075: saving model to History/model.epoch75.hdf5
# Epoch 76/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.5028 - accuracy: 0.8130 - auc: 0.8866 - val_loss: 0.8673 - val_accuracy: 0.5743 - val_auc: 0.5907
#
# Epoch 00076: saving model to History/model.epoch76.hdf5
# Epoch 77/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.5005 - accuracy: 0.8166 - auc: 0.8853 - val_loss: 0.9620 - val_accuracy: 0.5050 - val_auc: 0.5478
#
# Epoch 00077: saving model to History/model.epoch77.hdf5
# Epoch 78/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.4775 - accuracy: 0.8192 - auc: 0.8931 - val_loss: 0.8144 - val_accuracy: 0.6238 - val_auc: 0.6696
#
# Epoch 00078: saving model to History/model.epoch78.hdf5
# Epoch 79/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.5092 - accuracy: 0.7983 - auc: 0.8911 - val_loss: 0.8251 - val_accuracy: 0.6337 - val_auc: 0.6712
#
# Epoch 00079: saving model to History/model.epoch79.hdf5
# Epoch 80/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4873 - accuracy: 0.7859 - auc: 0.8922 - val_loss: 0.8422 - val_accuracy: 0.6040 - val_auc: 0.6344
#
# Epoch 00080: saving model to History/model.epoch80.hdf5
# Epoch 81/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.5072 - accuracy: 0.8026 - auc: 0.9011 - val_loss: 0.8912 - val_accuracy: 0.5941 - val_auc: 0.6083
#
# Epoch 00081: saving model to History/model.epoch81.hdf5
# Epoch 82/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.5736 - accuracy: 0.7516 - auc: 0.8202 - val_loss: 0.8337 - val_accuracy: 0.6337 - val_auc: 0.6961
#
# Epoch 00082: saving model to History/model.epoch82.hdf5
# Epoch 83/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4667 - accuracy: 0.8204 - auc: 0.9044 - val_loss: 0.8544 - val_accuracy: 0.6337 - val_auc: 0.6436
#
# Epoch 00083: saving model to History/model.epoch83.hdf5
# Epoch 84/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.5118 - accuracy: 0.7755 - auc: 0.8869 - val_loss: 1.0301 - val_accuracy: 0.5248 - val_auc: 0.5245
#
# Epoch 00084: saving model to History/model.epoch84.hdf5
# Epoch 85/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.4808 - accuracy: 0.8027 - auc: 0.8977 - val_loss: 0.8029 - val_accuracy: 0.6931 - val_auc: 0.7221
#
# Epoch 00085: saving model to History/model.epoch85.hdf5
# Epoch 86/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4663 - accuracy: 0.8402 - auc: 0.9134 - val_loss: 0.8279 - val_accuracy: 0.6634 - val_auc: 0.7137
#
# Epoch 00086: saving model to History/model.epoch86.hdf5
# Epoch 87/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4736 - accuracy: 0.8225 - auc: 0.8985 - val_loss: 0.8540 - val_accuracy: 0.6535 - val_auc: 0.7023
#
# Epoch 00087: saving model to History/model.epoch87.hdf5
# Epoch 88/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.4813 - accuracy: 0.8232 - auc: 0.9051 - val_loss: 0.9644 - val_accuracy: 0.5842 - val_auc: 0.5802
#
# Epoch 00088: saving model to History/model.epoch88.hdf5
# Epoch 89/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.5047 - accuracy: 0.7834 - auc: 0.8865 - val_loss: 0.8967 - val_accuracy: 0.5941 - val_auc: 0.6093
#
# Epoch 00089: saving model to History/model.epoch89.hdf5
# Epoch 90/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.4796 - accuracy: 0.8183 - auc: 0.9046 - val_loss: 0.9097 - val_accuracy: 0.6139 - val_auc: 0.6428
#
# Epoch 00090: saving model to History/model.epoch90.hdf5
# Epoch 91/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4770 - accuracy: 0.8210 - auc: 0.9032 - val_loss: 0.8331 - val_accuracy: 0.6436 - val_auc: 0.6919
#
# Epoch 00091: saving model to History/model.epoch91.hdf5
# Epoch 92/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4622 - accuracy: 0.8093 - auc: 0.9130 - val_loss: 0.9508 - val_accuracy: 0.6040 - val_auc: 0.5958
#
# Epoch 00092: saving model to History/model.epoch92.hdf5
# Epoch 93/200
# 141/141 [==============================] - 15s 105ms/step - loss: 0.4497 - accuracy: 0.8197 - auc: 0.9122 - val_loss: 0.9949 - val_accuracy: 0.5248 - val_auc: 0.5593
#
# Epoch 00093: saving model to History/model.epoch93.hdf5
# Epoch 94/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.4842 - accuracy: 0.8274 - auc: 0.9013 - val_loss: 0.7999 - val_accuracy: 0.6733 - val_auc: 0.7248
#
# Epoch 00094: saving model to History/model.epoch94.hdf5
# Epoch 95/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.4969 - accuracy: 0.8076 - auc: 0.8962 - val_loss: 0.8780 - val_accuracy: 0.6139 - val_auc: 0.6620
#
# Epoch 00095: saving model to History/model.epoch95.hdf5
# Epoch 96/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.4450 - accuracy: 0.8417 - auc: 0.9202 - val_loss: 0.8681 - val_accuracy: 0.5941 - val_auc: 0.6488
#
# Epoch 00096: saving model to History/model.epoch96.hdf5
# Epoch 97/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4567 - accuracy: 0.8304 - auc: 0.9039 - val_loss: 0.9001 - val_accuracy: 0.5842 - val_auc: 0.6385
#
# Epoch 00097: saving model to History/model.epoch97.hdf5
# Epoch 98/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.4884 - accuracy: 0.8108 - auc: 0.8964 - val_loss: 0.9491 - val_accuracy: 0.5941 - val_auc: 0.6125
#
# Epoch 00098: saving model to History/model.epoch98.hdf5
# Epoch 99/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.4691 - accuracy: 0.8049 - auc: 0.8959 - val_loss: 0.7760 - val_accuracy: 0.7129 - val_auc: 0.7181
#
# Epoch 00099: saving model to History/model.epoch99.hdf5
# Epoch 100/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.4411 - accuracy: 0.8389 - auc: 0.9199 - val_loss: 0.9424 - val_accuracy: 0.5644 - val_auc: 0.5933
#
# Epoch 00100: saving model to History/model.epoch100.hdf5
# Epoch 101/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.4607 - accuracy: 0.8205 - auc: 0.9090 - val_loss: 0.9596 - val_accuracy: 0.6139 - val_auc: 0.6251
#
# Epoch 00101: saving model to History/model.epoch101.hdf5
# Epoch 102/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.4377 - accuracy: 0.8460 - auc: 0.9219 - val_loss: 0.9264 - val_accuracy: 0.6040 - val_auc: 0.6180
#
# Epoch 00102: saving model to History/model.epoch102.hdf5
# Epoch 103/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4900 - accuracy: 0.8067 - auc: 0.8922 - val_loss: 0.8241 - val_accuracy: 0.6832 - val_auc: 0.7185
#
# Epoch 00103: saving model to History/model.epoch103.hdf5
# Epoch 104/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.4315 - accuracy: 0.8554 - auc: 0.9309 - val_loss: 0.9782 - val_accuracy: 0.5545 - val_auc: 0.6018
#
# Epoch 00104: saving model to History/model.epoch104.hdf5
# Epoch 105/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.4763 - accuracy: 0.8061 - auc: 0.8882 - val_loss: 0.7977 - val_accuracy: 0.6931 - val_auc: 0.7318
#
# Epoch 00105: saving model to History/model.epoch105.hdf5
# Epoch 106/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4508 - accuracy: 0.8407 - auc: 0.9110 - val_loss: 0.9006 - val_accuracy: 0.5743 - val_auc: 0.6364
#
# Epoch 00106: saving model to History/model.epoch106.hdf5
# Epoch 107/200
# 141/141 [==============================] - 13s 96ms/step - loss: 0.4886 - accuracy: 0.8386 - auc: 0.8976 - val_loss: 0.8421 - val_accuracy: 0.6832 - val_auc: 0.7127
#
# Epoch 00107: saving model to History/model.epoch107.hdf5
# Epoch 108/200
# 141/141 [==============================] - 14s 101ms/step - loss: 0.4275 - accuracy: 0.8533 - auc: 0.9271 - val_loss: 0.9478 - val_accuracy: 0.6040 - val_auc: 0.6083
#
# Epoch 00108: saving model to History/model.epoch108.hdf5
# Epoch 109/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.4157 - accuracy: 0.8509 - auc: 0.9364 - val_loss: 0.8784 - val_accuracy: 0.6634 - val_auc: 0.6684
#
# Epoch 00109: saving model to History/model.epoch109.hdf5
# Epoch 110/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4588 - accuracy: 0.8152 - auc: 0.9127 - val_loss: 0.9813 - val_accuracy: 0.5446 - val_auc: 0.6101
#
# Epoch 00110: saving model to History/model.epoch110.hdf5
# Epoch 111/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4775 - accuracy: 0.8169 - auc: 0.8972 - val_loss: 0.8809 - val_accuracy: 0.6634 - val_auc: 0.6960
#
# Epoch 00111: saving model to History/model.epoch111.hdf5
# Epoch 112/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.4665 - accuracy: 0.8375 - auc: 0.9191 - val_loss: 0.8520 - val_accuracy: 0.7030 - val_auc: 0.7227
#
# Epoch 00112: saving model to History/model.epoch112.hdf5
# Epoch 113/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.4371 - accuracy: 0.8347 - auc: 0.9247 - val_loss: 0.9190 - val_accuracy: 0.6634 - val_auc: 0.6775
#
# Epoch 00113: saving model to History/model.epoch113.hdf5
# Epoch 114/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.3758 - accuracy: 0.8760 - auc: 0.9468 - val_loss: 0.8790 - val_accuracy: 0.6733 - val_auc: 0.6917
#
# Epoch 00114: saving model to History/model.epoch114.hdf5
# Epoch 115/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4146 - accuracy: 0.8531 - auc: 0.9329 - val_loss: 0.9105 - val_accuracy: 0.5842 - val_auc: 0.6508
#
# Epoch 00115: saving model to History/model.epoch115.hdf5
# Epoch 116/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.4381 - accuracy: 0.8315 - auc: 0.9142 - val_loss: 0.8892 - val_accuracy: 0.6436 - val_auc: 0.6688
#
# Epoch 00116: saving model to History/model.epoch116.hdf5
# Epoch 117/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3888 - accuracy: 0.8571 - auc: 0.9417 - val_loss: 0.8677 - val_accuracy: 0.6634 - val_auc: 0.6884
#
# Epoch 00117: saving model to History/model.epoch117.hdf5
# Epoch 118/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4085 - accuracy: 0.8531 - auc: 0.9353 - val_loss: 0.8933 - val_accuracy: 0.6535 - val_auc: 0.6859
#
# Epoch 00118: saving model to History/model.epoch118.hdf5
# Epoch 119/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.4423 - accuracy: 0.8303 - auc: 0.9253 - val_loss: 0.8972 - val_accuracy: 0.6733 - val_auc: 0.7296
#
# Epoch 00119: saving model to History/model.epoch119.hdf5
# Epoch 120/200
# 141/141 [==============================] - 12s 84ms/step - loss: 0.4065 - accuracy: 0.8392 - auc: 0.9362 - val_loss: 0.8638 - val_accuracy: 0.6931 - val_auc: 0.7223
#
# Epoch 00120: saving model to History/model.epoch120.hdf5
# Epoch 121/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.4050 - accuracy: 0.8610 - auc: 0.9368 - val_loss: 0.8721 - val_accuracy: 0.7030 - val_auc: 0.7430
#
# Epoch 00121: saving model to History/model.epoch121.hdf5
# Epoch 122/200
# 141/141 [==============================] - 12s 83ms/step - loss: 0.3981 - accuracy: 0.8723 - auc: 0.9325 - val_loss: 0.8712 - val_accuracy: 0.7030 - val_auc: 0.7204
#
# Epoch 00122: saving model to History/model.epoch122.hdf5
# Epoch 123/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.4178 - accuracy: 0.8458 - auc: 0.9370 - val_loss: 0.8806 - val_accuracy: 0.6733 - val_auc: 0.7181
#
# Epoch 00123: saving model to History/model.epoch123.hdf5
# Epoch 124/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4092 - accuracy: 0.8267 - auc: 0.9318 - val_loss: 0.9023 - val_accuracy: 0.6535 - val_auc: 0.6728
#
# Epoch 00124: saving model to History/model.epoch124.hdf5
# Epoch 125/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.3828 - accuracy: 0.8608 - auc: 0.9498 - val_loss: 1.0528 - val_accuracy: 0.5644 - val_auc: 0.5983
#
# Epoch 00125: saving model to History/model.epoch125.hdf5
# Epoch 126/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4179 - accuracy: 0.8328 - auc: 0.9300 - val_loss: 0.9003 - val_accuracy: 0.7525 - val_auc: 0.7367
#
# Epoch 00126: saving model to History/model.epoch126.hdf5
# Epoch 127/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3921 - accuracy: 0.8827 - auc: 0.9466 - val_loss: 1.1665 - val_accuracy: 0.4950 - val_auc: 0.5370
#
# Epoch 00127: saving model to History/model.epoch127.hdf5
# Epoch 128/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.4005 - accuracy: 0.8749 - auc: 0.9321 - val_loss: 0.9109 - val_accuracy: 0.6733 - val_auc: 0.7037
#
# Epoch 00128: saving model to History/model.epoch128.hdf5
# Epoch 129/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3620 - accuracy: 0.8898 - auc: 0.9532 - val_loss: 0.9025 - val_accuracy: 0.7129 - val_auc: 0.7046
#
# Epoch 00129: saving model to History/model.epoch129.hdf5
# Epoch 130/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.3930 - accuracy: 0.8715 - auc: 0.9402 - val_loss: 0.8908 - val_accuracy: 0.7129 - val_auc: 0.7322
#
# Epoch 00130: saving model to History/model.epoch130.hdf5
# Epoch 131/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3928 - accuracy: 0.8803 - auc: 0.9395 - val_loss: 0.9036 - val_accuracy: 0.6337 - val_auc: 0.6888
#
# Epoch 00131: saving model to History/model.epoch131.hdf5
# Epoch 132/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.3810 - accuracy: 0.8887 - auc: 0.9490 - val_loss: 0.9830 - val_accuracy: 0.6139 - val_auc: 0.6448
#
# Epoch 00132: saving model to History/model.epoch132.hdf5
# Epoch 133/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3947 - accuracy: 0.8685 - auc: 0.9389 - val_loss: 0.9473 - val_accuracy: 0.6634 - val_auc: 0.6928
#
# Epoch 00133: saving model to History/model.epoch133.hdf5
# Epoch 134/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.3877 - accuracy: 0.8769 - auc: 0.9473 - val_loss: 0.9455 - val_accuracy: 0.6436 - val_auc: 0.7042
#
# Epoch 00134: saving model to History/model.epoch134.hdf5
# Epoch 135/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3764 - accuracy: 0.8746 - auc: 0.9446 - val_loss: 0.9072 - val_accuracy: 0.7129 - val_auc: 0.7333
#
# Epoch 00135: saving model to History/model.epoch135.hdf5
# Epoch 136/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.3838 - accuracy: 0.8615 - auc: 0.9510 - val_loss: 1.0902 - val_accuracy: 0.5644 - val_auc: 0.5752
#
# Epoch 00136: saving model to History/model.epoch136.hdf5
# Epoch 137/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.4274 - accuracy: 0.8364 - auc: 0.9157 - val_loss: 0.9833 - val_accuracy: 0.6040 - val_auc: 0.6555
#
# Epoch 00137: saving model to History/model.epoch137.hdf5
# Epoch 138/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.3896 - accuracy: 0.8426 - auc: 0.9409 - val_loss: 0.8921 - val_accuracy: 0.6733 - val_auc: 0.7260
#
# Epoch 00138: saving model to History/model.epoch138.hdf5
# Epoch 139/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3498 - accuracy: 0.8783 - auc: 0.9561 - val_loss: 0.8835 - val_accuracy: 0.7030 - val_auc: 0.7266
#
# Epoch 00139: saving model to History/model.epoch139.hdf5
# Epoch 140/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.3775 - accuracy: 0.8681 - auc: 0.9433 - val_loss: 0.9448 - val_accuracy: 0.6634 - val_auc: 0.7210
#
# Epoch 00140: saving model to History/model.epoch140.hdf5
# Epoch 141/200
# 141/141 [==============================] - 12s 84ms/step - loss: 0.3787 - accuracy: 0.8773 - auc: 0.9441 - val_loss: 0.9639 - val_accuracy: 0.6535 - val_auc: 0.6829
#
# Epoch 00141: saving model to History/model.epoch141.hdf5
# Epoch 142/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3881 - accuracy: 0.8652 - auc: 0.9435 - val_loss: 0.9497 - val_accuracy: 0.6436 - val_auc: 0.6674
#
# Epoch 00142: saving model to History/model.epoch142.hdf5
# Epoch 143/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.3357 - accuracy: 0.8826 - auc: 0.9618 - val_loss: 0.9837 - val_accuracy: 0.5644 - val_auc: 0.6450
#
# Epoch 00143: saving model to History/model.epoch143.hdf5
# Epoch 144/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4062 - accuracy: 0.8493 - auc: 0.9339 - val_loss: 0.9343 - val_accuracy: 0.6832 - val_auc: 0.6885
#
# Epoch 00144: saving model to History/model.epoch144.hdf5
# Epoch 145/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.3816 - accuracy: 0.8661 - auc: 0.9472 - val_loss: 0.9681 - val_accuracy: 0.6436 - val_auc: 0.6709
#
# Epoch 00145: saving model to History/model.epoch145.hdf5
# Epoch 146/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3756 - accuracy: 0.8465 - auc: 0.9446 - val_loss: 1.1256 - val_accuracy: 0.6040 - val_auc: 0.5953
#
# Epoch 00146: saving model to History/model.epoch146.hdf5
# Epoch 147/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4022 - accuracy: 0.8479 - auc: 0.9359 - val_loss: 1.0240 - val_accuracy: 0.6535 - val_auc: 0.6677
#
# Epoch 00147: saving model to History/model.epoch147.hdf5
# Epoch 148/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3633 - accuracy: 0.8763 - auc: 0.9524 - val_loss: 0.9620 - val_accuracy: 0.6634 - val_auc: 0.6818
#
# Epoch 00148: saving model to History/model.epoch148.hdf5
# Epoch 149/200
# 141/141 [==============================] - 12s 84ms/step - loss: 0.3698 - accuracy: 0.8728 - auc: 0.9518 - val_loss: 0.9497 - val_accuracy: 0.6337 - val_auc: 0.6902
#
# Epoch 00149: saving model to History/model.epoch149.hdf5
# Epoch 150/200
# 141/141 [==============================] - 13s 91ms/step - loss: 0.3682 - accuracy: 0.8714 - auc: 0.9550 - val_loss: 0.9284 - val_accuracy: 0.6733 - val_auc: 0.7097
#
# Epoch 00150: saving model to History/model.epoch150.hdf5
# Epoch 151/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3137 - accuracy: 0.8772 - auc: 0.9640 - val_loss: 0.9713 - val_accuracy: 0.6931 - val_auc: 0.7114
#
# Epoch 00151: saving model to History/model.epoch151.hdf5
# Epoch 152/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3703 - accuracy: 0.8799 - auc: 0.9474 - val_loss: 0.9539 - val_accuracy: 0.7228 - val_auc: 0.7258
#
# Epoch 00152: saving model to History/model.epoch152.hdf5
# Epoch 153/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3159 - accuracy: 0.8927 - auc: 0.9678 - val_loss: 0.9870 - val_accuracy: 0.6535 - val_auc: 0.6893
#
# Epoch 00153: saving model to History/model.epoch153.hdf5
# Epoch 154/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3635 - accuracy: 0.8646 - auc: 0.9489 - val_loss: 0.9977 - val_accuracy: 0.7129 - val_auc: 0.7293
#
# Epoch 00154: saving model to History/model.epoch154.hdf5
# Epoch 155/200
# 141/141 [==============================] - 14s 96ms/step - loss: 0.3098 - accuracy: 0.9087 - auc: 0.9731 - val_loss: 1.0263 - val_accuracy: 0.6337 - val_auc: 0.6542
#
# Epoch 00155: saving model to History/model.epoch155.hdf5
# Epoch 156/200
# 141/141 [==============================] - 16s 114ms/step - loss: 0.3723 - accuracy: 0.8794 - auc: 0.9543 - val_loss: 1.0826 - val_accuracy: 0.6040 - val_auc: 0.6409
#
# Epoch 00156: saving model to History/model.epoch156.hdf5
# Epoch 157/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.3549 - accuracy: 0.8812 - auc: 0.9538 - val_loss: 1.0501 - val_accuracy: 0.6436 - val_auc: 0.6665
#
# Epoch 00157: saving model to History/model.epoch157.hdf5
# Epoch 158/200
# 141/141 [==============================] - 13s 95ms/step - loss: 0.3267 - accuracy: 0.9102 - auc: 0.9692 - val_loss: 0.9986 - val_accuracy: 0.6634 - val_auc: 0.6937
#
# Epoch 00158: saving model to History/model.epoch158.hdf5
# Epoch 159/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.3379 - accuracy: 0.9003 - auc: 0.9657 - val_loss: 0.9495 - val_accuracy: 0.6733 - val_auc: 0.7074
#
# Epoch 00159: saving model to History/model.epoch159.hdf5
# Epoch 160/200
# 141/141 [==============================] - 13s 93ms/step - loss: 0.4426 - accuracy: 0.8388 - auc: 0.9192 - val_loss: 0.9755 - val_accuracy: 0.6832 - val_auc: 0.7090
#
# Epoch 00160: saving model to History/model.epoch160.hdf5
# Epoch 161/200
# 141/141 [==============================] - 16s 115ms/step - loss: 0.3179 - accuracy: 0.8873 - auc: 0.9659 - val_loss: 0.9728 - val_accuracy: 0.6832 - val_auc: 0.7066
#
# Epoch 00161: saving model to History/model.epoch161.hdf5
# Epoch 162/200
# 141/141 [==============================] - 16s 111ms/step - loss: 0.3491 - accuracy: 0.8859 - auc: 0.9604 - val_loss: 1.0246 - val_accuracy: 0.6238 - val_auc: 0.6645
#
# Epoch 00162: saving model to History/model.epoch162.hdf5
# Epoch 163/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3398 - accuracy: 0.8866 - auc: 0.9550 - val_loss: 1.0180 - val_accuracy: 0.6634 - val_auc: 0.6715
#
# Epoch 00163: saving model to History/model.epoch163.hdf5
# Epoch 164/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.3497 - accuracy: 0.8826 - auc: 0.9571 - val_loss: 1.0206 - val_accuracy: 0.6535 - val_auc: 0.6999
#
# Epoch 00164: saving model to History/model.epoch164.hdf5
# Epoch 165/200
# 141/141 [==============================] - 12s 85ms/step - loss: 0.3488 - accuracy: 0.8867 - auc: 0.9492 - val_loss: 1.3532 - val_accuracy: 0.5347 - val_auc: 0.5538
#
# Epoch 00165: saving model to History/model.epoch165.hdf5
# Epoch 166/200
# 141/141 [==============================] - 12s 89ms/step - loss: 0.3458 - accuracy: 0.8763 - auc: 0.9557 - val_loss: 0.9449 - val_accuracy: 0.6832 - val_auc: 0.7271
#
# Epoch 00166: saving model to History/model.epoch166.hdf5
# Epoch 167/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.3662 - accuracy: 0.8767 - auc: 0.9493 - val_loss: 0.9863 - val_accuracy: 0.7228 - val_auc: 0.7428
#
# Epoch 00167: saving model to History/model.epoch167.hdf5
# Epoch 168/200
# 141/141 [==============================] - 13s 90ms/step - loss: 0.3825 - accuracy: 0.8501 - auc: 0.9403 - val_loss: 0.9427 - val_accuracy: 0.6832 - val_auc: 0.7146
#
# Epoch 00168: saving model to History/model.epoch168.hdf5
# Epoch 169/200
# 141/141 [==============================] - 14s 98ms/step - loss: 0.3412 - accuracy: 0.8583 - auc: 0.9577 - val_loss: 0.9777 - val_accuracy: 0.6832 - val_auc: 0.7111
#
# Epoch 00169: saving model to History/model.epoch169.hdf5
# Epoch 170/200
# 141/141 [==============================] - 15s 103ms/step - loss: 0.3078 - accuracy: 0.8918 - auc: 0.9673 - val_loss: 0.9722 - val_accuracy: 0.6733 - val_auc: 0.7015
#
# Epoch 00170: saving model to History/model.epoch170.hdf5
# Epoch 171/200
# 141/141 [==============================] - 15s 106ms/step - loss: 0.3771 - accuracy: 0.8581 - auc: 0.9452 - val_loss: 1.0026 - val_accuracy: 0.6634 - val_auc: 0.7010
#
# Epoch 00171: saving model to History/model.epoch171.hdf5
# Epoch 172/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.3742 - accuracy: 0.8877 - auc: 0.9486 - val_loss: 1.2254 - val_accuracy: 0.5347 - val_auc: 0.5671
#
# Epoch 00172: saving model to History/model.epoch172.hdf5
# Epoch 173/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.4149 - accuracy: 0.8609 - auc: 0.9234 - val_loss: 1.0013 - val_accuracy: 0.6337 - val_auc: 0.6867
#
# Epoch 00173: saving model to History/model.epoch173.hdf5
# Epoch 174/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3251 - accuracy: 0.9140 - auc: 0.9662 - val_loss: 0.9961 - val_accuracy: 0.6733 - val_auc: 0.7031
#
# Epoch 00174: saving model to History/model.epoch174.hdf5
# Epoch 175/200
# 141/141 [==============================] - 13s 89ms/step - loss: 0.3408 - accuracy: 0.8751 - auc: 0.9578 - val_loss: 1.0904 - val_accuracy: 0.5743 - val_auc: 0.6284
#
# Epoch 00175: saving model to History/model.epoch175.hdf5
# Epoch 176/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3531 - accuracy: 0.8854 - auc: 0.9534 - val_loss: 0.9490 - val_accuracy: 0.7129 - val_auc: 0.7239
#
# Epoch 00176: saving model to History/model.epoch176.hdf5
# Epoch 177/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3072 - accuracy: 0.8988 - auc: 0.9685 - val_loss: 0.9631 - val_accuracy: 0.6931 - val_auc: 0.7337
#
# Epoch 00177: saving model to History/model.epoch177.hdf5
# Epoch 178/200
# 141/141 [==============================] - 15s 103ms/step - loss: 0.3464 - accuracy: 0.8993 - auc: 0.9588 - val_loss: 0.8976 - val_accuracy: 0.7030 - val_auc: 0.7451
#
# Epoch 00178: saving model to History/model.epoch178.hdf5
# Epoch 179/200
# 141/141 [==============================] - 16s 112ms/step - loss: 0.3688 - accuracy: 0.8754 - auc: 0.9534 - val_loss: 1.0126 - val_accuracy: 0.6832 - val_auc: 0.6973
#
# Epoch 00179: saving model to History/model.epoch179.hdf5
# Epoch 180/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3210 - accuracy: 0.8976 - auc: 0.9648 - val_loss: 1.0800 - val_accuracy: 0.6139 - val_auc: 0.6523
#
# Epoch 00180: saving model to History/model.epoch180.hdf5
# Epoch 181/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3430 - accuracy: 0.8850 - auc: 0.9546 - val_loss: 0.9414 - val_accuracy: 0.6733 - val_auc: 0.7195
#
# Epoch 00181: saving model to History/model.epoch181.hdf5
# Epoch 182/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3347 - accuracy: 0.8850 - auc: 0.9580 - val_loss: 0.9385 - val_accuracy: 0.7030 - val_auc: 0.7310
#
# Epoch 00182: saving model to History/model.epoch182.hdf5
# Epoch 183/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3349 - accuracy: 0.8806 - auc: 0.9627 - val_loss: 0.9629 - val_accuracy: 0.7129 - val_auc: 0.7154
#
# Epoch 00183: saving model to History/model.epoch183.hdf5
# Epoch 184/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.2956 - accuracy: 0.9144 - auc: 0.9756 - val_loss: 1.2017 - val_accuracy: 0.5842 - val_auc: 0.6096
#
# Epoch 00184: saving model to History/model.epoch184.hdf5
# Epoch 185/200
# 141/141 [==============================] - 12s 87ms/step - loss: 0.3501 - accuracy: 0.8780 - auc: 0.9532 - val_loss: 0.9969 - val_accuracy: 0.7129 - val_auc: 0.7470
#
# Epoch 00185: saving model to History/model.epoch185.hdf5
# Epoch 186/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3544 - accuracy: 0.8854 - auc: 0.9533 - val_loss: 1.0294 - val_accuracy: 0.7030 - val_auc: 0.7512
#
# Epoch 00186: saving model to History/model.epoch186.hdf5
# Epoch 187/200
# 141/141 [==============================] - 17s 124ms/step - loss: 0.3411 - accuracy: 0.8841 - auc: 0.9669 - val_loss: 0.9769 - val_accuracy: 0.6931 - val_auc: 0.7262
#
# Epoch 00187: saving model to History/model.epoch187.hdf5
# Epoch 188/200
# 141/141 [==============================] - 14s 96ms/step - loss: 0.3544 - accuracy: 0.8776 - auc: 0.9540 - val_loss: 1.0145 - val_accuracy: 0.6931 - val_auc: 0.6918
#
# Epoch 00188: saving model to History/model.epoch188.hdf5
# Epoch 189/200
# 141/141 [==============================] - 14s 100ms/step - loss: 0.3105 - accuracy: 0.9102 - auc: 0.9679 - val_loss: 1.0534 - val_accuracy: 0.6535 - val_auc: 0.6887
#
# Epoch 00189: saving model to History/model.epoch189.hdf5
# Epoch 190/200
# 141/141 [==============================] - 16s 116ms/step - loss: 0.3449 - accuracy: 0.9005 - auc: 0.9584 - val_loss: 1.0580 - val_accuracy: 0.6931 - val_auc: 0.6786
#
# Epoch 00190: saving model to History/model.epoch190.hdf5
# Epoch 191/200
# 141/141 [==============================] - 13s 94ms/step - loss: 0.3130 - accuracy: 0.9071 - auc: 0.9676 - val_loss: 1.0265 - val_accuracy: 0.7129 - val_auc: 0.7345
#
# Epoch 00191: saving model to History/model.epoch191.hdf5
# Epoch 192/200
# 141/141 [==============================] - 16s 110ms/step - loss: 0.3188 - accuracy: 0.8840 - auc: 0.9616 - val_loss: 1.0553 - val_accuracy: 0.6931 - val_auc: 0.6880
#
# Epoch 00192: saving model to History/model.epoch192.hdf5
# Epoch 193/200
# 141/141 [==============================] - 13s 92ms/step - loss: 0.3001 - accuracy: 0.9220 - auc: 0.9708 - val_loss: 1.0203 - val_accuracy: 0.7030 - val_auc: 0.7114
#
# Epoch 00193: saving model to History/model.epoch193.hdf5
# Epoch 194/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3066 - accuracy: 0.9130 - auc: 0.9734 - val_loss: 1.1111 - val_accuracy: 0.6535 - val_auc: 0.6887
#
# Epoch 00194: saving model to History/model.epoch194.hdf5
# Epoch 195/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.3259 - accuracy: 0.8957 - auc: 0.9642 - val_loss: 1.0511 - val_accuracy: 0.6931 - val_auc: 0.7252
#
# Epoch 00195: saving model to History/model.epoch195.hdf5
# Epoch 196/200
# 141/141 [==============================] - 12s 86ms/step - loss: 0.4022 - accuracy: 0.8621 - auc: 0.9376 - val_loss: 0.9630 - val_accuracy: 0.7228 - val_auc: 0.7323
#
# Epoch 00196: saving model to History/model.epoch196.hdf5
# Epoch 197/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.2838 - accuracy: 0.9109 - auc: 0.9757 - val_loss: 0.9775 - val_accuracy: 0.6931 - val_auc: 0.7100
#
# Epoch 00197: saving model to History/model.epoch197.hdf5
# Epoch 198/200
# 141/141 [==============================] - 12s 88ms/step - loss: 0.3291 - accuracy: 0.8844 - auc: 0.9620 - val_loss: 1.0675 - val_accuracy: 0.6832 - val_auc: 0.6937
#
# Epoch 00198: saving model to History/model.epoch198.hdf5
# Epoch 199/200
# 141/141 [==============================] - 14s 96ms/step - loss: 0.3247 - accuracy: 0.8930 - auc: 0.9650 - val_loss: 1.0428 - val_accuracy: 0.6931 - val_auc: 0.7241
#
# Epoch 00199: saving model to History/model.epoch199.hdf5
# Epoch 200/200
# 141/141 [==============================] - 13s 95ms/step - loss: 0.3047 - accuracy: 0.9061 - auc: 0.9693 - val_loss: 0.9744 - val_accuracy: 0.6931 - val_auc: 0.7294
#
# Epoch 00200: saving model to History/model.epoch200.hdf5
