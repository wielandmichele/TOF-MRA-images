# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.6/dist-packages (0.12.2)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.5.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.19.4)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels) (2021.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import pandas as pd
import zipfile
import numpy as np
import tensorflow as tf
import h5py
import random
from scipy import ndimage
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import sklearn
import tempfile
import datetime
from statsmodels.stats.proportion import proportion_confint
from functions.auc_delong_xu import auc_ci_Delong

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import to_categorical
from keras.layers.merge import concatenate
from tensorflow.keras import regularizers

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session
import gc

from keras import backend as K

# %%
tf.__version__
# Out:
# '2.4.0'

# %% [markdown]
# ### Import data from HD5File

# %% [markdown]
# Checking the data

# %%
PATH_3D_H5 = 'Images/preprocessed_data_128_112_40.hdf5'
with h5py.File(PATH_3D_H5, 'r') as h5:
    print('H5-file: ', list(h5.keys()))

     # Training data
    X_train = h5["X_train"][:]
    Y_train = h5["Y_train"][:]
    pat_train = h5["pat_train"][:]

    # Test
    X_test = h5["X_test"][:]
    Y_test = h5["Y_test"][:]
    pat_test = h5["pat_test"][:]

print(X_train.shape, X_train.min(), X_train.max(), X_train.mean(), X_train.std(), Y_train.shape)
print(X_test.shape, X_test.min(), X_test.max(), X_test.mean(), X_test.std(), Y_test.shape)
# Out:
# H5-file:  ['X_test', 'X_train', 'Y_test', 'Y_train', 'pat_test', 'pat_train']
# (407, 128, 112, 40, 1) -1.5907471988589987 26.031565772467758 2.723923812611388e-18 0.9999999999999996 (407, 2)
# (101, 128, 112, 40, 1) -1.5879721448660902 21.687867391483003 -4.553955829438408e-19 1.0000000000000024 (101, 2)

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# Zoom images

# %%
# zoom
def random_zoom3d(X_im, min_zoom, max_zoom):
    z = np.random.sample() *(max_zoom-min_zoom) + min_zoom
    zoom_matrix = np.array([[z, 0, 0, 0],
                            [0, z, 0, 0],
                            [0, 0, z, 0],
                            [0, 0, 0, 1]])
    return ndimage.affine_transform(X_im, zoom_matrix, mode = "nearest", order = 1)

# %%
x = X_train[0]
X_aug = random_zoom3d(x, 0.8,1.00)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Rotate images

# %%
# rotate
def random_rotate3d(X_im, min_angle_xy, max_angle_xy, min_angle_xz, max_angle_xz, min_angle_yz, max_angle_yz):
    angle_xy = np.random.uniform(min_angle_xy, max_angle_xy)
    angle_xz = np.random.uniform(min_angle_xz, max_angle_xz)
    angle_yz = np.random.uniform(min_angle_yz, max_angle_yz)
    rotation_axis = np.random.choice([0,1,2])
    if(rotation_axis == 0):
        X_im = ndimage.rotate(X_im, angle = angle_xy, axes = (0,1), mode = "nearest", reshape = False, order = 3)
    if(rotation_axis == 1):
        X_im = ndimage.rotate(X_im, angle = angle_xz, axes = (0,2), mode = "nearest", reshape = False, order = 3)
    if(rotation_axis == 2):
        X_im = ndimage.rotate(X_im, angle = angle_yz, axes = (1,2), mode = "nearest", reshape = False, order = 3)
    return X_im

# %%
x = X_train[0]
X_aug = random_rotate3d(x, -20, 20, -10, 10, -5, 5)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Shifting images

# %%
# shifting
def random_shift3d(X_im, min_shift_x, max_shift_x, min_shift_y, max_shift_y, min_shift_z, max_shift_z):
    x_shift = np.random.uniform(min_shift_x, max_shift_x)
    y_shift = np.random.uniform(min_shift_y, max_shift_y)
    z_shift = np.random.uniform(min_shift_z, max_shift_z)
    return ndimage.shift(X_im, [x_shift, y_shift, z_shift, 0], mode = "nearest", order = 0)

# %%
x = X_train[0]
X_aug = random_shift3d(x, -10, 10, -10, 10, 0, 0)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Flipping images

# %%
def random_flip3d(X_im):
    axis = np.random.choice([0,1])
    if(axis == 0): # vertical flip
        X_im = X_im[:,::-1,:,:]
        # X_im = X_im[::-1,:,:,:] #horizontal
        # X_im = np.asarray(X_im).swapaxes(0, 1)#left, right flip
    return X_im

# %%
x = X_train[0]
X_aug = random_flip3d(x)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %% [markdown]
# Gauss filter

# %%
# Gauss filter (Glättung, Mittelwertberechnung per Pixel basierend auf umgebenden Pixeln ausgewählt mit Gaussfkt.)
def random_gaussianfilter3d(X_im, sigma_max):
    sigma = np.random.uniform(0, sigma_max)
    return ndimage.gaussian_filter(X_im, sigma, mode = "nearest")

# %%
x = X_train[0]
X_aug = random_gaussianfilter3d(x, 0.2)
fig, axis= plt.subplots(1,2, figsize = (7,10))

axis[0].imshow(np.squeeze(x[:, :, 10]), cmap="gray")
axis[1].imshow(np.squeeze(X_aug[:,:,10]), cmap="gray")

# %%
@tf.function
def augment_3d_many(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        if IMAGE_DIMENSION == (128, 112, 64):
            #volume = random_zoom3d(volume, 0.8, 1.3)
            volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            volume = random_shift3d(volume, -20, 20, -20, 20, 0, 0) #do not shift in z direction
            #volume = random_flip3d(volume)
            #volume = random_gaussianfilter3d(volume, 0.2)
            
        if IMAGE_DIMENSION == (96,84,30):
            volume = random_zoom3d(volume, 0.90,1.1)
            volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0)
            volume = random_flip3d(volume)
            volume = random_gaussianfilter3d(volume, 0.2)
            
        if IMAGE_DIMENSION == (64,56,20):
            #volume = random_zoom3d(volume, 0.95,1.05) 
            volume = random_rotate3d(volume, -10, 10, -5, 5, -5, 5)
            volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
            #volume = random_flip3d(volume)
            #volume = random_gaussianfilter3d(volume, 0.2)
            
        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
@tf.function
def augment_3d_one(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        rand = np.random.randint(0,6)
        
        if IMAGE_DIMENSION == (128, 112, 40):
            if rand == 0:
                volume = random_zoom3d(volume, 0.8, 1.3)
            if rand == 1:
                volume = random_rotate3d(volume, -20, 20, -5, 5, -5, 5)
            if rand == 2:
                volume = random_shift3d(volume, -20, 20, -20, 20, 0, 0) #do not shift in z direction
            if rand == 3:
                volume = random_flip3d(volume)
            if rand == 4:
                volume = random_gaussianfilter3d(volume, 0.2)
            if rand == 5:
                volume = volume
            
        if IMAGE_DIMENSION == (64,56,20):
            if rand == 0:
                volume = random_zoom3d(volume, 0.8,1.00) 
            if rand == 1:
                volume = random_rotate3d(volume, -20, 20, -10, 10, 0, 0)
            if rand == 2:
                #volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
                volume = random_shift3d(volume, -10, 10, -10, 10, 0, 0) #do not shift in z direction
            if rand == 3:
                volume = random_flip3d(volume)
            if rand == 4:
                volume = random_gaussianfilter3d(volume, 0.2)
            if rand == 5:
                volume = volume

        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
@tf.function
def augment_3d_two(volume):
    """Rotate the volume by a few degrees"""

    def augment(volume):
        rand = np.random.randint(0,6, size = 2)
            
        if IMAGE_DIMENSION == (64,56,20):
            if 0 in rand:
                volume = volume
                rand = np.array([0,0])
            if 1 in rand:
                volume = random_rotate3d(volume, -20, 20, -10, 10, 0, 0)
            if 2 in rand:
                #volume = random_shift3d(volume, -5, 5, -5, 5, 0, 0) #do not shift in z direction
                volume = random_shift3d(volume, -10, 10, -10, 10, 0, 0) #do not shift in z direction
            if 3 in rand:
                volume = random_flip3d(volume)
            if 4 in rand:
                volume = random_gaussianfilter3d(volume, 0.2)
            if 5 in rand:
                volume = random_zoom3d(volume, 0.8,1.00) 

        return volume
    
    volume_shape = volume.shape
    augmented_volume = tf.numpy_function(augment, [volume], np.float64)
    augmented_volume = tf.reshape(augmented_volume, volume_shape)
    return augmented_volume

# %%
def train_preprocessing(volume, label):
    volume = augment_3d_one(volume)
    return volume, label

# %% [markdown]
# Balanced dataset with tf.data

# %%
bool_train_labels = Y_train[:,1] != 0
pos_features = X_train[bool_train_labels]
neg_features = X_train[~bool_train_labels]
pos_labels = Y_train[bool_train_labels]
neg_labels = Y_train[~bool_train_labels]

# %%
def make_ds(features, labels):
  ds = tf.data.Dataset.from_tensor_slices((features, labels))#.cache()
  ds = ds.shuffle(len(pos_features)*2).repeat()
  return ds

pos_ds = make_ds(pos_features, pos_labels)
neg_ds = make_ds(neg_features, neg_labels)

# %%
resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5])
validation_loader = tf.data.Dataset.from_tensor_slices((X_test, Y_test))

batch_size = 2
# Augment the on the fly during training.
resampled_data = (
    
    resampled_ds.shuffle(buffer_size = (len(pos_features)*2), reshuffle_each_iteration=True)
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(X_test))
    .batch(batch_size)
    .prefetch(2)
)

# %%
pos = len(pos_features)
neg = len(neg_features)
total = pos + neg
resampled_steps_per_epoch = np.ceil(2.0*pos/batch_size)
resampled_steps_per_epoch
# Out:
# 281.0

# %%
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.62
# Weight for class 1: 0.72

# %% [markdown]
# ### Train CNN

# %%
IMAGE_DIMENSION = (128,112,40)
w = IMAGE_DIMENSION[0]
h = IMAGE_DIMENSION[1]
d = IMAGE_DIMENSION[2]

# %%
def get_model(width=w, height=h, depth=d):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=8, kernel_size=3, activation="relu", padding = 'same')(inputs)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=16, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu", padding = 'same')(x)
    x = layers.AveragePooling3D(pool_size = 2, padding = 'same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Flatten()(x)
    
    x = layers.Dense(units=64, activation="relu", kernel_regularizer=regularizers.l2(0.001))(x)
    #x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.01)(x)

    outputs = layers.Dense(units=2, activation="softmax")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")

    return model

# %%
# Build model softmax
model = get_model(width=w, height=h, depth=d)
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 112, 40, 1)] 0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 128, 112, 40, 8)   224
# _________________________________________________________________
# average_pooling3d_5 (Average (None, 64, 56, 20, 8)     0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 56, 20, 8)     32
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 64, 56, 20, 16)    3472
# _________________________________________________________________
# average_pooling3d_6 (Average (None, 32, 28, 10, 16)    0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 28, 10, 16)    64
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 32, 28, 10, 32)    13856
# _________________________________________________________________
# average_pooling3d_7 (Average (None, 16, 14, 5, 32)     0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 14, 5, 32)     128
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 16, 14, 5, 32)     27680
# _________________________________________________________________
# average_pooling3d_8 (Average (None, 8, 7, 2, 32)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 7, 2, 32)       128
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 8, 7, 2, 64)       55360
# _________________________________________________________________
# average_pooling3d_9 (Average (None, 4, 4, 1, 64)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 1, 64)       256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                65600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 166,930
# Trainable params: 166,626
# Non-trainable params: 304
# _________________________________________________________________

# %%
### define metrics
reset_keras()
metrics = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc')]

### prepare files for logging
if os.path.exists('results.csv'):
    os.remove('results.csv')
    
shutil.rmtree('History')
os.makedirs('History')
    
filepath = 'History/model.epoch{epoch:02d}.hdf5'
    
### define callback_list
callback_list = [
    keras.callbacks.ModelCheckpoint(filepath=filepath, save_freq='epoch', verbose=1), 
    keras.callbacks.CSVLogger('results.csv')]
    
model.compile(loss = "categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate =  0.00001),
              #optimizer = keras.optimizers.RMSprop(learning_rate = 0.00001),
              metrics = metrics)
# Out:
# 43911

# %%
 def reset_keras():
        """
        Resets the Tensorflow graph and clears the session. Should be executed after eevery traning session with a model.

        :return:
        """
        sess = tf.compat.v1.keras.backend.get_session()
        tf.keras.backend.clear_session()
        sess.close()
        sess = tf.compat.v1.keras.backend.get_session()

        try:
            del model # this is from global space - change this as you need
        except:
            pass

        print(gc.collect()) # if it's done something you should see a number being outputted

        # use the same config as you used to create the session
        config = ConfigProto()
        config.gpu_options.per_process_gpu_memory_fraction = 1
        config.gpu_options.visible_device_list = "0"
        tf.compat.v1.keras.backend.set_session(Session(config=config))

# %% [markdown]
# ### Balanced model

# %%
epochs = 200
hist = model.fit(
    resampled_data,
    validation_data=validation_dataset,
    epochs=epochs,
    verbose=1, callbacks=callback_list, 
    steps_per_epoch = resampled_steps_per_epoch,
    class_weight = class_weight)
# Out:
# Epoch 1/200
# 281/281 [==============================] - 62s 194ms/step - loss: 0.9477 - accuracy: 0.4799 - auc: 0.4893 - val_loss: 1.3164 - val_accuracy: 0.3069 - val_auc: 0.3407
#
# Epoch 00001: saving model to History/model.epoch01.hdf5
# Epoch 2/200
# 281/281 [==============================] - 60s 213ms/step - loss: 0.8690 - accuracy: 0.5841 - auc: 0.5634 - val_loss: 1.1986 - val_accuracy: 0.3168 - val_auc: 0.3362
#
# Epoch 00002: saving model to History/model.epoch02.hdf5
# Epoch 3/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.8495 - accuracy: 0.5620 - auc: 0.5664 - val_loss: 1.0644 - val_accuracy: 0.3465 - val_auc: 0.3249
#
# Epoch 00003: saving model to History/model.epoch03.hdf5
# Epoch 4/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.8530 - accuracy: 0.5173 - auc: 0.5504 - val_loss: 1.0425 - val_accuracy: 0.3465 - val_auc: 0.3410
#
# Epoch 00004: saving model to History/model.epoch04.hdf5
# Epoch 5/200
# 281/281 [==============================] - 60s 212ms/step - loss: 0.8566 - accuracy: 0.5104 - auc: 0.5254 - val_loss: 1.2204 - val_accuracy: 0.3069 - val_auc: 0.3304
#
# Epoch 00005: saving model to History/model.epoch05.hdf5
# Epoch 6/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.8239 - accuracy: 0.5515 - auc: 0.6016 - val_loss: 1.2525 - val_accuracy: 0.3168 - val_auc: 0.3389
#
# Epoch 00006: saving model to History/model.epoch06.hdf5
# Epoch 7/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.8460 - accuracy: 0.5182 - auc: 0.5496 - val_loss: 1.0696 - val_accuracy: 0.3366 - val_auc: 0.3447
#
# Epoch 00007: saving model to History/model.epoch07.hdf5
# Epoch 8/200
# 281/281 [==============================] - 55s 198ms/step - loss: 0.8164 - accuracy: 0.5360 - auc: 0.5758 - val_loss: 0.9852 - val_accuracy: 0.4158 - val_auc: 0.3813
#
# Epoch 00008: saving model to History/model.epoch08.hdf5
# Epoch 9/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.8208 - accuracy: 0.5681 - auc: 0.5887 - val_loss: 1.1071 - val_accuracy: 0.3168 - val_auc: 0.3603
#
# Epoch 00009: saving model to History/model.epoch09.hdf5
# Epoch 10/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.7905 - accuracy: 0.5348 - auc: 0.6086 - val_loss: 1.0482 - val_accuracy: 0.3663 - val_auc: 0.3588
#
# Epoch 00010: saving model to History/model.epoch10.hdf5
# Epoch 11/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.8086 - accuracy: 0.5617 - auc: 0.5994 - val_loss: 0.9237 - val_accuracy: 0.4554 - val_auc: 0.4235
#
# Epoch 00011: saving model to History/model.epoch11.hdf5
# Epoch 12/200
# 281/281 [==============================] - 60s 214ms/step - loss: 0.7750 - accuracy: 0.5869 - auc: 0.6509 - val_loss: 0.9424 - val_accuracy: 0.4554 - val_auc: 0.4338
#
# Epoch 00012: saving model to History/model.epoch12.hdf5
# Epoch 13/200
# 281/281 [==============================] - 57s 201ms/step - loss: 0.7912 - accuracy: 0.5790 - auc: 0.6207 - val_loss: 0.9756 - val_accuracy: 0.4059 - val_auc: 0.4075
#
# Epoch 00013: saving model to History/model.epoch13.hdf5
# Epoch 14/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.7592 - accuracy: 0.5897 - auc: 0.6537 - val_loss: 0.9863 - val_accuracy: 0.4554 - val_auc: 0.4163
#
# Epoch 00014: saving model to History/model.epoch14.hdf5
# Epoch 15/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.7819 - accuracy: 0.5724 - auc: 0.6307 - val_loss: 0.9482 - val_accuracy: 0.4851 - val_auc: 0.4413
#
# Epoch 00015: saving model to History/model.epoch15.hdf5
# Epoch 16/200
# 281/281 [==============================] - 56s 198ms/step - loss: 0.7578 - accuracy: 0.6199 - auc: 0.6766 - val_loss: 1.0920 - val_accuracy: 0.3564 - val_auc: 0.3633
#
# Epoch 00016: saving model to History/model.epoch16.hdf5
# Epoch 17/200
# 281/281 [==============================] - 56s 198ms/step - loss: 0.7471 - accuracy: 0.5848 - auc: 0.6599 - val_loss: 0.9144 - val_accuracy: 0.4356 - val_auc: 0.4438
#
# Epoch 00017: saving model to History/model.epoch17.hdf5
# Epoch 18/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.7278 - accuracy: 0.6177 - auc: 0.6944 - val_loss: 0.9752 - val_accuracy: 0.4158 - val_auc: 0.4225
#
# Epoch 00018: saving model to History/model.epoch18.hdf5
# Epoch 19/200
# 281/281 [==============================] - 55s 198ms/step - loss: 0.7175 - accuracy: 0.6466 - auc: 0.7152 - val_loss: 0.9473 - val_accuracy: 0.4554 - val_auc: 0.4513
#
# Epoch 00019: saving model to History/model.epoch19.hdf5
# Epoch 20/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.7160 - accuracy: 0.6437 - auc: 0.7021 - val_loss: 0.9745 - val_accuracy: 0.4455 - val_auc: 0.4366
#
# Epoch 00020: saving model to History/model.epoch20.hdf5
# Epoch 21/200
# 281/281 [==============================] - 54s 192ms/step - loss: 0.7062 - accuracy: 0.6548 - auc: 0.7109 - val_loss: 0.8857 - val_accuracy: 0.5446 - val_auc: 0.5117
#
# Epoch 00021: saving model to History/model.epoch21.hdf5
# Epoch 22/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.6835 - accuracy: 0.6821 - auc: 0.7587 - val_loss: 0.9089 - val_accuracy: 0.5050 - val_auc: 0.4842
#
# Epoch 00022: saving model to History/model.epoch22.hdf5
# Epoch 23/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.6601 - accuracy: 0.6774 - auc: 0.7672 - val_loss: 1.0461 - val_accuracy: 0.4257 - val_auc: 0.3957
#
# Epoch 00023: saving model to History/model.epoch23.hdf5
# Epoch 24/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.6850 - accuracy: 0.6678 - auc: 0.7279 - val_loss: 1.0429 - val_accuracy: 0.4455 - val_auc: 0.4273
#
# Epoch 00024: saving model to History/model.epoch24.hdf5
# Epoch 25/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.6889 - accuracy: 0.6388 - auc: 0.7233 - val_loss: 1.0112 - val_accuracy: 0.4158 - val_auc: 0.4232
#
# Epoch 00025: saving model to History/model.epoch25.hdf5
# Epoch 26/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.6578 - accuracy: 0.7090 - auc: 0.7619 - val_loss: 0.9492 - val_accuracy: 0.4752 - val_auc: 0.4521
#
# Epoch 00026: saving model to History/model.epoch26.hdf5
# Epoch 27/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.6508 - accuracy: 0.6649 - auc: 0.7681 - val_loss: 0.9216 - val_accuracy: 0.5050 - val_auc: 0.4947
#
# Epoch 00027: saving model to History/model.epoch27.hdf5
# Epoch 28/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.6277 - accuracy: 0.7211 - auc: 0.7985 - val_loss: 0.7731 - val_accuracy: 0.6238 - val_auc: 0.6788
#
# Epoch 00028: saving model to History/model.epoch28.hdf5
# Epoch 29/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.6298 - accuracy: 0.7240 - auc: 0.8040 - val_loss: 0.8386 - val_accuracy: 0.5941 - val_auc: 0.5917
#
# Epoch 00029: saving model to History/model.epoch29.hdf5
# Epoch 30/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.6448 - accuracy: 0.6909 - auc: 0.7912 - val_loss: 1.0773 - val_accuracy: 0.4257 - val_auc: 0.4294
#
# Epoch 00030: saving model to History/model.epoch30.hdf5
# Epoch 31/200
# 281/281 [==============================] - 56s 198ms/step - loss: 0.6132 - accuracy: 0.7044 - auc: 0.8033 - val_loss: 1.1161 - val_accuracy: 0.4059 - val_auc: 0.4152
#
# Epoch 00031: saving model to History/model.epoch31.hdf5
# Epoch 32/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.5826 - accuracy: 0.7208 - auc: 0.8245 - val_loss: 0.9409 - val_accuracy: 0.5050 - val_auc: 0.5176
#
# Epoch 00032: saving model to History/model.epoch32.hdf5
# Epoch 33/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.5577 - accuracy: 0.7817 - auc: 0.8616 - val_loss: 0.9466 - val_accuracy: 0.5248 - val_auc: 0.5262
#
# Epoch 00033: saving model to History/model.epoch33.hdf5
# Epoch 34/200
# 281/281 [==============================] - 57s 205ms/step - loss: 0.5949 - accuracy: 0.7324 - auc: 0.8302 - val_loss: 0.9588 - val_accuracy: 0.4851 - val_auc: 0.5044
#
# Epoch 00034: saving model to History/model.epoch34.hdf5
# Epoch 35/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.6269 - accuracy: 0.7123 - auc: 0.8028 - val_loss: 0.7535 - val_accuracy: 0.6436 - val_auc: 0.6972
#
# Epoch 00035: saving model to History/model.epoch35.hdf5
# Epoch 36/200
# 281/281 [==============================] - 59s 210ms/step - loss: 0.5726 - accuracy: 0.7686 - auc: 0.8714 - val_loss: 0.7910 - val_accuracy: 0.6436 - val_auc: 0.6654
#
# Epoch 00036: saving model to History/model.epoch36.hdf5
# Epoch 37/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.5931 - accuracy: 0.7584 - auc: 0.8394 - val_loss: 0.9043 - val_accuracy: 0.5446 - val_auc: 0.5437
#
# Epoch 00037: saving model to History/model.epoch37.hdf5
# Epoch 38/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.6060 - accuracy: 0.7172 - auc: 0.8173 - val_loss: 0.8291 - val_accuracy: 0.6337 - val_auc: 0.6348
#
# Epoch 00038: saving model to History/model.epoch38.hdf5
# Epoch 39/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.5953 - accuracy: 0.7686 - auc: 0.8275 - val_loss: 0.8231 - val_accuracy: 0.5941 - val_auc: 0.6337
#
# Epoch 00039: saving model to History/model.epoch39.hdf5
# Epoch 40/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.5542 - accuracy: 0.7891 - auc: 0.8702 - val_loss: 0.9928 - val_accuracy: 0.4851 - val_auc: 0.5061
#
# Epoch 00040: saving model to History/model.epoch40.hdf5
# Epoch 41/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.5585 - accuracy: 0.7619 - auc: 0.8546 - val_loss: 0.8133 - val_accuracy: 0.6634 - val_auc: 0.6537
#
# Epoch 00041: saving model to History/model.epoch41.hdf5
# Epoch 42/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.5622 - accuracy: 0.7985 - auc: 0.8503 - val_loss: 0.8321 - val_accuracy: 0.6238 - val_auc: 0.6296
#
# Epoch 00042: saving model to History/model.epoch42.hdf5
# Epoch 43/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.5158 - accuracy: 0.8143 - auc: 0.8939 - val_loss: 0.8861 - val_accuracy: 0.5545 - val_auc: 0.5961
#
# Epoch 00043: saving model to History/model.epoch43.hdf5
# Epoch 44/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.5311 - accuracy: 0.7928 - auc: 0.8787 - val_loss: 0.7784 - val_accuracy: 0.6436 - val_auc: 0.6841
#
# Epoch 00044: saving model to History/model.epoch44.hdf5
# Epoch 45/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.5173 - accuracy: 0.8238 - auc: 0.9015 - val_loss: 0.8193 - val_accuracy: 0.5842 - val_auc: 0.6442
#
# Epoch 00045: saving model to History/model.epoch45.hdf5
# Epoch 46/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.5249 - accuracy: 0.8097 - auc: 0.8864 - val_loss: 0.9066 - val_accuracy: 0.5743 - val_auc: 0.5827
#
# Epoch 00046: saving model to History/model.epoch46.hdf5
# Epoch 47/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.5106 - accuracy: 0.8268 - auc: 0.8926 - val_loss: 0.8379 - val_accuracy: 0.6337 - val_auc: 0.6539
#
# Epoch 00047: saving model to History/model.epoch47.hdf5
# Epoch 48/200
# 281/281 [==============================] - 57s 201ms/step - loss: 0.5365 - accuracy: 0.7942 - auc: 0.8761 - val_loss: 0.8527 - val_accuracy: 0.6139 - val_auc: 0.6348
#
# Epoch 00048: saving model to History/model.epoch48.hdf5
# Epoch 49/200
# 281/281 [==============================] - 61s 217ms/step - loss: 0.5429 - accuracy: 0.7616 - auc: 0.8649 - val_loss: 0.8083 - val_accuracy: 0.6436 - val_auc: 0.6622
#
# Epoch 00049: saving model to History/model.epoch49.hdf5
# Epoch 50/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4872 - accuracy: 0.8279 - auc: 0.9152 - val_loss: 0.8263 - val_accuracy: 0.6337 - val_auc: 0.6589
#
# Epoch 00050: saving model to History/model.epoch50.hdf5
# Epoch 51/200
# 281/281 [==============================] - 60s 212ms/step - loss: 0.5097 - accuracy: 0.8179 - auc: 0.8966 - val_loss: 0.9757 - val_accuracy: 0.5545 - val_auc: 0.5758
#
# Epoch 00051: saving model to History/model.epoch51.hdf5
# Epoch 52/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4700 - accuracy: 0.8319 - auc: 0.9149 - val_loss: 0.7521 - val_accuracy: 0.6832 - val_auc: 0.7162
#
# Epoch 00052: saving model to History/model.epoch52.hdf5
# Epoch 53/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.5201 - accuracy: 0.8195 - auc: 0.9005 - val_loss: 0.8012 - val_accuracy: 0.6535 - val_auc: 0.6854
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.5385 - accuracy: 0.8011 - auc: 0.8761 - val_loss: 0.7434 - val_accuracy: 0.6634 - val_auc: 0.7271
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.4712 - accuracy: 0.8503 - auc: 0.9212 - val_loss: 0.7658 - val_accuracy: 0.6634 - val_auc: 0.7154
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.5137 - accuracy: 0.8193 - auc: 0.8948 - val_loss: 0.9210 - val_accuracy: 0.6040 - val_auc: 0.6068
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.4662 - accuracy: 0.8237 - auc: 0.9164 - val_loss: 0.8446 - val_accuracy: 0.6337 - val_auc: 0.6423
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/200
# 281/281 [==============================] - 58s 208ms/step - loss: 0.4887 - accuracy: 0.8300 - auc: 0.9006 - val_loss: 0.7758 - val_accuracy: 0.6535 - val_auc: 0.7015
#
# Epoch 00058: saving model to History/model.epoch58.hdf5
# Epoch 59/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.4477 - accuracy: 0.8479 - auc: 0.9359 - val_loss: 0.7773 - val_accuracy: 0.6832 - val_auc: 0.7081
#
# Epoch 00059: saving model to History/model.epoch59.hdf5
# Epoch 60/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.5233 - accuracy: 0.8154 - auc: 0.8911 - val_loss: 0.7604 - val_accuracy: 0.6832 - val_auc: 0.7274
#
# Epoch 00060: saving model to History/model.epoch60.hdf5
# Epoch 61/200
# 281/281 [==============================] - 59s 212ms/step - loss: 0.4370 - accuracy: 0.8477 - auc: 0.9386 - val_loss: 0.7602 - val_accuracy: 0.6733 - val_auc: 0.7269
#
# Epoch 00061: saving model to History/model.epoch61.hdf5
# Epoch 62/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4450 - accuracy: 0.8398 - auc: 0.9376 - val_loss: 0.8520 - val_accuracy: 0.6535 - val_auc: 0.6569
#
# Epoch 00062: saving model to History/model.epoch62.hdf5
# Epoch 63/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.4713 - accuracy: 0.8638 - auc: 0.9289 - val_loss: 0.7503 - val_accuracy: 0.7030 - val_auc: 0.7492
#
# Epoch 00063: saving model to History/model.epoch63.hdf5
# Epoch 64/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.4954 - accuracy: 0.8036 - auc: 0.9085 - val_loss: 0.8412 - val_accuracy: 0.6337 - val_auc: 0.6719
#
# Epoch 00064: saving model to History/model.epoch64.hdf5
# Epoch 65/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.4546 - accuracy: 0.8316 - auc: 0.9258 - val_loss: 0.8593 - val_accuracy: 0.6535 - val_auc: 0.6553
#
# Epoch 00065: saving model to History/model.epoch65.hdf5
# Epoch 66/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.4134 - accuracy: 0.8601 - auc: 0.9392 - val_loss: 0.8225 - val_accuracy: 0.6733 - val_auc: 0.6900
#
# Epoch 00066: saving model to History/model.epoch66.hdf5
# Epoch 67/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.3941 - accuracy: 0.8795 - auc: 0.9614 - val_loss: 0.9843 - val_accuracy: 0.6040 - val_auc: 0.5833
#
# Epoch 00067: saving model to History/model.epoch67.hdf5
# Epoch 68/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4354 - accuracy: 0.8482 - auc: 0.9271 - val_loss: 0.8724 - val_accuracy: 0.6436 - val_auc: 0.6542
#
# Epoch 00068: saving model to History/model.epoch68.hdf5
# Epoch 69/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.4653 - accuracy: 0.8516 - auc: 0.9206 - val_loss: 0.8151 - val_accuracy: 0.6634 - val_auc: 0.6901
#
# Epoch 00069: saving model to History/model.epoch69.hdf5
# Epoch 70/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.4289 - accuracy: 0.8285 - auc: 0.9306 - val_loss: 0.8192 - val_accuracy: 0.6436 - val_auc: 0.6906
#
# Epoch 00070: saving model to History/model.epoch70.hdf5
# Epoch 71/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4275 - accuracy: 0.8715 - auc: 0.9443 - val_loss: 0.7800 - val_accuracy: 0.6634 - val_auc: 0.7372
#
# Epoch 00071: saving model to History/model.epoch71.hdf5
# Epoch 72/200
# 281/281 [==============================] - 58s 204ms/step - loss: 0.4212 - accuracy: 0.8649 - auc: 0.9361 - val_loss: 0.8313 - val_accuracy: 0.6436 - val_auc: 0.6916
#
# Epoch 00072: saving model to History/model.epoch72.hdf5
# Epoch 73/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4303 - accuracy: 0.8651 - auc: 0.9312 - val_loss: 0.8247 - val_accuracy: 0.6337 - val_auc: 0.7005
#
# Epoch 00073: saving model to History/model.epoch73.hdf5
# Epoch 74/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.4463 - accuracy: 0.8545 - auc: 0.9326 - val_loss: 0.7650 - val_accuracy: 0.7030 - val_auc: 0.7439
#
# Epoch 00074: saving model to History/model.epoch74.hdf5
# Epoch 75/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4505 - accuracy: 0.8424 - auc: 0.9185 - val_loss: 0.8425 - val_accuracy: 0.6634 - val_auc: 0.6888
#
# Epoch 00075: saving model to History/model.epoch75.hdf5
# Epoch 76/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4188 - accuracy: 0.8595 - auc: 0.9376 - val_loss: 0.7730 - val_accuracy: 0.6733 - val_auc: 0.7307
#
# Epoch 00076: saving model to History/model.epoch76.hdf5
# Epoch 77/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4013 - accuracy: 0.8913 - auc: 0.9492 - val_loss: 0.8312 - val_accuracy: 0.6436 - val_auc: 0.6999
#
# Epoch 00077: saving model to History/model.epoch77.hdf5
# Epoch 78/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.3766 - accuracy: 0.8761 - auc: 0.9637 - val_loss: 0.8643 - val_accuracy: 0.6436 - val_auc: 0.6619
#
# Epoch 00078: saving model to History/model.epoch78.hdf5
# Epoch 79/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.4080 - accuracy: 0.8455 - auc: 0.9416 - val_loss: 0.8637 - val_accuracy: 0.6238 - val_auc: 0.6696
#
# Epoch 00079: saving model to History/model.epoch79.hdf5
# Epoch 80/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.4337 - accuracy: 0.8432 - auc: 0.9267 - val_loss: 0.7768 - val_accuracy: 0.6931 - val_auc: 0.7254
#
# Epoch 00080: saving model to History/model.epoch80.hdf5
# Epoch 81/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3701 - accuracy: 0.9117 - auc: 0.9619 - val_loss: 0.8338 - val_accuracy: 0.6535 - val_auc: 0.6793
#
# Epoch 00081: saving model to History/model.epoch81.hdf5
# Epoch 82/200
# 281/281 [==============================] - 54s 193ms/step - loss: 0.3786 - accuracy: 0.8856 - auc: 0.9614 - val_loss: 0.7585 - val_accuracy: 0.6733 - val_auc: 0.7522
#
# Epoch 00082: saving model to History/model.epoch82.hdf5
# Epoch 83/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3544 - accuracy: 0.9243 - auc: 0.9697 - val_loss: 0.7967 - val_accuracy: 0.6436 - val_auc: 0.7201
#
# Epoch 00083: saving model to History/model.epoch83.hdf5
# Epoch 84/200
# 281/281 [==============================] - 59s 207ms/step - loss: 0.4211 - accuracy: 0.8481 - auc: 0.9213 - val_loss: 0.8151 - val_accuracy: 0.6436 - val_auc: 0.7124
#
# Epoch 00084: saving model to History/model.epoch84.hdf5
# Epoch 85/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3558 - accuracy: 0.8992 - auc: 0.9659 - val_loss: 0.8091 - val_accuracy: 0.6634 - val_auc: 0.7170
#
# Epoch 00085: saving model to History/model.epoch85.hdf5
# Epoch 86/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3783 - accuracy: 0.8674 - auc: 0.9535 - val_loss: 0.8129 - val_accuracy: 0.6634 - val_auc: 0.7032
#
# Epoch 00086: saving model to History/model.epoch86.hdf5
# Epoch 87/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.3757 - accuracy: 0.8692 - auc: 0.9473 - val_loss: 0.8023 - val_accuracy: 0.7228 - val_auc: 0.7300
#
# Epoch 00087: saving model to History/model.epoch87.hdf5
# Epoch 88/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.4077 - accuracy: 0.8546 - auc: 0.9408 - val_loss: 0.8941 - val_accuracy: 0.5842 - val_auc: 0.6573
#
# Epoch 00088: saving model to History/model.epoch88.hdf5
# Epoch 89/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.3663 - accuracy: 0.8932 - auc: 0.9553 - val_loss: 0.7795 - val_accuracy: 0.6733 - val_auc: 0.7442
#
# Epoch 00089: saving model to History/model.epoch89.hdf5
# Epoch 90/200
# 281/281 [==============================] - 58s 204ms/step - loss: 0.3954 - accuracy: 0.8768 - auc: 0.9496 - val_loss: 0.7628 - val_accuracy: 0.7129 - val_auc: 0.7574
#
# Epoch 00090: saving model to History/model.epoch90.hdf5
# Epoch 91/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.3940 - accuracy: 0.8658 - auc: 0.9491 - val_loss: 0.8078 - val_accuracy: 0.6832 - val_auc: 0.7384
#
# Epoch 00091: saving model to History/model.epoch91.hdf5
# Epoch 92/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3392 - accuracy: 0.8912 - auc: 0.9667 - val_loss: 0.8154 - val_accuracy: 0.6832 - val_auc: 0.7330
#
# Epoch 00092: saving model to History/model.epoch92.hdf5
# Epoch 93/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.3714 - accuracy: 0.8837 - auc: 0.9567 - val_loss: 0.8146 - val_accuracy: 0.7030 - val_auc: 0.7251
#
# Epoch 00093: saving model to History/model.epoch93.hdf5
# Epoch 94/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3503 - accuracy: 0.8906 - auc: 0.9620 - val_loss: 0.8265 - val_accuracy: 0.6832 - val_auc: 0.7312
#
# Epoch 00094: saving model to History/model.epoch94.hdf5
# Epoch 95/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3586 - accuracy: 0.9141 - auc: 0.9620 - val_loss: 0.9118 - val_accuracy: 0.6436 - val_auc: 0.6629
#
# Epoch 00095: saving model to History/model.epoch95.hdf5
# Epoch 96/200
# 281/281 [==============================] - 57s 201ms/step - loss: 0.3665 - accuracy: 0.8802 - auc: 0.9535 - val_loss: 0.8677 - val_accuracy: 0.6238 - val_auc: 0.6938
#
# Epoch 00096: saving model to History/model.epoch96.hdf5
# Epoch 97/200
# 281/281 [==============================] - 62s 220ms/step - loss: 0.3473 - accuracy: 0.9171 - auc: 0.9625 - val_loss: 0.7960 - val_accuracy: 0.6535 - val_auc: 0.7410
#
# Epoch 00097: saving model to History/model.epoch97.hdf5
# Epoch 98/200
# 281/281 [==============================] - 61s 217ms/step - loss: 0.3299 - accuracy: 0.8897 - auc: 0.9721 - val_loss: 0.8293 - val_accuracy: 0.6733 - val_auc: 0.7351
#
# Epoch 00098: saving model to History/model.epoch98.hdf5
# Epoch 99/200
# 281/281 [==============================] - 57s 205ms/step - loss: 0.3401 - accuracy: 0.9028 - auc: 0.9669 - val_loss: 0.8309 - val_accuracy: 0.6832 - val_auc: 0.7218
#
# Epoch 00099: saving model to History/model.epoch99.hdf5
# Epoch 100/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.3327 - accuracy: 0.8908 - auc: 0.9688 - val_loss: 0.9611 - val_accuracy: 0.6238 - val_auc: 0.6483
#
# Epoch 00100: saving model to History/model.epoch100.hdf5
# Epoch 101/200
# 281/281 [==============================] - 58s 208ms/step - loss: 0.3331 - accuracy: 0.8995 - auc: 0.9658 - val_loss: 0.8137 - val_accuracy: 0.7030 - val_auc: 0.7615
#
# Epoch 00101: saving model to History/model.epoch101.hdf5
# Epoch 102/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3615 - accuracy: 0.9081 - auc: 0.9613 - val_loss: 0.8643 - val_accuracy: 0.6634 - val_auc: 0.7033
#
# Epoch 00102: saving model to History/model.epoch102.hdf5
# Epoch 103/200
# 281/281 [==============================] - 55s 194ms/step - loss: 0.3599 - accuracy: 0.8850 - auc: 0.9579 - val_loss: 0.8091 - val_accuracy: 0.6634 - val_auc: 0.7369
#
# Epoch 00103: saving model to History/model.epoch103.hdf5
# Epoch 104/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.3031 - accuracy: 0.9336 - auc: 0.9795 - val_loss: 0.8124 - val_accuracy: 0.6931 - val_auc: 0.7441
#
# Epoch 00104: saving model to History/model.epoch104.hdf5
# Epoch 105/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3696 - accuracy: 0.8964 - auc: 0.9605 - val_loss: 1.0334 - val_accuracy: 0.6238 - val_auc: 0.6322
#
# Epoch 00105: saving model to History/model.epoch105.hdf5
# Epoch 106/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.3283 - accuracy: 0.9111 - auc: 0.9668 - val_loss: 0.9852 - val_accuracy: 0.6139 - val_auc: 0.6465
#
# Epoch 00106: saving model to History/model.epoch106.hdf5
# Epoch 107/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.3119 - accuracy: 0.9200 - auc: 0.9686 - val_loss: 0.8549 - val_accuracy: 0.6634 - val_auc: 0.7220
#
# Epoch 00107: saving model to History/model.epoch107.hdf5
# Epoch 108/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.3539 - accuracy: 0.8961 - auc: 0.9686 - val_loss: 0.8154 - val_accuracy: 0.6832 - val_auc: 0.7497
#
# Epoch 00108: saving model to History/model.epoch108.hdf5
# Epoch 109/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3289 - accuracy: 0.8969 - auc: 0.9706 - val_loss: 0.8021 - val_accuracy: 0.6535 - val_auc: 0.7510
#
# Epoch 00109: saving model to History/model.epoch109.hdf5
# Epoch 110/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.3110 - accuracy: 0.9121 - auc: 0.9771 - val_loss: 0.7989 - val_accuracy: 0.6832 - val_auc: 0.7581
#
# Epoch 00110: saving model to History/model.epoch110.hdf5
# Epoch 111/200
# 281/281 [==============================] - 59s 210ms/step - loss: 0.3171 - accuracy: 0.9268 - auc: 0.9733 - val_loss: 0.8030 - val_accuracy: 0.6535 - val_auc: 0.7547
#
# Epoch 00111: saving model to History/model.epoch111.hdf5
# Epoch 112/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3067 - accuracy: 0.9222 - auc: 0.9791 - val_loss: 0.8520 - val_accuracy: 0.6733 - val_auc: 0.7476
#
# Epoch 00112: saving model to History/model.epoch112.hdf5
# Epoch 113/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.2839 - accuracy: 0.9348 - auc: 0.9827 - val_loss: 0.8617 - val_accuracy: 0.6733 - val_auc: 0.7300
#
# Epoch 00113: saving model to History/model.epoch113.hdf5
# Epoch 114/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.3138 - accuracy: 0.9192 - auc: 0.9717 - val_loss: 0.8759 - val_accuracy: 0.6634 - val_auc: 0.7184
#
# Epoch 00114: saving model to History/model.epoch114.hdf5
# Epoch 115/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2966 - accuracy: 0.9204 - auc: 0.9788 - val_loss: 0.8898 - val_accuracy: 0.6634 - val_auc: 0.7020
#
# Epoch 00115: saving model to History/model.epoch115.hdf5
# Epoch 116/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.2867 - accuracy: 0.9286 - auc: 0.9818 - val_loss: 0.9299 - val_accuracy: 0.6733 - val_auc: 0.6828
#
# Epoch 00116: saving model to History/model.epoch116.hdf5
# Epoch 117/200
# 281/281 [==============================] - 60s 213ms/step - loss: 0.3130 - accuracy: 0.8863 - auc: 0.9673 - val_loss: 0.8335 - val_accuracy: 0.6832 - val_auc: 0.7461
#
# Epoch 00117: saving model to History/model.epoch117.hdf5
# Epoch 118/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.3687 - accuracy: 0.8799 - auc: 0.9557 - val_loss: 0.8850 - val_accuracy: 0.7030 - val_auc: 0.7167
#
# Epoch 00118: saving model to History/model.epoch118.hdf5
# Epoch 119/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3197 - accuracy: 0.9279 - auc: 0.9719 - val_loss: 0.8431 - val_accuracy: 0.6535 - val_auc: 0.7515
#
# Epoch 00119: saving model to History/model.epoch119.hdf5
# Epoch 120/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3089 - accuracy: 0.9133 - auc: 0.9752 - val_loss: 0.8799 - val_accuracy: 0.6535 - val_auc: 0.7053
#
# Epoch 00120: saving model to History/model.epoch120.hdf5
# Epoch 121/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2908 - accuracy: 0.9307 - auc: 0.9821 - val_loss: 0.8187 - val_accuracy: 0.6931 - val_auc: 0.7706
#
# Epoch 00121: saving model to History/model.epoch121.hdf5
# Epoch 122/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3278 - accuracy: 0.9108 - auc: 0.9674 - val_loss: 0.8167 - val_accuracy: 0.7030 - val_auc: 0.7653
#
# Epoch 00122: saving model to History/model.epoch122.hdf5
# Epoch 123/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.3109 - accuracy: 0.9117 - auc: 0.9740 - val_loss: 0.8411 - val_accuracy: 0.6634 - val_auc: 0.7545
#
# Epoch 00123: saving model to History/model.epoch123.hdf5
# Epoch 124/200
# 281/281 [==============================] - 59s 210ms/step - loss: 0.2807 - accuracy: 0.9380 - auc: 0.9833 - val_loss: 0.8830 - val_accuracy: 0.6931 - val_auc: 0.7233
#
# Epoch 00124: saving model to History/model.epoch124.hdf5
# Epoch 125/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.3144 - accuracy: 0.8851 - auc: 0.9713 - val_loss: 0.8845 - val_accuracy: 0.6931 - val_auc: 0.7158
#
# Epoch 00125: saving model to History/model.epoch125.hdf5
# Epoch 126/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3131 - accuracy: 0.9061 - auc: 0.9709 - val_loss: 0.9485 - val_accuracy: 0.6337 - val_auc: 0.6737
#
# Epoch 00126: saving model to History/model.epoch126.hdf5
# Epoch 127/200
# 281/281 [==============================] - 54s 192ms/step - loss: 0.3125 - accuracy: 0.9177 - auc: 0.9679 - val_loss: 0.8928 - val_accuracy: 0.6832 - val_auc: 0.7182
#
# Epoch 00127: saving model to History/model.epoch127.hdf5
# Epoch 128/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.2886 - accuracy: 0.9379 - auc: 0.9814 - val_loss: 0.9093 - val_accuracy: 0.6535 - val_auc: 0.6914
#
# Epoch 00128: saving model to History/model.epoch128.hdf5
# Epoch 129/200
# 281/281 [==============================] - 52s 186ms/step - loss: 0.2848 - accuracy: 0.9309 - auc: 0.9804 - val_loss: 0.9070 - val_accuracy: 0.6832 - val_auc: 0.7212
#
# Epoch 00129: saving model to History/model.epoch129.hdf5
# Epoch 130/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.2919 - accuracy: 0.9227 - auc: 0.9754 - val_loss: 0.9095 - val_accuracy: 0.6832 - val_auc: 0.7249
#
# Epoch 00130: saving model to History/model.epoch130.hdf5
# Epoch 131/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3135 - accuracy: 0.9032 - auc: 0.9729 - val_loss: 0.8601 - val_accuracy: 0.6535 - val_auc: 0.7501
#
# Epoch 00131: saving model to History/model.epoch131.hdf5
# Epoch 132/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3029 - accuracy: 0.9176 - auc: 0.9784 - val_loss: 0.8358 - val_accuracy: 0.6931 - val_auc: 0.7531
#
# Epoch 00132: saving model to History/model.epoch132.hdf5
# Epoch 133/200
# 281/281 [==============================] - 53s 189ms/step - loss: 0.2743 - accuracy: 0.9336 - auc: 0.9789 - val_loss: 0.8438 - val_accuracy: 0.6634 - val_auc: 0.7518
#
# Epoch 00133: saving model to History/model.epoch133.hdf5
# Epoch 134/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.2784 - accuracy: 0.9340 - auc: 0.9846 - val_loss: 0.8519 - val_accuracy: 0.6535 - val_auc: 0.7257
#
# Epoch 00134: saving model to History/model.epoch134.hdf5
# Epoch 135/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2947 - accuracy: 0.9237 - auc: 0.9800 - val_loss: 0.8825 - val_accuracy: 0.7129 - val_auc: 0.7573
#
# Epoch 00135: saving model to History/model.epoch135.hdf5
# Epoch 136/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2726 - accuracy: 0.9409 - auc: 0.9850 - val_loss: 0.8705 - val_accuracy: 0.7030 - val_auc: 0.7305
#
# Epoch 00136: saving model to History/model.epoch136.hdf5
# Epoch 137/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2613 - accuracy: 0.9395 - auc: 0.9874 - val_loss: 0.9152 - val_accuracy: 0.6535 - val_auc: 0.7112
#
# Epoch 00137: saving model to History/model.epoch137.hdf5
# Epoch 138/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.2614 - accuracy: 0.9265 - auc: 0.9846 - val_loss: 0.8649 - val_accuracy: 0.6832 - val_auc: 0.7438
#
# Epoch 00138: saving model to History/model.epoch138.hdf5
# Epoch 139/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2841 - accuracy: 0.9200 - auc: 0.9785 - val_loss: 0.8593 - val_accuracy: 0.6832 - val_auc: 0.7636
#
# Epoch 00139: saving model to History/model.epoch139.hdf5
# Epoch 140/200
# 281/281 [==============================] - 59s 210ms/step - loss: 0.2415 - accuracy: 0.9422 - auc: 0.9892 - val_loss: 1.0494 - val_accuracy: 0.6436 - val_auc: 0.6566
#
# Epoch 00140: saving model to History/model.epoch140.hdf5
# Epoch 141/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.2474 - accuracy: 0.9317 - auc: 0.9882 - val_loss: 0.8655 - val_accuracy: 0.6931 - val_auc: 0.7365
#
# Epoch 00141: saving model to History/model.epoch141.hdf5
# Epoch 142/200
# 281/281 [==============================] - 55s 194ms/step - loss: 0.2933 - accuracy: 0.9248 - auc: 0.9756 - val_loss: 0.8635 - val_accuracy: 0.6634 - val_auc: 0.7450
#
# Epoch 00142: saving model to History/model.epoch142.hdf5
# Epoch 143/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.2870 - accuracy: 0.9274 - auc: 0.9777 - val_loss: 0.9422 - val_accuracy: 0.7129 - val_auc: 0.7639
#
# Epoch 00143: saving model to History/model.epoch143.hdf5
# Epoch 144/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2881 - accuracy: 0.9285 - auc: 0.9789 - val_loss: 0.9081 - val_accuracy: 0.6832 - val_auc: 0.7463
#
# Epoch 00144: saving model to History/model.epoch144.hdf5
# Epoch 145/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2566 - accuracy: 0.9507 - auc: 0.9875 - val_loss: 0.9060 - val_accuracy: 0.7030 - val_auc: 0.7492
#
# Epoch 00145: saving model to History/model.epoch145.hdf5
# Epoch 146/200
# 281/281 [==============================] - 61s 216ms/step - loss: 0.2626 - accuracy: 0.9390 - auc: 0.9859 - val_loss: 0.9233 - val_accuracy: 0.6931 - val_auc: 0.7367
#
# Epoch 00146: saving model to History/model.epoch146.hdf5
# Epoch 147/200
# 281/281 [==============================] - 59s 208ms/step - loss: 0.2788 - accuracy: 0.9388 - auc: 0.9828 - val_loss: 1.0010 - val_accuracy: 0.6238 - val_auc: 0.6769
#
# Epoch 00147: saving model to History/model.epoch147.hdf5
# Epoch 148/200
# 281/281 [==============================] - 60s 212ms/step - loss: 0.2630 - accuracy: 0.9376 - auc: 0.9855 - val_loss: 0.9298 - val_accuracy: 0.6832 - val_auc: 0.7355
#
# Epoch 00148: saving model to History/model.epoch148.hdf5
# Epoch 149/200
# 281/281 [==============================] - 57s 200ms/step - loss: 0.3073 - accuracy: 0.9075 - auc: 0.9685 - val_loss: 0.9991 - val_accuracy: 0.6436 - val_auc: 0.6604
#
# Epoch 00149: saving model to History/model.epoch149.hdf5
# Epoch 150/200
# 281/281 [==============================] - 54s 192ms/step - loss: 0.2828 - accuracy: 0.9069 - auc: 0.9798 - val_loss: 0.9664 - val_accuracy: 0.6139 - val_auc: 0.7030
#
# Epoch 00150: saving model to History/model.epoch150.hdf5
# Epoch 151/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2840 - accuracy: 0.9386 - auc: 0.9779 - val_loss: 0.9026 - val_accuracy: 0.6535 - val_auc: 0.7248
#
# Epoch 00151: saving model to History/model.epoch151.hdf5
# Epoch 152/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.2661 - accuracy: 0.9408 - auc: 0.9835 - val_loss: 0.9985 - val_accuracy: 0.5941 - val_auc: 0.6858
#
# Epoch 00152: saving model to History/model.epoch152.hdf5
# Epoch 153/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3119 - accuracy: 0.9165 - auc: 0.9707 - val_loss: 1.0400 - val_accuracy: 0.6040 - val_auc: 0.6404
#
# Epoch 00153: saving model to History/model.epoch153.hdf5
# Epoch 154/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2757 - accuracy: 0.9193 - auc: 0.9824 - val_loss: 0.9711 - val_accuracy: 0.6238 - val_auc: 0.6897
#
# Epoch 00154: saving model to History/model.epoch154.hdf5
# Epoch 155/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2812 - accuracy: 0.9197 - auc: 0.9791 - val_loss: 0.9611 - val_accuracy: 0.6040 - val_auc: 0.6987
#
# Epoch 00155: saving model to History/model.epoch155.hdf5
# Epoch 156/200
# 281/281 [==============================] - 53s 188ms/step - loss: 0.2677 - accuracy: 0.9412 - auc: 0.9850 - val_loss: 0.9020 - val_accuracy: 0.6733 - val_auc: 0.7597
#
# Epoch 00156: saving model to History/model.epoch156.hdf5
# Epoch 157/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2921 - accuracy: 0.9237 - auc: 0.9814 - val_loss: 0.9031 - val_accuracy: 0.6733 - val_auc: 0.7544
#
# Epoch 00157: saving model to History/model.epoch157.hdf5
# Epoch 158/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2852 - accuracy: 0.9297 - auc: 0.9788 - val_loss: 0.9414 - val_accuracy: 0.7030 - val_auc: 0.7119
#
# Epoch 00158: saving model to History/model.epoch158.hdf5
# Epoch 159/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3033 - accuracy: 0.9116 - auc: 0.9684 - val_loss: 0.9169 - val_accuracy: 0.6436 - val_auc: 0.7230
#
# Epoch 00159: saving model to History/model.epoch159.hdf5
# Epoch 160/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.2492 - accuracy: 0.9322 - auc: 0.9874 - val_loss: 0.9427 - val_accuracy: 0.6832 - val_auc: 0.7378
#
# Epoch 00160: saving model to History/model.epoch160.hdf5
# Epoch 161/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.2563 - accuracy: 0.9326 - auc: 0.9832 - val_loss: 0.9150 - val_accuracy: 0.7129 - val_auc: 0.7657
#
# Epoch 00161: saving model to History/model.epoch161.hdf5
# Epoch 162/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.2712 - accuracy: 0.9324 - auc: 0.9814 - val_loss: 0.9597 - val_accuracy: 0.6337 - val_auc: 0.7059
#
# Epoch 00162: saving model to History/model.epoch162.hdf5
# Epoch 163/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.2360 - accuracy: 0.9513 - auc: 0.9915 - val_loss: 0.8987 - val_accuracy: 0.6436 - val_auc: 0.7252
#
# Epoch 00163: saving model to History/model.epoch163.hdf5
# Epoch 164/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3274 - accuracy: 0.9057 - auc: 0.9684 - val_loss: 0.9172 - val_accuracy: 0.6337 - val_auc: 0.7240
#
# Epoch 00164: saving model to History/model.epoch164.hdf5
# Epoch 165/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3117 - accuracy: 0.9047 - auc: 0.9760 - val_loss: 0.9052 - val_accuracy: 0.6535 - val_auc: 0.7461
#
# Epoch 00165: saving model to History/model.epoch165.hdf5
# Epoch 166/200
# 281/281 [==============================] - 59s 212ms/step - loss: 0.3036 - accuracy: 0.9120 - auc: 0.9721 - val_loss: 0.9660 - val_accuracy: 0.6139 - val_auc: 0.7209
#
# Epoch 00166: saving model to History/model.epoch166.hdf5
# Epoch 167/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2430 - accuracy: 0.9439 - auc: 0.9887 - val_loss: 0.9739 - val_accuracy: 0.6337 - val_auc: 0.7115
#
# Epoch 00167: saving model to History/model.epoch167.hdf5
# Epoch 168/200
# 281/281 [==============================] - 54s 193ms/step - loss: 0.2549 - accuracy: 0.9198 - auc: 0.9852 - val_loss: 0.9402 - val_accuracy: 0.6337 - val_auc: 0.7150
#
# Epoch 00168: saving model to History/model.epoch168.hdf5
# Epoch 169/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.2637 - accuracy: 0.9303 - auc: 0.9841 - val_loss: 0.9731 - val_accuracy: 0.6238 - val_auc: 0.7016
#
# Epoch 00169: saving model to History/model.epoch169.hdf5
# Epoch 170/200
# 281/281 [==============================] - 57s 202ms/step - loss: 0.2488 - accuracy: 0.9385 - auc: 0.9867 - val_loss: 0.9546 - val_accuracy: 0.7129 - val_auc: 0.7595
#
# Epoch 00170: saving model to History/model.epoch170.hdf5
# Epoch 171/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2735 - accuracy: 0.9277 - auc: 0.9846 - val_loss: 0.9737 - val_accuracy: 0.5941 - val_auc: 0.7014
#
# Epoch 00171: saving model to History/model.epoch171.hdf5
# Epoch 172/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2757 - accuracy: 0.9239 - auc: 0.9776 - val_loss: 0.9558 - val_accuracy: 0.6139 - val_auc: 0.7142
#
# Epoch 00172: saving model to History/model.epoch172.hdf5
# Epoch 173/200
# 281/281 [==============================] - 55s 195ms/step - loss: 0.2958 - accuracy: 0.9149 - auc: 0.9741 - val_loss: 0.9568 - val_accuracy: 0.6634 - val_auc: 0.6976
#
# Epoch 00173: saving model to History/model.epoch173.hdf5
# Epoch 174/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2368 - accuracy: 0.9430 - auc: 0.9878 - val_loss: 0.9464 - val_accuracy: 0.6535 - val_auc: 0.7342
#
# Epoch 00174: saving model to History/model.epoch174.hdf5
# Epoch 175/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2889 - accuracy: 0.9129 - auc: 0.9817 - val_loss: 0.9281 - val_accuracy: 0.6832 - val_auc: 0.7441
#
# Epoch 00175: saving model to History/model.epoch175.hdf5
# Epoch 176/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.2620 - accuracy: 0.9243 - auc: 0.9844 - val_loss: 0.9442 - val_accuracy: 0.6634 - val_auc: 0.7407
#
# Epoch 00176: saving model to History/model.epoch176.hdf5
# Epoch 177/200
# 281/281 [==============================] - 59s 211ms/step - loss: 0.2735 - accuracy: 0.9223 - auc: 0.9769 - val_loss: 0.9196 - val_accuracy: 0.6733 - val_auc: 0.7361
#
# Epoch 00177: saving model to History/model.epoch177.hdf5
# Epoch 178/200
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2439 - accuracy: 0.9471 - auc: 0.9855 - val_loss: 0.9103 - val_accuracy: 0.6535 - val_auc: 0.7283
#
# Epoch 00178: saving model to History/model.epoch178.hdf5
# Epoch 179/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2562 - accuracy: 0.9492 - auc: 0.9862 - val_loss: 0.9224 - val_accuracy: 0.6535 - val_auc: 0.7424
#
# Epoch 00179: saving model to History/model.epoch179.hdf5
# Epoch 180/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2615 - accuracy: 0.9329 - auc: 0.9816 - val_loss: 0.9763 - val_accuracy: 0.6436 - val_auc: 0.7322
#
# Epoch 00180: saving model to History/model.epoch180.hdf5
# Epoch 181/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.2434 - accuracy: 0.9371 - auc: 0.9872 - val_loss: 0.9673 - val_accuracy: 0.6436 - val_auc: 0.6998
#
# Epoch 00181: saving model to History/model.epoch181.hdf5
# Epoch 182/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.2636 - accuracy: 0.9350 - auc: 0.9823 - val_loss: 0.9731 - val_accuracy: 0.7228 - val_auc: 0.7654
#
# Epoch 00182: saving model to History/model.epoch182.hdf5
# Epoch 183/200
# 281/281 [==============================] - 55s 197ms/step - loss: 0.2320 - accuracy: 0.9552 - auc: 0.9905 - val_loss: 0.9733 - val_accuracy: 0.6337 - val_auc: 0.7283
#
# Epoch 00183: saving model to History/model.epoch183.hdf5
# Epoch 184/200
# 281/281 [==============================] - 60s 215ms/step - loss: 0.2497 - accuracy: 0.9412 - auc: 0.9876 - val_loss: 0.9957 - val_accuracy: 0.6634 - val_auc: 0.6936
#
# Epoch 00184: saving model to History/model.epoch184.hdf5
# Epoch 185/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2210 - accuracy: 0.9510 - auc: 0.9924 - val_loss: 0.9961 - val_accuracy: 0.6238 - val_auc: 0.7022
#
# Epoch 00185: saving model to History/model.epoch185.hdf5
# Epoch 186/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2564 - accuracy: 0.9242 - auc: 0.9850 - val_loss: 1.0401 - val_accuracy: 0.7030 - val_auc: 0.7626
#
# Epoch 00186: saving model to History/model.epoch186.hdf5
# Epoch 187/200
# 281/281 [==============================] - 56s 201ms/step - loss: 0.2481 - accuracy: 0.9433 - auc: 0.9866 - val_loss: 1.0308 - val_accuracy: 0.7030 - val_auc: 0.7567
#
# Epoch 00187: saving model to History/model.epoch187.hdf5
# Epoch 188/200
# 281/281 [==============================] - 58s 205ms/step - loss: 0.2188 - accuracy: 0.9477 - auc: 0.9929 - val_loss: 0.9720 - val_accuracy: 0.6733 - val_auc: 0.7458
#
# Epoch 00188: saving model to History/model.epoch188.hdf5
# Epoch 189/200
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2588 - accuracy: 0.9215 - auc: 0.9888 - val_loss: 0.9734 - val_accuracy: 0.6238 - val_auc: 0.7290
#
# Epoch 00189: saving model to History/model.epoch189.hdf5
# Epoch 190/200
# 281/281 [==============================] - 57s 201ms/step - loss: 0.2078 - accuracy: 0.9605 - auc: 0.9928 - val_loss: 0.9586 - val_accuracy: 0.7129 - val_auc: 0.7570
#
# Epoch 00190: saving model to History/model.epoch190.hdf5
# Epoch 191/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.2639 - accuracy: 0.9178 - auc: 0.9810 - val_loss: 0.9835 - val_accuracy: 0.6733 - val_auc: 0.7339
#
# Epoch 00191: saving model to History/model.epoch191.hdf5
# Epoch 192/200
# 281/281 [==============================] - 60s 215ms/step - loss: 0.2450 - accuracy: 0.9406 - auc: 0.9877 - val_loss: 1.1380 - val_accuracy: 0.5941 - val_auc: 0.6341
#
# Epoch 00192: saving model to History/model.epoch192.hdf5
# Epoch 193/200
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3186 - accuracy: 0.8904 - auc: 0.9652 - val_loss: 0.9909 - val_accuracy: 0.6634 - val_auc: 0.7537
#
# Epoch 00193: saving model to History/model.epoch193.hdf5
# Epoch 194/200
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2309 - accuracy: 0.9589 - auc: 0.9919 - val_loss: 0.9766 - val_accuracy: 0.6238 - val_auc: 0.7119
#
# Epoch 00194: saving model to History/model.epoch194.hdf5
# Epoch 195/200
# 281/281 [==============================] - 54s 192ms/step - loss: 0.2409 - accuracy: 0.9334 - auc: 0.9877 - val_loss: 0.9315 - val_accuracy: 0.6931 - val_auc: 0.7540
#
# Epoch 00195: saving model to History/model.epoch195.hdf5
# Epoch 196/200
# 281/281 [==============================] - 59s 209ms/step - loss: 0.2653 - accuracy: 0.9196 - auc: 0.9856 - val_loss: 0.9461 - val_accuracy: 0.6931 - val_auc: 0.7590
#
# Epoch 00196: saving model to History/model.epoch196.hdf5
# Epoch 197/200
# 281/281 [==============================] - 58s 206ms/step - loss: 0.2187 - accuracy: 0.9650 - auc: 0.9932 - val_loss: 1.0468 - val_accuracy: 0.7228 - val_auc: 0.7371
#
# Epoch 00197: saving model to History/model.epoch197.hdf5
# Epoch 198/200
# 281/281 [==============================] - 60s 212ms/step - loss: 0.2498 - accuracy: 0.9277 - auc: 0.9862 - val_loss: 0.9918 - val_accuracy: 0.6832 - val_auc: 0.7402
#
# Epoch 00198: saving model to History/model.epoch198.hdf5
# Epoch 199/200
# 281/281 [==============================] - 55s 196ms/step - loss: 0.2122 - accuracy: 0.9502 - auc: 0.9929 - val_loss: 1.0310 - val_accuracy: 0.6436 - val_auc: 0.7306
#
# Epoch 00199: saving model to History/model.epoch199.hdf5
# Epoch 200/200
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2168 - accuracy: 0.9548 - auc: 0.9918 - val_loss: 1.0046 - val_accuracy: 0.6337 - val_auc: 0.7099
#
# Epoch 00200: saving model to History/model.epoch200.hdf5

# %%
dat = pd.read_csv('results.csv', index_col='epoch')

fig, ax = plt.subplots(3, 1, figsize=(7,14))
metrics = ['accuracy', 'loss', 'auc']

for i, metric in enumerate(metrics):
    ax[i].plot(dat[metric])
    ax[i].plot(dat['val_'+metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])
    
    if metric == 'accuracy' or metric == 'auc':
        ax[i].set_ylim(0,1)
        
    else:
        ax[i].set_ylim(0)
    
fig.tight_layout()
plt.show()

p = 'softmax'+str(IMAGE_DIMENSION)
fig.savefig(p)

# %% [markdown]
# #### Prediction on test data

# %%
#best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
#print(best_model)
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
model.load_weights('History/model.epoch120.hdf5')

y_prob = model.predict(X_test, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_test = Y_test.argmax(axis = 1)

# %%
auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_test,
    y_scores=y_prob[:,1])

cm = confusion_matrix(y_test, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

print("Accuracy: ", round((np.mean(y_pred == y_test)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_test, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_test, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  65.35  CI: [0.557 0.739]
# AUC:  0.684 CI: [0.573 0.795]
# Confusion matrix:
#  [[18 13]
#  [22 48]]
# Normalized Confusion matrix:
#  [[0.581 0.419]
#  [0.314 0.686]]

# %% [markdown]
# #### Prediction on training data

# %%
best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
print(best_model)
#best_model = np.where(dat.val_auc == np.max(dat.val_auc))[0][0]
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
model.load_weights('History/model.epoch120.hdf5')

y_prob = model.predict(X_train, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_train = Y_train.argmax(axis = 1)
# Out:
# 53

# %%
cm = confusion_matrix(y_train, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_train,
    y_scores=y_prob[:,1])

print("Accuracy: ", round((np.mean(y_pred == y_train)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_train, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_train, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  99.51  CI: [0.982 0.999]
# AUC:  1.0 CI: [nan nan]
# Confusion matrix:
#  [[126   0]
#  [  2 279]]
# Normalized Confusion matrix:
#  [[1.    0.   ]
#  [0.007 0.993]]
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:2023: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:2024: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %% [markdown]
# #### Prediction on balanced test data

# %%
bool_test_labels = Y_test[:,1] != 0
pos_features_test = X_test[bool_test_labels]
neg_features_test = X_test[~bool_test_labels]
pos_labels_test = Y_test[bool_test_labels]
neg_labels_test = Y_test[~bool_test_labels]

ids = np.arange(len(neg_features_test))
choices = np.random.choice(ids, len(pos_features_test))
res_neg_features = neg_features_test[choices]
res_neg_labels = neg_labels_test[choices]

resampled_features = np.concatenate([res_neg_features, pos_features_test], axis=0)
resampled_labels = np.concatenate([res_neg_labels, pos_labels_test], axis=0)

order = np.arange(len(resampled_labels))
np.random.shuffle(order)
X_test_balanced = resampled_features[order]
Y_test_balanced  = resampled_labels[order]

# %%
best_model = np.where(dat.val_loss == np.min(dat.val_loss))[0][0] 
print(best_model)
#best_model = np.where(dat.val_auc == np.max(dat.val_auc))[0][0]
#best_model = np.where(dat.val_accuracy == np.max(dat.val_accuracy))[0][0]
model.load_weights('History/model.epoch120.hdf5')

y_prob = model.predict(X_test_balanced, batch_size=batch_size)
y_pred = (y_prob[:,1] > 0.5).astype(np.int)

y_test_balanced = Y_test_balanced.argmax(axis = 1)
# Out:
# 53

# %%
cm = confusion_matrix(y_test_balanced, y_pred)
lower_acc, upper_acc = proportion_confint(sum(np.diag(cm)), np.sum(cm), 0.05, method = 'wilson')
ci_acc = np.array([lower_acc, upper_acc])

auc, auc_var, ci_auc = auc_ci_Delong(
    y_true=y_test_balanced,
    y_scores=y_prob[:,1])

print("Accuracy: ", round((np.mean(y_pred == y_test_balanced)*100),2), ' CI:', np.round(ci_acc,3) )
print("AUC: ", round(auc, 3), 'CI:', np.round(ci_auc, 3))
print("Confusion matrix: \n", 
      confusion_matrix(y_test_balanced, y_pred))
print("Normalized Confusion matrix: \n", 
      np.round(confusion_matrix(y_test_balanced, y_pred, normalize = 'true'),3))
# Out:
# Accuracy:  64.29  CI: [0.561 0.717]
# AUC:  0.695 CI: [0.606 0.784]
# Confusion matrix:
#  [[42 28]
#  [22 48]]
# Normalized Confusion matrix:
#  [[0.6   0.4  ]
#  [0.314 0.686]]

# %% [markdown]
# ### Deep Ensemble

# %%
def ensemble(width, height, depth, batch_size, count, X_test, Y_test, pat_test):
    
    model = get_model(width=w, height=h, depth=d)
    print(model.summary())
    
    metrics = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc')]
    
    model.compile(loss = "categorical_crossentropy",
              optimizer = keras.optimizers.Adam(learning_rate =  0.00001),
              metrics = metrics)
    
    epochs = 120
    hist = model.fit(
    resampled_data,
    validation_data=validation_dataset,
    epochs=epochs,
    verbose=1, callbacks=callback_list, 
    steps_per_epoch = resampled_steps_per_epoch,
    class_weight = class_weight)
    
    y_prob = model.predict(X_test, batch_size=batch_size)
    y_pred = (y_prob[:,1] > 0.5).astype(np.int)
    y_test = Y_test.argmax(axis = 1) 
    
    model.save('model'+str(count)+'.h5')
    
    df = pd.DataFrame()
    df.loc[:,'y_test'] = y_test
    df.loc[:,'y_pred'] = y_pred
    df.loc[:,'y_prob'] = list(y_prob[:,1])
    df.loc[:,'pat'] = pat_test
    
    return df

# %%
for index in range(0,5):
    reset_keras()
    
    df = ensemble(width=w, height=h, depth=d, count = index, batch_size = 4, X_test = X_test, Y_test = Y_test, pat_test = pat_test)
    
    df.to_csv('predictions'+str(index)+'.csv', index=False)
# Out:
# 94
# Model: "3dcnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 112, 40, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 128, 112, 40, 8)   224
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 64, 56, 20, 8)     0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 56, 20, 8)     32
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 64, 56, 20, 16)    3472
# _________________________________________________________________
# average_pooling3d_1 (Average (None, 32, 28, 10, 16)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 28, 10, 16)    64
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 32, 28, 10, 32)    13856
# _________________________________________________________________
# average_pooling3d_2 (Average (None, 16, 14, 5, 32)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 14, 5, 32)     128
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 16, 14, 5, 32)     27680
# _________________________________________________________________
# average_pooling3d_3 (Average (None, 8, 7, 2, 32)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 7, 2, 32)       128
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 8, 7, 2, 64)       55360
# _________________________________________________________________
# average_pooling3d_4 (Average (None, 4, 4, 1, 64)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 1, 64)       256
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 166,930
# Trainable params: 166,626
# Non-trainable params: 304
# _________________________________________________________________
# None
# Epoch 1/120
# 281/281 [==============================] - 61s 197ms/step - loss: 1.0099 - accuracy: 0.4827 - auc: 0.4540 - val_loss: 0.9168 - val_accuracy: 0.3267 - val_auc: 0.3426
#
# Epoch 00001: saving model to History/model.epoch01.hdf5
# Epoch 2/120
# 281/281 [==============================] - 54s 194ms/step - loss: 0.9241 - accuracy: 0.4992 - auc: 0.4877 - val_loss: 0.9272 - val_accuracy: 0.4257 - val_auc: 0.4294
#
# Epoch 00002: saving model to History/model.epoch02.hdf5
# Epoch 3/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.8167 - accuracy: 0.5503 - auc: 0.6103 - val_loss: 0.9775 - val_accuracy: 0.3960 - val_auc: 0.4005
#
# Epoch 00003: saving model to History/model.epoch03.hdf5
# Epoch 4/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.8449 - accuracy: 0.5439 - auc: 0.5552 - val_loss: 1.2004 - val_accuracy: 0.3168 - val_auc: 0.3453
#
# Epoch 00004: saving model to History/model.epoch04.hdf5
# Epoch 5/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.8422 - accuracy: 0.5682 - auc: 0.5700 - val_loss: 1.1357 - val_accuracy: 0.3267 - val_auc: 0.3473
#
# Epoch 00005: saving model to History/model.epoch05.hdf5
# Epoch 6/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.8063 - accuracy: 0.5831 - auc: 0.6109 - val_loss: 0.9198 - val_accuracy: 0.4752 - val_auc: 0.4470
#
# Epoch 00006: saving model to History/model.epoch06.hdf5
# Epoch 7/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.8043 - accuracy: 0.5894 - auc: 0.6118 - val_loss: 1.1321 - val_accuracy: 0.3366 - val_auc: 0.3770
#
# Epoch 00007: saving model to History/model.epoch07.hdf5
# Epoch 8/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.7882 - accuracy: 0.5681 - auc: 0.6290 - val_loss: 0.9158 - val_accuracy: 0.5050 - val_auc: 0.4689
#
# Epoch 00008: saving model to History/model.epoch08.hdf5
# Epoch 9/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.7775 - accuracy: 0.6083 - auc: 0.6690 - val_loss: 1.1799 - val_accuracy: 0.3663 - val_auc: 0.3598
#
# Epoch 00009: saving model to History/model.epoch09.hdf5
# Epoch 10/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.7519 - accuracy: 0.6006 - auc: 0.6671 - val_loss: 0.8888 - val_accuracy: 0.5248 - val_auc: 0.4950
#
# Epoch 00010: saving model to History/model.epoch10.hdf5
# Epoch 11/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.7339 - accuracy: 0.6277 - auc: 0.6902 - val_loss: 0.9209 - val_accuracy: 0.5149 - val_auc: 0.4696
#
# Epoch 00011: saving model to History/model.epoch11.hdf5
# Epoch 12/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.7102 - accuracy: 0.6473 - auc: 0.7085 - val_loss: 1.0609 - val_accuracy: 0.4158 - val_auc: 0.3980
#
# Epoch 00012: saving model to History/model.epoch12.hdf5
# Epoch 13/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.7271 - accuracy: 0.6403 - auc: 0.6981 - val_loss: 1.0857 - val_accuracy: 0.3960 - val_auc: 0.4015
#
# Epoch 00013: saving model to History/model.epoch13.hdf5
# Epoch 14/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.6805 - accuracy: 0.6482 - auc: 0.7387 - val_loss: 0.9437 - val_accuracy: 0.4950 - val_auc: 0.4733
#
# Epoch 00014: saving model to History/model.epoch14.hdf5
# Epoch 15/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.6530 - accuracy: 0.7215 - auc: 0.7910 - val_loss: 0.9496 - val_accuracy: 0.4851 - val_auc: 0.4720
#
# Epoch 00015: saving model to History/model.epoch15.hdf5
# Epoch 16/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.7388 - accuracy: 0.6192 - auc: 0.6837 - val_loss: 1.0641 - val_accuracy: 0.4158 - val_auc: 0.4126
#
# Epoch 00016: saving model to History/model.epoch16.hdf5
# Epoch 17/120
# 281/281 [==============================] - 59s 211ms/step - loss: 0.6947 - accuracy: 0.6471 - auc: 0.7274 - val_loss: 0.9760 - val_accuracy: 0.4752 - val_auc: 0.4533
#
# Epoch 00017: saving model to History/model.epoch17.hdf5
# Epoch 18/120
# 281/281 [==============================] - 53s 190ms/step - loss: 0.6683 - accuracy: 0.7180 - auc: 0.7680 - val_loss: 0.8666 - val_accuracy: 0.5248 - val_auc: 0.5416
#
# Epoch 00018: saving model to History/model.epoch18.hdf5
# Epoch 19/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.6580 - accuracy: 0.7190 - auc: 0.7671 - val_loss: 0.9080 - val_accuracy: 0.5248 - val_auc: 0.5077
#
# Epoch 00019: saving model to History/model.epoch19.hdf5
# Epoch 20/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.6562 - accuracy: 0.6734 - auc: 0.7660 - val_loss: 0.9248 - val_accuracy: 0.5149 - val_auc: 0.4976
#
# Epoch 00020: saving model to History/model.epoch20.hdf5
# Epoch 21/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.6149 - accuracy: 0.7478 - auc: 0.8154 - val_loss: 0.8250 - val_accuracy: 0.5446 - val_auc: 0.5944
#
# Epoch 00021: saving model to History/model.epoch21.hdf5
# Epoch 22/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.6443 - accuracy: 0.7185 - auc: 0.7837 - val_loss: 0.7906 - val_accuracy: 0.5842 - val_auc: 0.6205
#
# Epoch 00022: saving model to History/model.epoch22.hdf5
# Epoch 23/120
# 281/281 [==============================] - 53s 190ms/step - loss: 0.6517 - accuracy: 0.7286 - auc: 0.7967 - val_loss: 0.8091 - val_accuracy: 0.5743 - val_auc: 0.6068
#
# Epoch 00023: saving model to History/model.epoch23.hdf5
# Epoch 24/120
# 281/281 [==============================] - 54s 194ms/step - loss: 0.6093 - accuracy: 0.7814 - auc: 0.8400 - val_loss: 0.9025 - val_accuracy: 0.5149 - val_auc: 0.5275
#
# Epoch 00024: saving model to History/model.epoch24.hdf5
# Epoch 25/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.6131 - accuracy: 0.7426 - auc: 0.8069 - val_loss: 0.8715 - val_accuracy: 0.5149 - val_auc: 0.5773
#
# Epoch 00025: saving model to History/model.epoch25.hdf5
# Epoch 26/120
# 281/281 [==============================] - 57s 205ms/step - loss: 0.6134 - accuracy: 0.7452 - auc: 0.8317 - val_loss: 0.8690 - val_accuracy: 0.5842 - val_auc: 0.5730
#
# Epoch 00026: saving model to History/model.epoch26.hdf5
# Epoch 27/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.5674 - accuracy: 0.7944 - auc: 0.8541 - val_loss: 0.7922 - val_accuracy: 0.5941 - val_auc: 0.6465
#
# Epoch 00027: saving model to History/model.epoch27.hdf5
# Epoch 28/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.5827 - accuracy: 0.7665 - auc: 0.8408 - val_loss: 0.7900 - val_accuracy: 0.5446 - val_auc: 0.6271
#
# Epoch 00028: saving model to History/model.epoch28.hdf5
# Epoch 29/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.5989 - accuracy: 0.7404 - auc: 0.8307 - val_loss: 0.7362 - val_accuracy: 0.6238 - val_auc: 0.6982
#
# Epoch 00029: saving model to History/model.epoch29.hdf5
# Epoch 30/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.5938 - accuracy: 0.7456 - auc: 0.8341 - val_loss: 0.7409 - val_accuracy: 0.6337 - val_auc: 0.6891
#
# Epoch 00030: saving model to History/model.epoch30.hdf5
# Epoch 31/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.5622 - accuracy: 0.7924 - auc: 0.8800 - val_loss: 0.9883 - val_accuracy: 0.5149 - val_auc: 0.5199
#
# Epoch 00031: saving model to History/model.epoch31.hdf5
# Epoch 32/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.5420 - accuracy: 0.7804 - auc: 0.8701 - val_loss: 0.8307 - val_accuracy: 0.5248 - val_auc: 0.6090
#
# Epoch 00032: saving model to History/model.epoch32.hdf5
# Epoch 33/120
# 281/281 [==============================] - 57s 205ms/step - loss: 0.5401 - accuracy: 0.7750 - auc: 0.8738 - val_loss: 0.7824 - val_accuracy: 0.6535 - val_auc: 0.6531
#
# Epoch 00033: saving model to History/model.epoch33.hdf5
# Epoch 34/120
# 281/281 [==============================] - 54s 193ms/step - loss: 0.5736 - accuracy: 0.7845 - auc: 0.8546 - val_loss: 0.7964 - val_accuracy: 0.6436 - val_auc: 0.6345
#
# Epoch 00034: saving model to History/model.epoch34.hdf5
# Epoch 35/120
# 281/281 [==============================] - 54s 191ms/step - loss: 0.5340 - accuracy: 0.7992 - auc: 0.8714 - val_loss: 0.7825 - val_accuracy: 0.6337 - val_auc: 0.6572
#
# Epoch 00035: saving model to History/model.epoch35.hdf5
# Epoch 36/120
# 281/281 [==============================] - 55s 198ms/step - loss: 0.5901 - accuracy: 0.7517 - auc: 0.8428 - val_loss: 0.7638 - val_accuracy: 0.6139 - val_auc: 0.6632
#
# Epoch 00036: saving model to History/model.epoch36.hdf5
# Epoch 37/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.5163 - accuracy: 0.7961 - auc: 0.8935 - val_loss: 0.9470 - val_accuracy: 0.5248 - val_auc: 0.5379
#
# Epoch 00037: saving model to History/model.epoch37.hdf5
# Epoch 38/120
# 281/281 [==============================] - 58s 204ms/step - loss: 0.4973 - accuracy: 0.7930 - auc: 0.8993 - val_loss: 0.8522 - val_accuracy: 0.6040 - val_auc: 0.6131
#
# Epoch 00038: saving model to History/model.epoch38.hdf5
# Epoch 39/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.5338 - accuracy: 0.7961 - auc: 0.8735 - val_loss: 0.7393 - val_accuracy: 0.6238 - val_auc: 0.7002
#
# Epoch 00039: saving model to History/model.epoch39.hdf5
# Epoch 40/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.5040 - accuracy: 0.8183 - auc: 0.8943 - val_loss: 0.7374 - val_accuracy: 0.5842 - val_auc: 0.6918
#
# Epoch 00040: saving model to History/model.epoch40.hdf5
# Epoch 41/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.4747 - accuracy: 0.8378 - auc: 0.9291 - val_loss: 0.7286 - val_accuracy: 0.6238 - val_auc: 0.7095
#
# Epoch 00041: saving model to History/model.epoch41.hdf5
# Epoch 42/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4379 - accuracy: 0.8851 - auc: 0.9386 - val_loss: 0.8009 - val_accuracy: 0.5347 - val_auc: 0.6393
#
# Epoch 00042: saving model to History/model.epoch42.hdf5
# Epoch 43/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.4656 - accuracy: 0.8229 - auc: 0.9157 - val_loss: 0.7056 - val_accuracy: 0.6535 - val_auc: 0.7390
#
# Epoch 00043: saving model to History/model.epoch43.hdf5
# Epoch 44/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.4503 - accuracy: 0.8690 - auc: 0.9252 - val_loss: 0.7688 - val_accuracy: 0.6040 - val_auc: 0.6760
#
# Epoch 00044: saving model to History/model.epoch44.hdf5
# Epoch 45/120
# 281/281 [==============================] - 60s 214ms/step - loss: 0.4881 - accuracy: 0.8399 - auc: 0.9018 - val_loss: 0.8876 - val_accuracy: 0.5446 - val_auc: 0.5920
#
# Epoch 00045: saving model to History/model.epoch45.hdf5
# Epoch 46/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4358 - accuracy: 0.8762 - auc: 0.9376 - val_loss: 0.8698 - val_accuracy: 0.5743 - val_auc: 0.5950
#
# Epoch 00046: saving model to History/model.epoch46.hdf5
# Epoch 47/120
# 281/281 [==============================] - 61s 219ms/step - loss: 0.5101 - accuracy: 0.7769 - auc: 0.8835 - val_loss: 0.7050 - val_accuracy: 0.6238 - val_auc: 0.7344
#
# Epoch 00047: saving model to History/model.epoch47.hdf5
# Epoch 48/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.4701 - accuracy: 0.8668 - auc: 0.9186 - val_loss: 0.6992 - val_accuracy: 0.6535 - val_auc: 0.7448
#
# Epoch 00048: saving model to History/model.epoch48.hdf5
# Epoch 49/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.4435 - accuracy: 0.8515 - auc: 0.9365 - val_loss: 0.7800 - val_accuracy: 0.6040 - val_auc: 0.6624
#
# Epoch 00049: saving model to History/model.epoch49.hdf5
# Epoch 50/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.4583 - accuracy: 0.8656 - auc: 0.9222 - val_loss: 0.6710 - val_accuracy: 0.6832 - val_auc: 0.7821
#
# Epoch 00050: saving model to History/model.epoch50.hdf5
# Epoch 51/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.4979 - accuracy: 0.8107 - auc: 0.9107 - val_loss: 0.7856 - val_accuracy: 0.6139 - val_auc: 0.6625
#
# Epoch 00051: saving model to History/model.epoch51.hdf5
# Epoch 52/120
# 281/281 [==============================] - 60s 214ms/step - loss: 0.4680 - accuracy: 0.8268 - auc: 0.9145 - val_loss: 0.7065 - val_accuracy: 0.6436 - val_auc: 0.7387
#
# Epoch 00052: saving model to History/model.epoch52.hdf5
# Epoch 53/120
# 281/281 [==============================] - 62s 220ms/step - loss: 0.4510 - accuracy: 0.8518 - auc: 0.9337 - val_loss: 0.7028 - val_accuracy: 0.6436 - val_auc: 0.7561
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.4253 - accuracy: 0.8929 - auc: 0.9387 - val_loss: 0.7237 - val_accuracy: 0.6337 - val_auc: 0.7273
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.4365 - accuracy: 0.8691 - auc: 0.9412 - val_loss: 0.9373 - val_accuracy: 0.5644 - val_auc: 0.5829
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4391 - accuracy: 0.8641 - auc: 0.9280 - val_loss: 0.8053 - val_accuracy: 0.6139 - val_auc: 0.6595
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4508 - accuracy: 0.8451 - auc: 0.9234 - val_loss: 0.7510 - val_accuracy: 0.6139 - val_auc: 0.7115
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/120
# 281/281 [==============================] - 59s 211ms/step - loss: 0.4573 - accuracy: 0.8698 - auc: 0.9255 - val_loss: 0.7777 - val_accuracy: 0.6139 - val_auc: 0.6882
#
# Epoch 00058: saving model to History/model.epoch58.hdf5
# Epoch 59/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3969 - accuracy: 0.8830 - auc: 0.9515 - val_loss: 0.8431 - val_accuracy: 0.5842 - val_auc: 0.6460
#
# Epoch 00059: saving model to History/model.epoch59.hdf5
# Epoch 60/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4297 - accuracy: 0.8606 - auc: 0.9312 - val_loss: 0.7670 - val_accuracy: 0.6238 - val_auc: 0.6990
#
# Epoch 00060: saving model to History/model.epoch60.hdf5
# Epoch 61/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4075 - accuracy: 0.8726 - auc: 0.9425 - val_loss: 0.7103 - val_accuracy: 0.6040 - val_auc: 0.7428
#
# Epoch 00061: saving model to History/model.epoch61.hdf5
# Epoch 62/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.4171 - accuracy: 0.8624 - auc: 0.9424 - val_loss: 0.7209 - val_accuracy: 0.6436 - val_auc: 0.7306
#
# Epoch 00062: saving model to History/model.epoch62.hdf5
# Epoch 63/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3671 - accuracy: 0.9033 - auc: 0.9581 - val_loss: 0.7247 - val_accuracy: 0.6634 - val_auc: 0.7439
#
# Epoch 00063: saving model to History/model.epoch63.hdf5
# Epoch 64/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.4099 - accuracy: 0.8594 - auc: 0.9376 - val_loss: 0.7819 - val_accuracy: 0.5446 - val_auc: 0.6853
#
# Epoch 00064: saving model to History/model.epoch64.hdf5
# Epoch 65/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3983 - accuracy: 0.8680 - auc: 0.9487 - val_loss: 0.7118 - val_accuracy: 0.6634 - val_auc: 0.7565
#
# Epoch 00065: saving model to History/model.epoch65.hdf5
# Epoch 66/120
# 281/281 [==============================] - 53s 189ms/step - loss: 0.4059 - accuracy: 0.8631 - auc: 0.9495 - val_loss: 0.7507 - val_accuracy: 0.6436 - val_auc: 0.7189
#
# Epoch 00066: saving model to History/model.epoch66.hdf5
# Epoch 67/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.3655 - accuracy: 0.9076 - auc: 0.9646 - val_loss: 0.7074 - val_accuracy: 0.6634 - val_auc: 0.7670
#
# Epoch 00067: saving model to History/model.epoch67.hdf5
# Epoch 68/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.4209 - accuracy: 0.8854 - auc: 0.9377 - val_loss: 0.8598 - val_accuracy: 0.5842 - val_auc: 0.6385
#
# Epoch 00068: saving model to History/model.epoch68.hdf5
# Epoch 69/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.3942 - accuracy: 0.8725 - auc: 0.9506 - val_loss: 0.7149 - val_accuracy: 0.6634 - val_auc: 0.7733
#
# Epoch 00069: saving model to History/model.epoch69.hdf5
# Epoch 70/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3906 - accuracy: 0.8805 - auc: 0.9543 - val_loss: 0.7639 - val_accuracy: 0.6139 - val_auc: 0.7025
#
# Epoch 00070: saving model to History/model.epoch70.hdf5
# Epoch 71/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.3460 - accuracy: 0.9010 - auc: 0.9707 - val_loss: 0.7827 - val_accuracy: 0.6040 - val_auc: 0.6809
#
# Epoch 00071: saving model to History/model.epoch71.hdf5
# Epoch 72/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.3670 - accuracy: 0.8914 - auc: 0.9626 - val_loss: 0.7340 - val_accuracy: 0.6139 - val_auc: 0.7162
#
# Epoch 00072: saving model to History/model.epoch72.hdf5
# Epoch 73/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3647 - accuracy: 0.9070 - auc: 0.9546 - val_loss: 0.7420 - val_accuracy: 0.6139 - val_auc: 0.7203
#
# Epoch 00073: saving model to History/model.epoch73.hdf5
# Epoch 74/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3555 - accuracy: 0.9002 - auc: 0.9679 - val_loss: 0.7358 - val_accuracy: 0.6337 - val_auc: 0.7512
#
# Epoch 00074: saving model to History/model.epoch74.hdf5
# Epoch 75/120
# 281/281 [==============================] - 60s 214ms/step - loss: 0.3780 - accuracy: 0.8928 - auc: 0.9545 - val_loss: 0.7546 - val_accuracy: 0.6931 - val_auc: 0.7584
#
# Epoch 00075: saving model to History/model.epoch75.hdf5
# Epoch 76/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.4302 - accuracy: 0.8625 - auc: 0.9336 - val_loss: 0.7690 - val_accuracy: 0.6238 - val_auc: 0.7086
#
# Epoch 00076: saving model to History/model.epoch76.hdf5
# Epoch 77/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.3994 - accuracy: 0.8688 - auc: 0.9462 - val_loss: 0.7414 - val_accuracy: 0.6238 - val_auc: 0.7321
#
# Epoch 00077: saving model to History/model.epoch77.hdf5
# Epoch 78/120
# 281/281 [==============================] - 57s 205ms/step - loss: 0.3706 - accuracy: 0.8732 - auc: 0.9541 - val_loss: 0.7489 - val_accuracy: 0.6238 - val_auc: 0.7370
#
# Epoch 00078: saving model to History/model.epoch78.hdf5
# Epoch 79/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.3837 - accuracy: 0.8679 - auc: 0.9544 - val_loss: 0.7472 - val_accuracy: 0.6634 - val_auc: 0.7596
#
# Epoch 00079: saving model to History/model.epoch79.hdf5
# Epoch 80/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3167 - accuracy: 0.9352 - auc: 0.9829 - val_loss: 0.8061 - val_accuracy: 0.6436 - val_auc: 0.6882
#
# Epoch 00080: saving model to History/model.epoch80.hdf5
# Epoch 81/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.3775 - accuracy: 0.9014 - auc: 0.9604 - val_loss: 0.7106 - val_accuracy: 0.6733 - val_auc: 0.7650
#
# Epoch 00081: saving model to History/model.epoch81.hdf5
# Epoch 82/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3787 - accuracy: 0.8946 - auc: 0.9536 - val_loss: 0.7611 - val_accuracy: 0.6634 - val_auc: 0.7406
#
# Epoch 00082: saving model to History/model.epoch82.hdf5
# Epoch 83/120
# 281/281 [==============================] - 55s 198ms/step - loss: 0.3286 - accuracy: 0.9100 - auc: 0.9722 - val_loss: 0.8019 - val_accuracy: 0.5941 - val_auc: 0.6933
#
# Epoch 00083: saving model to History/model.epoch83.hdf5
# Epoch 84/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3572 - accuracy: 0.8945 - auc: 0.9586 - val_loss: 0.7717 - val_accuracy: 0.6040 - val_auc: 0.7084
#
# Epoch 00084: saving model to History/model.epoch84.hdf5
# Epoch 85/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.3669 - accuracy: 0.8829 - auc: 0.9518 - val_loss: 0.8096 - val_accuracy: 0.6040 - val_auc: 0.6949
#
# Epoch 00085: saving model to History/model.epoch85.hdf5
# Epoch 86/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.3338 - accuracy: 0.9242 - auc: 0.9687 - val_loss: 0.7839 - val_accuracy: 0.5941 - val_auc: 0.7189
#
# Epoch 00086: saving model to History/model.epoch86.hdf5
# Epoch 87/120
# 281/281 [==============================] - 60s 212ms/step - loss: 0.3368 - accuracy: 0.8990 - auc: 0.9688 - val_loss: 0.8059 - val_accuracy: 0.6238 - val_auc: 0.6946
#
# Epoch 00087: saving model to History/model.epoch87.hdf5
# Epoch 88/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.3618 - accuracy: 0.9105 - auc: 0.9630 - val_loss: 0.7925 - val_accuracy: 0.6139 - val_auc: 0.7246
#
# Epoch 00088: saving model to History/model.epoch88.hdf5
# Epoch 89/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3342 - accuracy: 0.9072 - auc: 0.9693 - val_loss: 0.7531 - val_accuracy: 0.6436 - val_auc: 0.7575
#
# Epoch 00089: saving model to History/model.epoch89.hdf5
# Epoch 90/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3754 - accuracy: 0.8971 - auc: 0.9550 - val_loss: 0.7686 - val_accuracy: 0.6238 - val_auc: 0.7428
#
# Epoch 00090: saving model to History/model.epoch90.hdf5
# Epoch 91/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.3148 - accuracy: 0.8978 - auc: 0.9753 - val_loss: 0.7548 - val_accuracy: 0.6436 - val_auc: 0.7496
#
# Epoch 00091: saving model to History/model.epoch91.hdf5
# Epoch 92/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3253 - accuracy: 0.9139 - auc: 0.9730 - val_loss: 0.7621 - val_accuracy: 0.6535 - val_auc: 0.7348
#
# Epoch 00092: saving model to History/model.epoch92.hdf5
# Epoch 93/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3172 - accuracy: 0.9109 - auc: 0.9738 - val_loss: 0.7892 - val_accuracy: 0.6337 - val_auc: 0.7250
#
# Epoch 00093: saving model to History/model.epoch93.hdf5
# Epoch 94/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3053 - accuracy: 0.9231 - auc: 0.9783 - val_loss: 0.7888 - val_accuracy: 0.6337 - val_auc: 0.7462
#
# Epoch 00094: saving model to History/model.epoch94.hdf5
# Epoch 95/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3349 - accuracy: 0.9051 - auc: 0.9718 - val_loss: 0.8071 - val_accuracy: 0.5842 - val_auc: 0.7114
#
# Epoch 00095: saving model to History/model.epoch95.hdf5
# Epoch 96/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.2957 - accuracy: 0.9486 - auc: 0.9791 - val_loss: 0.7978 - val_accuracy: 0.6535 - val_auc: 0.7374
#
# Epoch 00096: saving model to History/model.epoch96.hdf5
# Epoch 97/120
# 281/281 [==============================] - 60s 212ms/step - loss: 0.3908 - accuracy: 0.8681 - auc: 0.9485 - val_loss: 0.7907 - val_accuracy: 0.6634 - val_auc: 0.7310
#
# Epoch 00097: saving model to History/model.epoch97.hdf5
# Epoch 98/120
# 281/281 [==============================] - 55s 198ms/step - loss: 0.3413 - accuracy: 0.9008 - auc: 0.9646 - val_loss: 0.8277 - val_accuracy: 0.6040 - val_auc: 0.7015
#
# Epoch 00098: saving model to History/model.epoch98.hdf5
# Epoch 99/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3407 - accuracy: 0.8919 - auc: 0.9631 - val_loss: 0.8102 - val_accuracy: 0.6139 - val_auc: 0.7055
#
# Epoch 00099: saving model to History/model.epoch99.hdf5
# Epoch 100/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3515 - accuracy: 0.8973 - auc: 0.9626 - val_loss: 0.7877 - val_accuracy: 0.6139 - val_auc: 0.7250
#
# Epoch 00100: saving model to History/model.epoch100.hdf5
# Epoch 101/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3828 - accuracy: 0.8747 - auc: 0.9466 - val_loss: 0.7622 - val_accuracy: 0.6436 - val_auc: 0.7338
#
# Epoch 00101: saving model to History/model.epoch101.hdf5
# Epoch 102/120
# 281/281 [==============================] - 55s 194ms/step - loss: 0.3145 - accuracy: 0.9184 - auc: 0.9745 - val_loss: 0.7674 - val_accuracy: 0.6931 - val_auc: 0.7751
#
# Epoch 00102: saving model to History/model.epoch102.hdf5
# Epoch 103/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.3201 - accuracy: 0.9067 - auc: 0.9727 - val_loss: 0.7901 - val_accuracy: 0.6040 - val_auc: 0.7221
#
# Epoch 00103: saving model to History/model.epoch103.hdf5
# Epoch 104/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3030 - accuracy: 0.9116 - auc: 0.9787 - val_loss: 0.8390 - val_accuracy: 0.6139 - val_auc: 0.7107
#
# Epoch 00104: saving model to History/model.epoch104.hdf5
# Epoch 105/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3733 - accuracy: 0.8775 - auc: 0.9505 - val_loss: 0.7835 - val_accuracy: 0.6238 - val_auc: 0.7433
#
# Epoch 00105: saving model to History/model.epoch105.hdf5
# Epoch 106/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.2980 - accuracy: 0.9348 - auc: 0.9795 - val_loss: 0.9098 - val_accuracy: 0.7228 - val_auc: 0.7815
#
# Epoch 00106: saving model to History/model.epoch106.hdf5
# Epoch 107/120
# 281/281 [==============================] - 60s 216ms/step - loss: 0.3180 - accuracy: 0.9057 - auc: 0.9732 - val_loss: 0.7984 - val_accuracy: 0.6535 - val_auc: 0.7372
#
# Epoch 00107: saving model to History/model.epoch107.hdf5
# Epoch 108/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.2817 - accuracy: 0.9359 - auc: 0.9855 - val_loss: 0.8162 - val_accuracy: 0.6436 - val_auc: 0.7438
#
# Epoch 00108: saving model to History/model.epoch108.hdf5
# Epoch 109/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2869 - accuracy: 0.9406 - auc: 0.9812 - val_loss: 0.8067 - val_accuracy: 0.6634 - val_auc: 0.7580
#
# Epoch 00109: saving model to History/model.epoch109.hdf5
# Epoch 110/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3169 - accuracy: 0.9101 - auc: 0.9778 - val_loss: 0.8116 - val_accuracy: 0.7030 - val_auc: 0.7724
#
# Epoch 00110: saving model to History/model.epoch110.hdf5
# Epoch 111/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.3333 - accuracy: 0.8891 - auc: 0.9665 - val_loss: 0.7543 - val_accuracy: 0.6139 - val_auc: 0.7511
#
# Epoch 00111: saving model to History/model.epoch111.hdf5
# Epoch 112/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3249 - accuracy: 0.8888 - auc: 0.9681 - val_loss: 0.7774 - val_accuracy: 0.6535 - val_auc: 0.7662
#
# Epoch 00112: saving model to History/model.epoch112.hdf5
# Epoch 113/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3139 - accuracy: 0.9108 - auc: 0.9780 - val_loss: 0.7481 - val_accuracy: 0.6634 - val_auc: 0.7722
#
# Epoch 00113: saving model to History/model.epoch113.hdf5
# Epoch 114/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3026 - accuracy: 0.9155 - auc: 0.9754 - val_loss: 0.7760 - val_accuracy: 0.6436 - val_auc: 0.7454
#
# Epoch 00114: saving model to History/model.epoch114.hdf5
# Epoch 115/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3427 - accuracy: 0.8802 - auc: 0.9619 - val_loss: 0.7706 - val_accuracy: 0.6733 - val_auc: 0.7727
#
# Epoch 00115: saving model to History/model.epoch115.hdf5
# Epoch 116/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.2885 - accuracy: 0.9255 - auc: 0.9820 - val_loss: 0.8337 - val_accuracy: 0.6436 - val_auc: 0.7598
#
# Epoch 00116: saving model to History/model.epoch116.hdf5
# Epoch 117/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.3052 - accuracy: 0.9083 - auc: 0.9767 - val_loss: 0.7948 - val_accuracy: 0.6238 - val_auc: 0.7330
#
# Epoch 00117: saving model to History/model.epoch117.hdf5
# Epoch 118/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.3450 - accuracy: 0.8897 - auc: 0.9651 - val_loss: 0.7590 - val_accuracy: 0.6139 - val_auc: 0.7553
#
# Epoch 00118: saving model to History/model.epoch118.hdf5
# Epoch 119/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3113 - accuracy: 0.9198 - auc: 0.9753 - val_loss: 0.8547 - val_accuracy: 0.6139 - val_auc: 0.6862
#
# Epoch 00119: saving model to History/model.epoch119.hdf5
# Epoch 120/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.2620 - accuracy: 0.9513 - auc: 0.9857 - val_loss: 0.7951 - val_accuracy: 0.6238 - val_auc: 0.7186
#
# Epoch 00120: saving model to History/model.epoch120.hdf5
# 1178
# Model: "3dcnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 112, 40, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 128, 112, 40, 8)   224
# _________________________________________________________________
# average_pooling3d (AveragePo (None, 64, 56, 20, 8)     0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 56, 20, 8)     32
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 64, 56, 20, 16)    3472
# _________________________________________________________________
# average_pooling3d_1 (Average (None, 32, 28, 10, 16)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 28, 10, 16)    64
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 32, 28, 10, 32)    13856
# _________________________________________________________________
# average_pooling3d_2 (Average (None, 16, 14, 5, 32)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 14, 5, 32)     128
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 16, 14, 5, 32)     27680
# _________________________________________________________________
# average_pooling3d_3 (Average (None, 8, 7, 2, 32)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 7, 2, 32)       128
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 8, 7, 2, 64)       55360
# _________________________________________________________________
# average_pooling3d_4 (Average (None, 4, 4, 1, 64)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 1, 64)       256
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 166,930
# Trainable params: 166,626
# Non-trainable params: 304
# _________________________________________________________________
# None
# Epoch 1/120
# 281/281 [==============================] - 61s 191ms/step - loss: 1.0559 - accuracy: 0.4639 - auc: 0.4622 - val_loss: 1.0194 - val_accuracy: 0.3366 - val_auc: 0.2665
#
# Epoch 00001: saving model to History/model.epoch01.hdf5
# Epoch 2/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.8985 - accuracy: 0.4920 - auc: 0.5053 - val_loss: 0.9794 - val_accuracy: 0.3663 - val_auc: 0.3333
#
# Epoch 00002: saving model to History/model.epoch02.hdf5
# Epoch 3/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.8933 - accuracy: 0.4876 - auc: 0.4728 - val_loss: 0.9630 - val_accuracy: 0.4158 - val_auc: 0.3542
#
# Epoch 00003: saving model to History/model.epoch03.hdf5
# Epoch 4/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.8252 - accuracy: 0.5513 - auc: 0.5499 - val_loss: 0.9826 - val_accuracy: 0.4158 - val_auc: 0.3736
#
# Epoch 00004: saving model to History/model.epoch04.hdf5
# Epoch 5/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.8585 - accuracy: 0.5355 - auc: 0.5561 - val_loss: 0.8803 - val_accuracy: 0.4950 - val_auc: 0.4612
#
# Epoch 00005: saving model to History/model.epoch05.hdf5
# Epoch 6/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.8381 - accuracy: 0.5685 - auc: 0.5742 - val_loss: 1.0462 - val_accuracy: 0.3861 - val_auc: 0.3358
#
# Epoch 00006: saving model to History/model.epoch06.hdf5
# Epoch 7/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.8432 - accuracy: 0.5180 - auc: 0.5386 - val_loss: 0.9367 - val_accuracy: 0.4455 - val_auc: 0.3887
#
# Epoch 00007: saving model to History/model.epoch07.hdf5
# Epoch 8/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.8028 - accuracy: 0.5564 - auc: 0.6051 - val_loss: 1.2638 - val_accuracy: 0.3069 - val_auc: 0.3128
#
# Epoch 00008: saving model to History/model.epoch08.hdf5
# Epoch 9/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.7937 - accuracy: 0.5671 - auc: 0.6204 - val_loss: 1.0531 - val_accuracy: 0.3861 - val_auc: 0.3451
#
# Epoch 00009: saving model to History/model.epoch09.hdf5
# Epoch 10/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.7589 - accuracy: 0.6122 - auc: 0.6662 - val_loss: 0.9534 - val_accuracy: 0.4158 - val_auc: 0.3799
#
# Epoch 00010: saving model to History/model.epoch10.hdf5
# Epoch 11/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.7810 - accuracy: 0.6051 - auc: 0.6312 - val_loss: 0.9448 - val_accuracy: 0.4158 - val_auc: 0.3949
#
# Epoch 00011: saving model to History/model.epoch11.hdf5
# Epoch 12/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.7445 - accuracy: 0.6203 - auc: 0.6687 - val_loss: 1.0617 - val_accuracy: 0.3663 - val_auc: 0.3517
#
# Epoch 00012: saving model to History/model.epoch12.hdf5
# Epoch 13/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.7437 - accuracy: 0.5900 - auc: 0.6584 - val_loss: 1.0658 - val_accuracy: 0.3663 - val_auc: 0.3412
#
# Epoch 00013: saving model to History/model.epoch13.hdf5
# Epoch 14/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.7207 - accuracy: 0.5986 - auc: 0.6869 - val_loss: 0.8256 - val_accuracy: 0.5644 - val_auc: 0.5754
#
# Epoch 00014: saving model to History/model.epoch14.hdf5
# Epoch 15/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.7257 - accuracy: 0.6436 - auc: 0.7182 - val_loss: 1.0711 - val_accuracy: 0.3663 - val_auc: 0.3622
#
# Epoch 00015: saving model to History/model.epoch15.hdf5
# Epoch 16/120
# 281/281 [==============================] - 54s 191ms/step - loss: 0.7090 - accuracy: 0.6643 - auc: 0.7055 - val_loss: 1.0082 - val_accuracy: 0.4059 - val_auc: 0.3880
#
# Epoch 00016: saving model to History/model.epoch16.hdf5
# Epoch 17/120
# 281/281 [==============================] - 59s 212ms/step - loss: 0.6858 - accuracy: 0.6531 - auc: 0.7300 - val_loss: 0.9111 - val_accuracy: 0.5149 - val_auc: 0.4587
#
# Epoch 00017: saving model to History/model.epoch17.hdf5
# Epoch 18/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.7063 - accuracy: 0.6317 - auc: 0.7129 - val_loss: 1.1443 - val_accuracy: 0.4059 - val_auc: 0.3587
#
# Epoch 00018: saving model to History/model.epoch18.hdf5
# Epoch 19/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.6948 - accuracy: 0.6302 - auc: 0.7208 - val_loss: 1.0455 - val_accuracy: 0.4455 - val_auc: 0.3840
#
# Epoch 00019: saving model to History/model.epoch19.hdf5
# Epoch 20/120
# 281/281 [==============================] - 57s 205ms/step - loss: 0.7101 - accuracy: 0.6538 - auc: 0.7052 - val_loss: 0.9107 - val_accuracy: 0.5050 - val_auc: 0.4823
#
# Epoch 00020: saving model to History/model.epoch20.hdf5
# Epoch 21/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.6769 - accuracy: 0.6787 - auc: 0.7544 - val_loss: 0.8883 - val_accuracy: 0.5050 - val_auc: 0.5194
#
# Epoch 00021: saving model to History/model.epoch21.hdf5
# Epoch 22/120
# 281/281 [==============================] - 60s 214ms/step - loss: 0.6573 - accuracy: 0.7149 - auc: 0.7796 - val_loss: 0.7719 - val_accuracy: 0.5644 - val_auc: 0.6573
#
# Epoch 00022: saving model to History/model.epoch22.hdf5
# Epoch 23/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.6847 - accuracy: 0.6495 - auc: 0.7429 - val_loss: 0.8006 - val_accuracy: 0.5446 - val_auc: 0.6206
#
# Epoch 00023: saving model to History/model.epoch23.hdf5
# Epoch 24/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.6505 - accuracy: 0.7267 - auc: 0.8043 - val_loss: 0.8644 - val_accuracy: 0.5347 - val_auc: 0.5359
#
# Epoch 00024: saving model to History/model.epoch24.hdf5
# Epoch 25/120
# 281/281 [==============================] - 59s 211ms/step - loss: 0.6727 - accuracy: 0.6992 - auc: 0.7610 - val_loss: 0.9918 - val_accuracy: 0.4653 - val_auc: 0.4236
#
# Epoch 00025: saving model to History/model.epoch25.hdf5
# Epoch 26/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.6467 - accuracy: 0.7370 - auc: 0.7795 - val_loss: 0.8880 - val_accuracy: 0.5149 - val_auc: 0.5119
#
# Epoch 00026: saving model to History/model.epoch26.hdf5
# Epoch 27/120
# 281/281 [==============================] - 53s 189ms/step - loss: 0.6051 - accuracy: 0.7523 - auc: 0.8244 - val_loss: 0.8293 - val_accuracy: 0.5743 - val_auc: 0.5931
#
# Epoch 00027: saving model to History/model.epoch27.hdf5
# Epoch 28/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.5945 - accuracy: 0.7689 - auc: 0.8491 - val_loss: 0.9251 - val_accuracy: 0.5446 - val_auc: 0.5075
#
# Epoch 00028: saving model to History/model.epoch28.hdf5
# Epoch 29/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.6371 - accuracy: 0.7097 - auc: 0.7786 - val_loss: 0.8814 - val_accuracy: 0.5347 - val_auc: 0.5448
#
# Epoch 00029: saving model to History/model.epoch29.hdf5
# Epoch 30/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.6283 - accuracy: 0.7512 - auc: 0.8145 - val_loss: 0.9212 - val_accuracy: 0.5545 - val_auc: 0.5173
#
# Epoch 00030: saving model to History/model.epoch30.hdf5
# Epoch 31/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.6099 - accuracy: 0.7329 - auc: 0.8259 - val_loss: 0.9986 - val_accuracy: 0.4455 - val_auc: 0.4290
#
# Epoch 00031: saving model to History/model.epoch31.hdf5
# Epoch 32/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.5775 - accuracy: 0.7427 - auc: 0.8397 - val_loss: 1.0938 - val_accuracy: 0.4059 - val_auc: 0.3850
#
# Epoch 00032: saving model to History/model.epoch32.hdf5
# Epoch 33/120
# 281/281 [==============================] - 57s 205ms/step - loss: 0.5773 - accuracy: 0.7618 - auc: 0.8435 - val_loss: 1.0702 - val_accuracy: 0.4653 - val_auc: 0.4118
#
# Epoch 00033: saving model to History/model.epoch33.hdf5
# Epoch 34/120
# 281/281 [==============================] - 59s 210ms/step - loss: 0.6302 - accuracy: 0.7213 - auc: 0.7977 - val_loss: 0.7784 - val_accuracy: 0.5941 - val_auc: 0.6781
#
# Epoch 00034: saving model to History/model.epoch34.hdf5
# Epoch 35/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.5572 - accuracy: 0.7705 - auc: 0.8726 - val_loss: 0.8376 - val_accuracy: 0.5743 - val_auc: 0.6149
#
# Epoch 00035: saving model to History/model.epoch35.hdf5
# Epoch 36/120
# 281/281 [==============================] - 59s 212ms/step - loss: 0.5671 - accuracy: 0.7561 - auc: 0.8612 - val_loss: 1.0618 - val_accuracy: 0.4455 - val_auc: 0.4243
#
# Epoch 00036: saving model to History/model.epoch36.hdf5
# Epoch 37/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.5448 - accuracy: 0.7566 - auc: 0.8644 - val_loss: 0.9349 - val_accuracy: 0.5050 - val_auc: 0.5077
#
# Epoch 00037: saving model to History/model.epoch37.hdf5
# Epoch 38/120
# 281/281 [==============================] - 57s 201ms/step - loss: 0.5675 - accuracy: 0.7526 - auc: 0.8481 - val_loss: 0.8966 - val_accuracy: 0.5248 - val_auc: 0.5502
#
# Epoch 00038: saving model to History/model.epoch38.hdf5
# Epoch 39/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.5406 - accuracy: 0.7957 - auc: 0.8657 - val_loss: 0.8822 - val_accuracy: 0.5842 - val_auc: 0.5713
#
# Epoch 00039: saving model to History/model.epoch39.hdf5
# Epoch 40/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.5341 - accuracy: 0.7822 - auc: 0.8828 - val_loss: 0.9015 - val_accuracy: 0.5743 - val_auc: 0.5455
#
# Epoch 00040: saving model to History/model.epoch40.hdf5
# Epoch 41/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.5094 - accuracy: 0.8022 - auc: 0.8925 - val_loss: 0.8184 - val_accuracy: 0.5446 - val_auc: 0.6332
#
# Epoch 00041: saving model to History/model.epoch41.hdf5
# Epoch 42/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.5465 - accuracy: 0.7864 - auc: 0.8766 - val_loss: 0.9880 - val_accuracy: 0.5347 - val_auc: 0.4980
#
# Epoch 00042: saving model to History/model.epoch42.hdf5
# Epoch 43/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.5489 - accuracy: 0.7688 - auc: 0.8718 - val_loss: 1.0851 - val_accuracy: 0.4653 - val_auc: 0.4363
#
# Epoch 00043: saving model to History/model.epoch43.hdf5
# Epoch 44/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.5628 - accuracy: 0.7475 - auc: 0.8356 - val_loss: 0.9832 - val_accuracy: 0.5149 - val_auc: 0.4891
#
# Epoch 00044: saving model to History/model.epoch44.hdf5
# Epoch 45/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.5321 - accuracy: 0.7768 - auc: 0.8663 - val_loss: 0.9072 - val_accuracy: 0.5446 - val_auc: 0.5492
#
# Epoch 00045: saving model to History/model.epoch45.hdf5
# Epoch 46/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.5179 - accuracy: 0.7913 - auc: 0.8823 - val_loss: 0.8973 - val_accuracy: 0.5149 - val_auc: 0.5583
#
# Epoch 00046: saving model to History/model.epoch46.hdf5
# Epoch 47/120
# 281/281 [==============================] - 60s 213ms/step - loss: 0.5009 - accuracy: 0.8100 - auc: 0.8970 - val_loss: 0.9666 - val_accuracy: 0.4851 - val_auc: 0.5008
#
# Epoch 00047: saving model to History/model.epoch47.hdf5
# Epoch 48/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.4782 - accuracy: 0.8330 - auc: 0.9087 - val_loss: 0.9378 - val_accuracy: 0.5347 - val_auc: 0.5371
#
# Epoch 00048: saving model to History/model.epoch48.hdf5
# Epoch 49/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.5371 - accuracy: 0.7857 - auc: 0.8639 - val_loss: 0.8467 - val_accuracy: 0.5743 - val_auc: 0.6145
#
# Epoch 00049: saving model to History/model.epoch49.hdf5
# Epoch 50/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.5164 - accuracy: 0.8038 - auc: 0.8863 - val_loss: 0.9201 - val_accuracy: 0.5644 - val_auc: 0.5599
#
# Epoch 00050: saving model to History/model.epoch50.hdf5
# Epoch 51/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.4821 - accuracy: 0.8010 - auc: 0.9098 - val_loss: 0.8932 - val_accuracy: 0.5842 - val_auc: 0.5854
#
# Epoch 00051: saving model to History/model.epoch51.hdf5
# Epoch 52/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4696 - accuracy: 0.8365 - auc: 0.9078 - val_loss: 0.8775 - val_accuracy: 0.6040 - val_auc: 0.6032
#
# Epoch 00052: saving model to History/model.epoch52.hdf5
# Epoch 53/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.5093 - accuracy: 0.8150 - auc: 0.8923 - val_loss: 1.0190 - val_accuracy: 0.5050 - val_auc: 0.5099
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.4621 - accuracy: 0.8456 - auc: 0.9213 - val_loss: 0.8523 - val_accuracy: 0.5941 - val_auc: 0.6303
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.5005 - accuracy: 0.8149 - auc: 0.8978 - val_loss: 0.8267 - val_accuracy: 0.5941 - val_auc: 0.6553
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.4395 - accuracy: 0.8601 - auc: 0.9317 - val_loss: 0.8279 - val_accuracy: 0.5941 - val_auc: 0.6547
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4347 - accuracy: 0.8325 - auc: 0.9335 - val_loss: 0.9041 - val_accuracy: 0.5743 - val_auc: 0.5746
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/120
# 281/281 [==============================] - 59s 210ms/step - loss: 0.4513 - accuracy: 0.8596 - auc: 0.9262 - val_loss: 0.8478 - val_accuracy: 0.5941 - val_auc: 0.6443
#
# ...
#
# Epoch 00053: saving model to History/model.epoch53.hdf5
# Epoch 54/120
# 281/281 [==============================] - 55s 195ms/step - loss: 0.4431 - accuracy: 0.8628 - auc: 0.9344 - val_loss: 0.8350 - val_accuracy: 0.5545 - val_auc: 0.6446
#
# Epoch 00054: saving model to History/model.epoch54.hdf5
# Epoch 55/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3903 - accuracy: 0.8796 - auc: 0.9532 - val_loss: 0.8006 - val_accuracy: 0.5941 - val_auc: 0.6721
#
# Epoch 00055: saving model to History/model.epoch55.hdf5
# Epoch 56/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.4171 - accuracy: 0.8645 - auc: 0.9457 - val_loss: 0.8384 - val_accuracy: 0.5941 - val_auc: 0.6556
#
# Epoch 00056: saving model to History/model.epoch56.hdf5
# Epoch 57/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.4203 - accuracy: 0.8463 - auc: 0.9373 - val_loss: 0.7234 - val_accuracy: 0.6832 - val_auc: 0.7523
#
# Epoch 00057: saving model to History/model.epoch57.hdf5
# Epoch 58/120
# 281/281 [==============================] - 55s 196ms/step - loss: 0.4611 - accuracy: 0.8301 - auc: 0.9235 - val_loss: 0.7419 - val_accuracy: 0.6139 - val_auc: 0.7189
#
# Epoch 00058: saving model to History/model.epoch58.hdf5
# Epoch 59/120
# 281/281 [==============================] - 59s 211ms/step - loss: 0.4578 - accuracy: 0.8614 - auc: 0.9302 - val_loss: 0.7818 - val_accuracy: 0.6139 - val_auc: 0.6917
#
# Epoch 00059: saving model to History/model.epoch59.hdf5
# Epoch 60/120
# 281/281 [==============================] - 54s 193ms/step - loss: 0.3849 - accuracy: 0.8809 - auc: 0.9574 - val_loss: 0.8354 - val_accuracy: 0.6337 - val_auc: 0.6667
#
# Epoch 00060: saving model to History/model.epoch60.hdf5
# Epoch 61/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4104 - accuracy: 0.8734 - auc: 0.9395 - val_loss: 0.8544 - val_accuracy: 0.5842 - val_auc: 0.6445
#
# Epoch 00061: saving model to History/model.epoch61.hdf5
# Epoch 62/120
# 281/281 [==============================] - 59s 208ms/step - loss: 0.4767 - accuracy: 0.8181 - auc: 0.9016 - val_loss: 0.8340 - val_accuracy: 0.5842 - val_auc: 0.6617
#
# Epoch 00062: saving model to History/model.epoch62.hdf5
# Epoch 63/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.4200 - accuracy: 0.8534 - auc: 0.9427 - val_loss: 0.7781 - val_accuracy: 0.6139 - val_auc: 0.7088
#
# Epoch 00063: saving model to History/model.epoch63.hdf5
# Epoch 64/120
# 281/281 [==============================] - 59s 207ms/step - loss: 0.4188 - accuracy: 0.8848 - auc: 0.9400 - val_loss: 0.7646 - val_accuracy: 0.6436 - val_auc: 0.7077
#
# Epoch 00064: saving model to History/model.epoch64.hdf5
# Epoch 65/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.4342 - accuracy: 0.8654 - auc: 0.9347 - val_loss: 0.7930 - val_accuracy: 0.6040 - val_auc: 0.6895
#
# Epoch 00065: saving model to History/model.epoch65.hdf5
# Epoch 66/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.4220 - accuracy: 0.8587 - auc: 0.9395 - val_loss: 0.7382 - val_accuracy: 0.6634 - val_auc: 0.7438
#
# Epoch 00066: saving model to History/model.epoch66.hdf5
# Epoch 67/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.4211 - accuracy: 0.8692 - auc: 0.9382 - val_loss: 0.7083 - val_accuracy: 0.6832 - val_auc: 0.7786
#
# Epoch 00067: saving model to History/model.epoch67.hdf5
# Epoch 68/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3734 - accuracy: 0.9076 - auc: 0.9654 - val_loss: 0.7420 - val_accuracy: 0.6535 - val_auc: 0.7394
#
# Epoch 00068: saving model to History/model.epoch68.hdf5
# Epoch 69/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.4060 - accuracy: 0.8845 - auc: 0.9434 - val_loss: 0.8688 - val_accuracy: 0.5941 - val_auc: 0.6582
#
# Epoch 00069: saving model to History/model.epoch69.hdf5
# Epoch 70/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.4108 - accuracy: 0.8766 - auc: 0.9409 - val_loss: 0.7420 - val_accuracy: 0.6535 - val_auc: 0.7342
#
# Epoch 00070: saving model to History/model.epoch70.hdf5
# Epoch 71/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.4058 - accuracy: 0.8809 - auc: 0.9458 - val_loss: 0.8368 - val_accuracy: 0.6139 - val_auc: 0.6659
#
# Epoch 00071: saving model to History/model.epoch71.hdf5
# Epoch 72/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.4153 - accuracy: 0.8478 - auc: 0.9351 - val_loss: 0.7316 - val_accuracy: 0.6733 - val_auc: 0.7444
#
# Epoch 00072: saving model to History/model.epoch72.hdf5
# Epoch 73/120
# 281/281 [==============================] - 59s 208ms/step - loss: 0.3972 - accuracy: 0.8784 - auc: 0.9511 - val_loss: 0.7299 - val_accuracy: 0.6436 - val_auc: 0.7491
#
# Epoch 00073: saving model to History/model.epoch73.hdf5
# Epoch 74/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3560 - accuracy: 0.9067 - auc: 0.9633 - val_loss: 1.2532 - val_accuracy: 0.4653 - val_auc: 0.4950
#
# Epoch 00074: saving model to History/model.epoch74.hdf5
# Epoch 75/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3881 - accuracy: 0.8756 - auc: 0.9435 - val_loss: 0.9071 - val_accuracy: 0.6040 - val_auc: 0.6306
#
# Epoch 00075: saving model to History/model.epoch75.hdf5
# Epoch 76/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3887 - accuracy: 0.8851 - auc: 0.9504 - val_loss: 0.7864 - val_accuracy: 0.6139 - val_auc: 0.7075
#
# Epoch 00076: saving model to History/model.epoch76.hdf5
# Epoch 77/120
# 281/281 [==============================] - 59s 210ms/step - loss: 0.3967 - accuracy: 0.8710 - auc: 0.9471 - val_loss: 0.7631 - val_accuracy: 0.6733 - val_auc: 0.7320
#
# Epoch 00077: saving model to History/model.epoch77.hdf5
# Epoch 78/120
# 281/281 [==============================] - 57s 204ms/step - loss: 0.3579 - accuracy: 0.9039 - auc: 0.9651 - val_loss: 0.7463 - val_accuracy: 0.6139 - val_auc: 0.7330
#
# Epoch 00078: saving model to History/model.epoch78.hdf5
# Epoch 79/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.3826 - accuracy: 0.8801 - auc: 0.9540 - val_loss: 0.8299 - val_accuracy: 0.6238 - val_auc: 0.6754
#
# Epoch 00079: saving model to History/model.epoch79.hdf5
# Epoch 80/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3919 - accuracy: 0.8847 - auc: 0.9424 - val_loss: 0.9512 - val_accuracy: 0.5743 - val_auc: 0.6007
#
# Epoch 00080: saving model to History/model.epoch80.hdf5
# Epoch 81/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3994 - accuracy: 0.8793 - auc: 0.9419 - val_loss: 0.8030 - val_accuracy: 0.6139 - val_auc: 0.6841
#
# Epoch 00081: saving model to History/model.epoch81.hdf5
# Epoch 82/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3650 - accuracy: 0.9017 - auc: 0.9611 - val_loss: 0.7237 - val_accuracy: 0.6535 - val_auc: 0.7564
#
# Epoch 00082: saving model to History/model.epoch82.hdf5
# Epoch 83/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.4071 - accuracy: 0.8557 - auc: 0.9397 - val_loss: 0.7485 - val_accuracy: 0.6436 - val_auc: 0.7353
#
# Epoch 00083: saving model to History/model.epoch83.hdf5
# Epoch 84/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3742 - accuracy: 0.8950 - auc: 0.9575 - val_loss: 0.7923 - val_accuracy: 0.6040 - val_auc: 0.6967
#
# Epoch 00084: saving model to History/model.epoch84.hdf5
# Epoch 85/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3714 - accuracy: 0.8776 - auc: 0.9568 - val_loss: 0.7502 - val_accuracy: 0.6634 - val_auc: 0.7345
#
# Epoch 00085: saving model to History/model.epoch85.hdf5
# Epoch 86/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3925 - accuracy: 0.8785 - auc: 0.9489 - val_loss: 0.7828 - val_accuracy: 0.6238 - val_auc: 0.7290
#
# Epoch 00086: saving model to History/model.epoch86.hdf5
# Epoch 87/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.3602 - accuracy: 0.8991 - auc: 0.9633 - val_loss: 0.8102 - val_accuracy: 0.6139 - val_auc: 0.6998
#
# Epoch 00087: saving model to History/model.epoch87.hdf5
# Epoch 88/120
# 281/281 [==============================] - 55s 198ms/step - loss: 0.3195 - accuracy: 0.9120 - auc: 0.9715 - val_loss: 0.7277 - val_accuracy: 0.6733 - val_auc: 0.7627
#
# Epoch 00088: saving model to History/model.epoch88.hdf5
# Epoch 89/120
# 281/281 [==============================] - 55s 194ms/step - loss: 0.3447 - accuracy: 0.8974 - auc: 0.9658 - val_loss: 0.7457 - val_accuracy: 0.6634 - val_auc: 0.7397
#
# Epoch 00089: saving model to History/model.epoch89.hdf5
# Epoch 90/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3373 - accuracy: 0.9061 - auc: 0.9690 - val_loss: 0.8086 - val_accuracy: 0.6139 - val_auc: 0.6985
#
# Epoch 00090: saving model to History/model.epoch90.hdf5
# Epoch 91/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3637 - accuracy: 0.8992 - auc: 0.9601 - val_loss: 0.7365 - val_accuracy: 0.7030 - val_auc: 0.7608
#
# Epoch 00091: saving model to History/model.epoch91.hdf5
# Epoch 92/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.3802 - accuracy: 0.8811 - auc: 0.9530 - val_loss: 0.7740 - val_accuracy: 0.6634 - val_auc: 0.7333
#
# Epoch 00092: saving model to History/model.epoch92.hdf5
# Epoch 93/120
# 281/281 [==============================] - 61s 216ms/step - loss: 0.3826 - accuracy: 0.8862 - auc: 0.9538 - val_loss: 0.7622 - val_accuracy: 0.6436 - val_auc: 0.7322
#
# Epoch 00093: saving model to History/model.epoch93.hdf5
# Epoch 94/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.3452 - accuracy: 0.9080 - auc: 0.9634 - val_loss: 0.7300 - val_accuracy: 0.6832 - val_auc: 0.7543
#
# Epoch 00094: saving model to History/model.epoch94.hdf5
# Epoch 95/120
# 281/281 [==============================] - 53s 190ms/step - loss: 0.3048 - accuracy: 0.9293 - auc: 0.9760 - val_loss: 0.7222 - val_accuracy: 0.6733 - val_auc: 0.7695
#
# Epoch 00095: saving model to History/model.epoch95.hdf5
# Epoch 96/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.3192 - accuracy: 0.9252 - auc: 0.9787 - val_loss: 0.7292 - val_accuracy: 0.6832 - val_auc: 0.7683
#
# Epoch 00096: saving model to History/model.epoch96.hdf5
# Epoch 97/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3350 - accuracy: 0.9029 - auc: 0.9701 - val_loss: 0.7508 - val_accuracy: 0.6436 - val_auc: 0.7503
#
# Epoch 00097: saving model to History/model.epoch97.hdf5
# Epoch 98/120
# 281/281 [==============================] - 58s 206ms/step - loss: 0.3129 - accuracy: 0.9249 - auc: 0.9755 - val_loss: 0.7748 - val_accuracy: 0.6535 - val_auc: 0.7345
#
# Epoch 00098: saving model to History/model.epoch98.hdf5
# Epoch 99/120
# 281/281 [==============================] - 61s 218ms/step - loss: 0.3620 - accuracy: 0.8913 - auc: 0.9608 - val_loss: 0.8169 - val_accuracy: 0.6436 - val_auc: 0.7251
#
# Epoch 00099: saving model to History/model.epoch99.hdf5
# Epoch 100/120
# 281/281 [==============================] - 56s 198ms/step - loss: 0.3570 - accuracy: 0.8940 - auc: 0.9608 - val_loss: 0.7891 - val_accuracy: 0.6436 - val_auc: 0.7213
#
# Epoch 00100: saving model to History/model.epoch100.hdf5
# Epoch 101/120
# 281/281 [==============================] - 54s 194ms/step - loss: 0.3093 - accuracy: 0.9299 - auc: 0.9767 - val_loss: 0.8029 - val_accuracy: 0.6139 - val_auc: 0.7130
#
# Epoch 00101: saving model to History/model.epoch101.hdf5
# Epoch 102/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.3088 - accuracy: 0.9153 - auc: 0.9746 - val_loss: 0.7640 - val_accuracy: 0.6733 - val_auc: 0.7815
#
# Epoch 00102: saving model to History/model.epoch102.hdf5
# Epoch 103/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.3303 - accuracy: 0.9062 - auc: 0.9693 - val_loss: 0.8009 - val_accuracy: 0.6337 - val_auc: 0.7221
#
# Epoch 00103: saving model to History/model.epoch103.hdf5
# Epoch 104/120
# 281/281 [==============================] - 58s 208ms/step - loss: 0.3700 - accuracy: 0.8743 - auc: 0.9573 - val_loss: 0.8164 - val_accuracy: 0.6436 - val_auc: 0.7097
#
# Epoch 00104: saving model to History/model.epoch104.hdf5
# Epoch 105/120
# 281/281 [==============================] - 59s 209ms/step - loss: 0.3004 - accuracy: 0.9316 - auc: 0.9852 - val_loss: 0.7677 - val_accuracy: 0.6634 - val_auc: 0.7540
#
# Epoch 00105: saving model to History/model.epoch105.hdf5
# Epoch 106/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.3072 - accuracy: 0.9190 - auc: 0.9735 - val_loss: 0.8780 - val_accuracy: 0.6040 - val_auc: 0.6770
#
# Epoch 00106: saving model to History/model.epoch106.hdf5
# Epoch 107/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3266 - accuracy: 0.9021 - auc: 0.9694 - val_loss: 0.7962 - val_accuracy: 0.6139 - val_auc: 0.7219
#
# Epoch 00107: saving model to History/model.epoch107.hdf5
# Epoch 108/120
# 281/281 [==============================] - 56s 200ms/step - loss: 0.3385 - accuracy: 0.9022 - auc: 0.9671 - val_loss: 0.8108 - val_accuracy: 0.6436 - val_auc: 0.7242
#
# Epoch 00108: saving model to History/model.epoch108.hdf5
# Epoch 109/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.3295 - accuracy: 0.8898 - auc: 0.9692 - val_loss: 0.7975 - val_accuracy: 0.6337 - val_auc: 0.7264
#
# Epoch 00109: saving model to History/model.epoch109.hdf5
# Epoch 110/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.2934 - accuracy: 0.9374 - auc: 0.9827 - val_loss: 0.8368 - val_accuracy: 0.6238 - val_auc: 0.7060
#
# Epoch 00110: saving model to History/model.epoch110.hdf5
# Epoch 111/120
# 281/281 [==============================] - 57s 203ms/step - loss: 0.3371 - accuracy: 0.9020 - auc: 0.9641 - val_loss: 0.9895 - val_accuracy: 0.6238 - val_auc: 0.6352
#
# Epoch 00111: saving model to History/model.epoch111.hdf5
# Epoch 112/120
# 281/281 [==============================] - 54s 191ms/step - loss: 0.3122 - accuracy: 0.8932 - auc: 0.9686 - val_loss: 0.7761 - val_accuracy: 0.6931 - val_auc: 0.7634
#
# Epoch 00112: saving model to History/model.epoch112.hdf5
# Epoch 113/120
# 281/281 [==============================] - 56s 199ms/step - loss: 0.2872 - accuracy: 0.9264 - auc: 0.9870 - val_loss: 0.8232 - val_accuracy: 0.6535 - val_auc: 0.7289
#
# Epoch 00113: saving model to History/model.epoch113.hdf5
# Epoch 114/120
# 281/281 [==============================] - 56s 201ms/step - loss: 0.3283 - accuracy: 0.8981 - auc: 0.9692 - val_loss: 0.8095 - val_accuracy: 0.6931 - val_auc: 0.7517
#
# Epoch 00114: saving model to History/model.epoch114.hdf5
# Epoch 115/120
# 281/281 [==============================] - 61s 217ms/step - loss: 0.3179 - accuracy: 0.9133 - auc: 0.9713 - val_loss: 0.8101 - val_accuracy: 0.6832 - val_auc: 0.7433
#
# Epoch 00115: saving model to History/model.epoch115.hdf5
# Epoch 116/120
# 281/281 [==============================] - 55s 197ms/step - loss: 0.2698 - accuracy: 0.9401 - auc: 0.9830 - val_loss: 0.8212 - val_accuracy: 0.6634 - val_auc: 0.7235
#
# Epoch 00116: saving model to History/model.epoch116.hdf5
# Epoch 117/120
# 281/281 [==============================] - 58s 207ms/step - loss: 0.2912 - accuracy: 0.9326 - auc: 0.9815 - val_loss: 0.8220 - val_accuracy: 0.7030 - val_auc: 0.7527
#
# Epoch 00117: saving model to History/model.epoch117.hdf5
# Epoch 118/120
# 281/281 [==============================] - 57s 202ms/step - loss: 0.2855 - accuracy: 0.9106 - auc: 0.9815 - val_loss: 0.9058 - val_accuracy: 0.6040 - val_auc: 0.6802
#
# Epoch 00118: saving model to History/model.epoch118.hdf5
# Epoch 119/120
# 281/281 [==============================] - 60s 214ms/step - loss: 0.2993 - accuracy: 0.9227 - auc: 0.9756 - val_loss: 0.8997 - val_accuracy: 0.6040 - val_auc: 0.6783
#
# Epoch 00119: saving model to History/model.epoch119.hdf5
# Epoch 120/120
# 281/281 [==============================] - 58s 205ms/step - loss: 0.3398 - accuracy: 0.8797 - auc: 0.9631 - val_loss: 0.8675 - val_accuracy: 0.6238 - val_auc: 0.7115
#
# Epoch 00120: saving model to History/model.epoch120.hdf5
